# %% [markdown]
# # Lag feature model
# This origin comming from https://www.kaggle.com/code/lblhandsome/optiver-robust-best-single-model/notebook

# %% [markdown]
# # Test for submission

# %%
from pathlib import Path
import os
import warnings
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import gc  # Garbage collection for memory management
import os  # Operating system-related functions
import time  # Time-related functions
import warnings  # Handling warnings
from itertools import combinations  # For creating combinations of elements
from warnings import simplefilter  # Simplifying warning handling
import joblib  # For saving and loading models
import numpy as np  # Numerical operations
import pandas as pd  # Data manipulation and analysis
from sklearn.metrics import mean_absolute_error  # Metric for evaluation
from sklearn.model_selection import KFold, TimeSeriesSplit  # Cross-validation techniques

# Disable warnings to keep the code clean
warnings.filterwarnings("ignore")
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

warnings.filterwarnings("ignore")

seed = 2023
num_folds = 8 # クロスバリデーションの分割数
# valid_split_day = 435  # Split day for time series data

# For kaggle environment
if os.environ.get("KAGGLE_DATA_PROXY_TOKEN") != None:
    BASE_OUTPUT_PATH = Path(f'/kaggle/working')
    BASE_INPUT_PATH = Path(f'/kaggle/input/optiver-trading-at-the-close')
    TRAIN_FILE = Path(f'{BASE_INPUT_PATH}/train.csv')
    TEST_FILE = Path(f'{BASE_INPUT_PATH}/example_test_files/test.csv')
    
    IS_LOCAL = False # If kaggle environment, set False
    IS_INFER = True # If kaggle environment, set True
    IS_USE_SAVED_MODEL = False # Use saved model or not
    IS_MIN_LEARN = False
    USE_OPTUNA = False # Use optuna or not
    USE_TEST_DATE_ON_TRAIN = True # Use test date on train or not
    USE_ALL_FEATUTES = True # Use all features or not
    USE_REVEALED_TARGETS = False # Use revealed targets or not
    USE_INDEX = True # Use index or not

    SAMPLE_SUBMISSION_FILE = Path(f'{BASE_INPUT_PATH}/example_test_files/sample_submission.csv')
    REVEALED_TARGETS_FILE = Path(f'{BASE_INPUT_PATH}/example_test_files/revealed_targets.csv')

    stopping_rounds = 100 # early_stopping用コールバック関数
    num_boost_round = 3000 # 計算回数
    DEVICE = 'gpu' # cpu or gpu
    OPTUNA_TIME_BUDGET = 60 * 60 * 4 # 1 hours
    TARGET_STOCK_IDS = [0, 1]

    optuna_params = {
        'boosting_type': 'gbdt',
        'objective': 'regression',         # 回帰
        'metric': 'rmse',                  # 損失（誤差）
        'verbosity': -1,
        'deterministic':True, #再現性確保用のパラメータ
        'force_row_wise':True,  #再現性確保用のパラメータ
        'device': DEVICE
    }

    """
    lgb_params = {
        'boosting_type': 'gbdt',
        'objective': 'regression',
        'metric': 'rmse',
        'verbosity': -1, 
        'device': DEVICE, 
        'feature_pre_filter': False, 
        'lambda_l1': 0.5,
        'lambda_l2': 0.5,
        'num_leaves': 31, 
        'feature_fraction': 0.8999999999999999, 
        'bagging_fraction': 1.0, 
        'bagging_freq': 0,
        'min_child_samples': 20
    }
    """

    """
    lgb_params = {
        'boosting_type': 'gbdt',
        'objective': 'regression', 
        'metric': 'rmse', 
        'verbosity': -1, 
        'device': DEVICE,
        'feature_pre_filter': False, 
        'lambda_l1': 0.0,
        'lambda_l2': 0.0,
        'num_leaves': 31, 
        'feature_fraction': 0.8, 
        'bagging_fraction': 1.0, 
        'bagging_freq': 0, 
        'min_child_samples': 20
    }
    """
   
    lgb_params = {
        'task': 'train',                   # 学習
        'objective': 'regression',                # 目的関数の種類。ここでは回帰タスクを指定
        'metric': 'rmse',                          # 評価指標
        'boosting_type': 'gbdt',                  # ブースティングタイプ。勾配ブースティング決定木
        "n_estimators": 32,                        # ブースティングに使用する木の数。多いほど性能が向上するが計算コストが増加
        "num_leaves": 64,                         # 木に存在する最大の葉の数。大きい値は精度を向上させるが過学習のリスクが増加
        "subsample": 0.8,                         # 各木のトレーニングに使用されるデータの割合。過学習を防ぐために一部のデータをサンプリング
        "colsample_bytree": 0.8,                  # 木を構築する際に使用される特徴の割合。特徴のサブセットを使用し過学習を防ぐ
        "learning_rate": 0.01,                 # 学習率。小さい値は堅牢なモデルを生成するが収束に時間がかかる
        'max_depth': 32,                           # 木の最大の深さ。深い木は複雑なモデルを作成するが過学習のリスクがある
        "device": DEVICE,                         # トレーニングに使用するデバイス（CPUまたはGPU）
        "verbosity": -1,                          # LightGBMのログ出力のレベル。-1はログを出力しないことを意味する
        "importance_type": "gain",                # 特徴重要度を計算する際の指標。"gain"は分割による平均情報利得
        'lambda_l1': 0.5,                         # L1正則化項の係数。過学習を防ぐためにモデルの複雑さにペナルティを課す
        'lambda_l2': 0.5,                         # L2正則化項の係数。同じく過学習を防ぐ
        'bagging_freq': 5,                 # バギング実施頻度
        'min_child_samples': 10,           # 葉に含まれる最小データ数
        'seed': seed,                       # シード値
    }

# For local environment
else:
    BASE_OUTPUT_PATH = Path(f'../output')
    BASE_INPUT_PATH = Path(f'../kaggle/input/optiver-trading-at-the-close')
    TRAIN_FILE = Path(f'{BASE_INPUT_PATH}/train.csv')
    TEST_FILE = Path(f'{BASE_INPUT_PATH}/test.csv')

    SAMPLE_SUBMISSION_FILE = Path(f'{BASE_INPUT_PATH}/sample_submission.csv')
    REVEALED_TARGETS_FILE = Path(f'{BASE_INPUT_PATH}/revealed_targets.csv')

    IS_LOCAL = True
    IS_INFER = True
    IS_USE_SAVED_MODEL = False # Use saved model or not
    IS_MIN_LEARN = True
    USE_OPTUNA = True # Use optuna or not
    USE_ALL_FEATUTES = True # Use all features or not
    USE_TEST_DATE_ON_TRAIN = True # Use test date on train or not
    USE_REVEALED_TARGETS = True 
    USE_INDEX = True # Use index or not
    TARGET_STOCK_IDS = [0, 1]

    # For training
    stopping_rounds = 1 # early_stopping用コールバック関数
    num_boost_round = 1 # 計算回数
    DEVICE = 'cpu' # cpu or gpu
    OPTUNA_TIME_BUDGET = 60 # 1 min

    optuna_params = {
        'boosting_type': 'gbdt',
        'objective': 'regression',         # 回帰
        'metric': 'rmse',                  # 損失（誤差）
        'verbosity': -1,
        'deterministic':True, #再現性確保用のパラメータ
        'force_row_wise':True,  #再現性確保用のパラメータ
        'device': DEVICE
    }

    
    lgb_params = {
        'task': 'train',                   # 学習
        'boosting_type': 'gbdt',           # GBDT
        'objective': 'regression',         # 回帰
        'metric': 'rmse',                  # 損失（誤差）
        'learning_rate': 0.01,             # 学習率
        'lambda_l1': 0.5,                  # L1正則化項の係数
        'lambda_l2': 0.5,                  # L2正則化項の係数
        'num_leaves': 10,                  # 最大葉枚数
        'feature_fraction': 0.5,           # ランダムに抽出される列の割合
        'bagging_fraction': 0.5,           # ランダムに抽出される標本の割合
        'bagging_freq': 5,                 # バギング実施頻度
        'min_child_samples': 10,           # 葉に含まれる最小データ数
        'seed': seed,                       # シード値
        "device": DEVICE,
        'verbosity': -1
    }


print(f"BASE_OUTPUT_PATH: {BASE_OUTPUT_PATH}")
print(f"BASE_INPUT_PATH: {BASE_INPUT_PATH}")
print(f"TRAIN_FILE: {TRAIN_FILE}")
print(f"TEST_FILE: {TEST_FILE}")
print(f"IS_LOCAL: {IS_LOCAL}")
print(f"IS_INFER: {IS_INFER}")
print(f"IS_USE_SAVED_MODEL: {IS_USE_SAVED_MODEL}")
print(f"IS_MIN_LEARN: {IS_MIN_LEARN}")
print(f"USE_OPTUNA: {USE_OPTUNA}")
print(f"USE_TEST_DATE_ON_TRAIN: {USE_TEST_DATE_ON_TRAIN}")
print(f"USE_ALL_FEATUTES: {USE_ALL_FEATUTES}")
print(f"USE_REVEALED_TARGETS: {USE_REVEALED_TARGETS}")
print(f"USE_INDEX: {USE_INDEX}")
# Out:
# BASE_OUTPUT_PATH: ../output
# BASE_INPUT_PATH: ../kaggle/input/optiver-trading-at-the-close
# TRAIN_FILE: ../kaggle/input/optiver-trading-at-the-close/train.csv
# TEST_FILE: ../kaggle/input/optiver-trading-at-the-close/test.csv
# IS_LOCAL: True
# IS_INFER: True
# IS_USE_SAVED_MODEL: False
# IS_MIN_LEARN: True
# USE_OPTUNA: True
# USE_TEST_DATE_ON_TRAIN: True
# USE_ALL_FEATUTES: True
# USE_REVEALED_TARGETS: True
# USE_INDEX: True

# %%
# %%time 

from gc import collect;
from psutil import Process;
from os import system, getpid, walk;

# Defining global configurations and functions:-

    
def GetMemUsage():
    """
    This function defines the memory usage across the kernel. 
    Source-
    https://stackoverflow.com/questions/61366458/how-to-find-memory-usage-of-kaggle-notebook
    """;
    
    pid = getpid();
    py = Process(pid);
    memory_use = py.memory_info()[0] / 2. ** 30;
    return f"RAM memory GB usage = {memory_use :.4}";


collect();
print(GetMemUsage())
# Out:
# RAM memory GB usage = 0.4208
# CPU times: user 199 ms, sys: 113 ms, total: 312 ms
# Wall time: 414 ms

# %% [markdown]
# # Functions

# %%
# %%time 

from typing import Sequence, Tuple
import pandas as pd

# for local execution
class MockApi:
    def __init__(self):
        '''
        YOU MUST UPDATE THE FIRST THREE LINES of this method.
        They've been intentionally left in an invalid state.

        Variables to set:
            input_paths: a list of two or more paths to the csv files to be served
            group_id_column: the column that identifies which groups of rows the API should serve.
                A call to iter_test serves all rows of all dataframes with the current group ID value.
            export_group_id_column: if true, the dataframes iter_test serves will include the group_id_column values.
        '''
        self.input_paths: Sequence[str] = [TEST_FILE, REVEALED_TARGETS_FILE, SAMPLE_SUBMISSION_FILE]
        self.group_id_column: str = 'time_id'
        self.export_group_id_column: bool = True
        # iter_test is only designed to support at least two dataframes, such as test and sample_submission
        assert len(self.input_paths) >= 2

        self._status = 'initialized'
        self.predictions = []

    def iter_test(self) -> Tuple[pd.DataFrame]:
        '''
        Loads all of the dataframes specified in self.input_paths,
        then yields all rows in those dataframes that equal the current self.group_id_column value.
        '''
        if self._status != 'initialized':

            raise Exception('WARNING: the real API can only iterate over `iter_test()` once.')

        dataframes = []
        for pth in self.input_paths:
            dataframes.append(pd.read_csv(pth, low_memory=False))
        group_order = dataframes[0][self.group_id_column].drop_duplicates().tolist()
        dataframes = [df.set_index(self.group_id_column) for df in dataframes]

        for group_id in group_order:
            self._status = 'prediction_needed'
            current_data = []
            for df in dataframes:
                cur_df = df.loc[group_id].copy()
                # returning single line dataframes from df.loc requires special handling
                if not isinstance(cur_df, pd.DataFrame):
                    cur_df = pd.DataFrame({a: b for a, b in zip(cur_df.index.values, cur_df.values)}, index=[group_id])
                    cur_df.index.name = self.group_id_column
                cur_df = cur_df.reset_index(drop=not(self.export_group_id_column))
                current_data.append(cur_df)
            yield tuple(current_data)

            while self._status != 'prediction_received':
                print('You must call `predict()` successfully before you can continue with `iter_test()`', flush=True)
                yield None

        with open('submission.csv', 'w') as f_open:
            pd.concat(self.predictions).to_csv(f_open, index=False)
        self._status = 'finished'

    def predict(self, user_predictions: pd.DataFrame):
        '''
        Accepts and stores the user's predictions and unlocks iter_test once that is done
        '''
        if self._status == 'finished':
            raise Exception('You have already made predictions for the full test set.')
        if self._status != 'prediction_needed':
            raise Exception('You must get the next test sample from `iter_test()` first.')
        if not isinstance(user_predictions, pd.DataFrame):
            raise Exception('You must provide a DataFrame.')

        self.predictions.append(user_predictions)
        self._status = 'prediction_received'

def make_env():
    return MockApi()
# Out:
# CPU times: user 34 µs, sys: 6 µs, total: 40 µs
# Wall time: 42 µs

# %%
def pd_display_max():
    pd.set_option('display.max_rows', None)  # 行の最大表示数を無制限に設定
    pd.set_option('display.max_columns', None)  # 列の最大表示数を無制限に設定
    pd.set_option('display.width', None)  # 表示幅を拡張
    pd.set_option('display.max_colwidth', None)  # 列の幅を最大に設定

def pd_clear_display_max():
    pd.set_option('display.max_rows', 10)
    pd.set_option('display.max_columns', 10)
    pd.set_option('display.width', None)  # 表示幅を拡張
    pd.set_option('display.max_colwidth', None)  # 列の幅を最大に設定

# %%
# 🧹 Function to reduce memory usage of a Pandas DataFrame
def reduce_mem_usage(df, name: str):
    """
    Iterate through all numeric columns of a dataframe and modify the data type
    to reduce memory usage.
    """
    
    # 📏 Calculate the initial memory usage of the DataFrame
    start_mem = df.memory_usage().sum() / 1024**2

    # 🔄 Iterate through each column in the DataFrame
    for col in df.columns:
        col_type = df[col].dtype

        # Check if the column's data type is not 'object' (i.e., numeric)
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            
            # Check if the column's data type is an integer
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                # Check if the column's data type is a float
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float32)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float32)


    print(f"Memory usage of {name} is {start_mem:.2f} MB")
    end_mem = df.memory_usage().sum() / 1024**2
    print(f"Memory usage after optimization is: {end_mem:.2f} MB")
    decrease = 100 * (start_mem - end_mem) / start_mem
    print(f"Decreased by {decrease:.2f}%")

    # 🔄 Return the DataFrame with optimized memory usage

    start_mem = df.memory_usage().sum() / 1024**2
    return df

# %%
# 🏎️ Import Numba for just-in-time (JIT) compilation and parallel processing
from numba import njit, prange

# 📊 Function to compute triplet imbalance in parallel using Numba
@njit(parallel=True)
def compute_triplet_imbalance(df_values, comb_indices):
    num_rows = df_values.shape[0]
    num_combinations = len(comb_indices)
    imbalance_features = np.empty((num_rows, num_combinations))

    # 🔁 Loop through all combinations of triplets
    for i in prange(num_combinations):
        a, b, c = comb_indices[i]
        
        # 🔁 Loop through rows of the DataFrame
        for j in range(num_rows):
            max_val = max(df_values[j, a], df_values[j, b], df_values[j, c])
            min_val = min(df_values[j, a], df_values[j, b], df_values[j, c])
            mid_val = df_values[j, a] + df_values[j, b] + df_values[j, c] - min_val - max_val
            
            # 🚫 Prevent division by zero
            if mid_val == min_val:
                imbalance_features[j, i] = np.nan
            else:
                imbalance_features[j, i] = (max_val - mid_val) / (mid_val - min_val)

    return imbalance_features

# 📈 Function to calculate triplet imbalance for given price data and a DataFrame
def calculate_triplet_imbalance_numba(price, df):
    # Convert DataFrame to numpy array for Numba compatibility
    df_values = df[price].values
    comb_indices = [(price.index(a), price.index(b), price.index(c)) for a, b, c in combinations(price, 3)]

    # Calculate the triplet imbalance using the Numba-optimized function
    features_array = compute_triplet_imbalance(df_values, comb_indices)

    # Create a DataFrame from the results
    columns = [f"{a}_{b}_{c}_imb2" for a, b, c in combinations(price, 3)]
    features = pd.DataFrame(features_array, columns=columns)

    return features

# %%
# 📊 Function to generate imbalance features
def imbalance_features(df):
    if DEVICE == 'gpu':
        import cudf
        df = cudf.from_pandas(df)
    
    # Define lists of price and size-related column names
    prices = ["reference_price", "far_price", "near_price", "ask_price", "bid_price", "wap"]
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]

    # V1 features
    # Calculate various features using Pandas eval function
    df["volume"] = df.eval("ask_size + bid_size")
    df["mid_price"] = df.eval("ask_price + bid_price")/2
    df["liquidity_imbalance"] = df.eval("(bid_size-ask_size)/(bid_size+ask_size)")
    df["matched_imbalance"] = df.eval("imbalance_size-matched_size")/df.eval("matched_size+imbalance_size")
    df["size_imbalance"] = df.eval("bid_size / ask_size")
    
    # Create features for pairwise price imbalances
    for c in combinations(prices, 2):
        df[f"{c[0]}_{c[1]}_imb"] = df.eval(f"({c[0]} - {c[1]})/({c[0]} + {c[1]})")
        
    # V2 features
    # Calculate additional features
    df["imbalance_momentum"] = df.groupby(['stock_id'])['imbalance_size'].diff(periods=1) / df['matched_size']
    df["price_spread"] = df["ask_price"] - df["bid_price"]
    df["spread_intensity"] = df.groupby(['stock_id'])['price_spread'].diff()
    df['price_pressure'] = df['imbalance_size'] * (df['ask_price'] - df['bid_price'])
    df['market_urgency'] = df['price_spread'] * df['liquidity_imbalance']
    df['depth_pressure'] = (df['ask_size'] - df['bid_size']) * (df['far_price'] - df['near_price'])
    # Calculate the imbalance ratio
    df['match_balance'] = ( df['matched_size']  + (df['imbalance_buy_sell_flag'] * df['imbalance_size'])) / df['matched_size']
    
    # Calculate various statistical aggregation features
    
        
    # V3 features
    # Calculate shifted and return features for specific columns
    for col in ['matched_size', 'imbalance_size', 'reference_price', 'imbalance_buy_sell_flag']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_shift_{window}"] = df.groupby('stock_id')[col].shift(window)
            df[f"{col}_ret_{window}"] = df.groupby('stock_id')[col].pct_change(window)
    
    # Calculate diff features for specific columns
    for col in ['ask_price', 'bid_price', 'ask_size', 'bid_size']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_diff_{window}"] = df.groupby("stock_id")[col].diff(window)
    if DEVICE == 'gpu':
        df = df.to_pandas()
    # Replace infinite values with 0
    return df.replace([np.inf, -np.inf], 0)

def numba_imb_features(df):
    prices = ["reference_price", "far_price", "near_price", "ask_price", "bid_price", "wap"]
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]
    
    for func in ["mean", "std", "skew", "kurt"]:
        df[f"all_prices_{func}"] = df[prices].agg(func, axis=1)
        df[f"all_sizes_{func}"] = df[sizes].agg(func, axis=1)
        
    # Calculate triplet imbalance features using the Numba-optimized function
    for c in [['ask_price', 'bid_price', 'wap', 'reference_price'], sizes]:
        triplet_feature = calculate_triplet_imbalance_numba(c, df)
        df[triplet_feature.columns] = triplet_feature.values
    return df

# 📅 Function to generate time and stock-related features
def other_features(df):
    df["dow"] = df["date_id"] % 5  # Day of the week
    df["seconds"] = df["seconds_in_bucket"] % 60  # Seconds
    df["minute"] = df["seconds_in_bucket"] // 60  # Minutes

    # Map global features to the DataFrame
    for key, value in global_stock_id_feats.items():
        df[f"global_{key}"] = df["stock_id"].map(value.to_dict())

    return df

# 🚀 Function to generate all features by combining imbalance and other features
def generate_basic_features(df):
    prev_cols = list(df.columns)

    # Generate imbalance features
    df = imbalance_features(df)
    df = numba_imb_features(df)

    df = reduce_mem_usage(df, "generate_basic_features")

    collect()  # Perform garbage collection to free up memory

    return df

# %% [markdown]
# # Generationg train dataset

# %%
def load_train_dataset():
    df = pd.read_csv(TRAIN_FILE)
    # 🧹 Remove rows with missing values in the "target" column
    df = df.dropna(subset=["target"])
    # 🔁 Reset the index of the DataFrame and apply the changes in place
    df.reset_index(drop=True, inplace=True)
    return df

def load_test_dataset():
    df_test = pd.read_csv(TEST_FILE)
    df_revealed_targets = pd.read_csv(REVEALED_TARGETS_FILE)
    df_revealed_targets = df_revealed_targets.dropna(subset=['date_id', 'seconds_in_bucket', 'stock_id'])
    df_revealed_targets['revealed_date_id'] = df_revealed_targets['revealed_date_id'].astype(int).astype(str)
    df_revealed_targets['seconds_in_bucket'] = df_revealed_targets['seconds_in_bucket'].astype(str)
    df_revealed_targets['stock_id'] = df_revealed_targets['stock_id'].astype(int).astype(str)  # Converting to int first to remove any decimal points
    df_revealed_targets['row_id'] = df_revealed_targets['revealed_date_id'] + '_' + df_revealed_targets['seconds_in_bucket'] + '_' + df_revealed_targets['stock_id']
    df_revealed_targets = df_revealed_targets.rename(columns={'revealed_target': 'target'})
    df_revealed_targets = df_revealed_targets[['row_id', 'target']]
    df_revealed_targets = df_revealed_targets.dropna(subset=["target"])
    df = pd.merge(df_test, df_revealed_targets, how='left', on='row_id')
    df = df.rename(columns={'revealed_target': 'target'})
    df = df.dropna(subset=["target"])
    df.reset_index(drop=True, inplace=True)
    return df

# %%
# %%time
# Check if the code is running in offline or online mode
print("Load train dataset")

df_train = load_train_dataset()

if USE_TEST_DATE_ON_TRAIN:
    try:
        df_test = load_test_dataset()
        df_test.to_csv('train_test.csv', index=False)
        df_train = pd.concat([df_train, df_test])
        df_train = df_train.drop_duplicates()
        del df_test
    except Exception as e:
        print("Cannot get test date", e)
df_train.reset_index(drop=True, inplace=True)


if IS_MIN_LEARN:
    print("MIN LEARN MODE :", TARGET_STOCK_IDS)
    # In local mode, stock id TARGET_STOCK_ID is used for training
    df_train = df_train[df_train["stock_id"].isin(TARGET_STOCK_IDS)]
    
features = [c for c in df_train.columns if c not in ["row_id", "target", "time_id", "row_id", "date_id", "currently_scored"]]
print(features)

collect();
print(GetMemUsage())
# Out:
# Load train dataset
# MIN LEARN MODE : [0, 1]
# ['stock_id', 'seconds_in_bucket', 'imbalance_size', 'imbalance_buy_sell_flag', 'reference_price', 'matched_size', 'far_price', 'near_price', 'bid_price', 'bid_size', 'ask_price', 'ask_size', 'wap']
# RAM memory GB usage = 1.395
# CPU times: user 12.7 s, sys: 3.88 s, total: 16.6 s
# Wall time: 18.4 s

# %%
# %%time

print("Step1. Generate general Global Stock ID Features and basic features")
prev_cols = list(df_train.columns)
global_stock_id_feats = {
    "median_size": df_train.groupby("stock_id")["bid_size"].median() + df_train.groupby("stock_id")["ask_size"].median(),
    "std_size": df_train.groupby("stock_id")["bid_size"].std() + df_train.groupby("stock_id")["ask_size"].std(),
    "ptp_size": df_train.groupby("stock_id")["bid_size"].max() - df_train.groupby("stock_id")["bid_size"].min(),
    "median_price": df_train.groupby("stock_id")["bid_price"].median() + df_train.groupby("stock_id")["ask_price"].median(),
    "std_price": df_train.groupby("stock_id")["bid_price"].std() + df_train.groupby("stock_id")["ask_price"].std(),
    "ptp_price": df_train.groupby("stock_id")["bid_price"].max() - df_train.groupby("stock_id")["ask_price"].min(),
}

df_train = generate_basic_features(df_train)

generated_feature_name = list(set(df_train.columns) - set(prev_cols))
features += generated_feature_name
print(generated_feature_name)

collect()
print(GetMemUsage())
# Out:
# Step1. Generate general Global Stock ID Features and basic features
# Memory usage of generate_basic_features is 44.00 MB
# Memory usage after optimization is: 21.80 MB
# Decreased by 50.46%
# ['bid_size_diff_3', 'near_price_ask_price_imb', 'imbalance_buy_sell_flag_shift_1', 'size_imbalance', 'price_pressure', 'ask_size_diff_2', 'imbalance_size_ret_1', 'liquidity_imbalance', 'matched_size_ret_1', 'bid_size_diff_2', 'imbalance_buy_sell_flag_ret_2', 'imbalance_momentum', 'matched_imbalance', 'bid_price_wap_reference_price_imb2', 'imbalance_size_shift_10', 'bid_price_wap_imb', 'ask_price_wap_reference_price_imb2', 'bid_price_diff_2', 'matched_size_bid_size_imbalance_size_imb2', 'reference_price_shift_2', 'ask_price_bid_price_wap_imb2', 'imbalance_buy_sell_flag_shift_2', 'imbalance_buy_sell_flag_shift_10', 'matched_size_shift_3', 'far_price_bid_price_imb', 'matched_size_ret_10', 'all_prices_mean', 'near_price_wap_imb', 'bid_size_ask_size_imbalance_size_imb2', 'reference_price_ask_price_imb', 'near_price_bid_price_imb', 'reference_price_ret_3', 'reference_price_far_price_imb', 'all_prices_skew', 'match_balance', 'imbalance_buy_sell_flag_ret_3', 'reference_price_shift_3', 'bid_price_diff_3', 'far_price_wap_imb', 'matched_size_ret_2', 'imbalance_size_shift_2', 'volume', 'reference_price_wap_imb', 'ask_price_diff_10', 'matched_size_ask_size_imbalance_size_imb2', 'ask_size_diff_10', 'imbalance_buy_sell_flag_ret_1', 'price_spread', 'bid_price_diff_1', 'imbalance_size_shift_3', 'far_price_ask_price_imb', 'all_sizes_kurt', 'reference_price_ret_2', 'imbalance_buy_sell_flag_ret_10', 'imbalance_size_ret_10', 'matched_size_bid_size_ask_size_imb2', 'reference_price_ret_1', 'imbalance_size_ret_2', 'ask_size_diff_1', 'all_prices_kurt', 'imbalance_buy_sell_flag_shift_3', 'ask_price_diff_1', 'ask_price_bid_price_reference_price_imb2', 'ask_price_diff_2', 'matched_size_shift_2', 'ask_price_wap_imb', 'ask_price_bid_price_imb', 'matched_size_shift_1', 'ask_price_diff_3', 'matched_size_ret_3', 'all_sizes_mean', 'reference_price_shift_10', 'all_sizes_std', 'spread_intensity', 'depth_pressure', 'reference_price_bid_price_imb', 'matched_size_shift_10', 'market_urgency', 'all_sizes_skew', 'bid_price_diff_10', 'far_price_near_price_imb', 'reference_price_ret_10', 'ask_size_diff_3', 'all_prices_std', 'imbalance_size_ret_3', 'bid_size_diff_1', 'mid_price', 'imbalance_size_shift_1', 'reference_price_shift_1', 'bid_size_diff_10', 'reference_price_near_price_imb']
# RAM memory GB usage = 1.494
# CPU times: user 956 ms, sys: 75.5 ms, total: 1.03 s
# Wall time: 1.13 s

# %%
# %%time

print("Step2. Generate enhanced features")
prev_cols = list(df_train.columns)

def generate_historical_features(df):
    def cal_vix(df, group_key, target_col, period):
        return df.groupby(group_key)[target_col].transform(lambda x: np.log(x).diff().rolling(period).std())

    print("generate_historical_features")
    taget_cols = ['wap', 'match_balance']
    if USE_REVEALED_TARGETS:
        taget_cols.append('revealed_target')
    if USE_INDEX:
        taget_cols.append('index_mean_wap')
        taget_cols.append('index_std_wap')
        taget_cols.append('index_mean_match_balance')
        taget_cols.append('index_std_match_balance')
    for col in taget_cols:
        for window in [1, 3, 7]:
            col_name = f"{col}_diff_{window}"
            df[col_name] = df.groupby("stock_id")[col].diff(window)
            #df[col_name] = df[col_name].fillna(0)  # NaNを0で置き換える
        for period in [3, 5, 7]:
            col_name = f"{col}_vix_{period}"
            df[col_name] = cal_vix(df, ['stock_id', 'date_id'], col, period)
    df = df.replace([np.inf, -np.inf], 0)
    return df

def generate_index_features(df):
    print("generate_index_features")
     # Calculating mean and std for 'wap' and 'match_balance'
    wap_stats = df.groupby(['date_id', 'seconds_in_bucket'])['wap'].agg(['mean', 'std']).reset_index()
    match_balance_stats = df.groupby(['date_id', 'seconds_in_bucket'])['match_balance'].agg(['mean', 'std']).reset_index()

    # Adding prefix and suffix
    wap_stats = wap_stats.add_prefix('index_').add_suffix('_wap')
    match_balance_stats = match_balance_stats.add_prefix('index_').add_suffix('_match_balance')

    # Adjusting column names for merging
    wap_stats = wap_stats.rename(columns={'index_date_id_wap': 'date_id', 'index_seconds_in_bucket_wap': 'seconds_in_bucket'})
    match_balance_stats = match_balance_stats.rename(columns={'index_date_id_match_balance': 'date_id', 'index_seconds_in_bucket_match_balance': 'seconds_in_bucket'})

    # Merging with the original dataframe
    df = df.merge(wap_stats, on=['date_id', 'seconds_in_bucket'], how='left')
    df = df.merge(match_balance_stats, on=['date_id', 'seconds_in_bucket'], how='left')

    del wap_stats, match_balance_stats
    return df

def generate_enhance_features(df, is_train = False):
    if is_train:
        if USE_REVEALED_TARGETS:
            print("Use revealed targets")
            df[f"revealed_target"] = df.groupby(['date_id', 'stock_id'])['target'].shift(1)
        else:
            print("Dosent't use revealed targets")
    if USE_INDEX:
        print("Use index")
        df = generate_index_features(df)
    df = generate_historical_features(df)
    df = reduce_mem_usage(df, "generate_enhance_features")
    collect()
    return df

df_train = generate_enhance_features(df_train, is_train=True)
generated_feature_name = list(set(df_train.columns) - set(prev_cols))
features += generated_feature_name
print(generated_feature_name)

collect()
print(GetMemUsage())
# Out:
# Step2. Generate enhanced features
# Use revealed targets
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 35.12 MB
# Memory usage after optimization is: 30.88 MB
# Decreased by 12.07%
# ['index_std_match_balance_vix_5', 'index_std_match_balance_vix_3', 'revealed_target_vix_5', 'index_std_wap_vix_7', 'revealed_target_diff_3', 'wap_diff_3', 'wap_diff_1', 'index_std_match_balance_vix_7', 'revealed_target', 'index_mean_wap_diff_7', 'index_mean_wap_diff_3', 'index_std_match_balance', 'wap_vix_3', 'index_std_wap_vix_5', 'index_std_wap_diff_7', 'index_std_match_balance_diff_3', 'wap_vix_7', 'index_std_wap_diff_3', 'match_balance_vix_3', 'index_std_wap', 'match_balance_diff_3', 'index_mean_wap', 'match_balance_vix_7', 'match_balance_diff_7', 'revealed_target_diff_7', 'index_mean_wap_vix_5', 'revealed_target_vix_7', 'index_mean_wap_vix_3', 'wap_diff_7', 'index_std_wap_diff_1', 'index_mean_wap_vix_7', 'index_mean_match_balance_vix_3', 'index_mean_match_balance_vix_5', 'index_mean_match_balance', 'revealed_target_diff_1', 'index_mean_match_balance_diff_1', 'index_mean_match_balance_diff_7', 'index_std_match_balance_diff_1', 'match_balance_diff_1', 'index_mean_wap_diff_1', 'index_mean_match_balance_diff_3', 'revealed_target_vix_3', 'index_std_match_balance_diff_7', 'match_balance_vix_5', 'wap_vix_5', 'index_std_wap_vix_3', 'index_mean_match_balance_vix_7']
# RAM memory GB usage = 1.528
# CPU times: user 3.94 s, sys: 44 ms, total: 3.99 s
# Wall time: 4 s

# %%
cdf=None
if USE_REVEALED_TARGETS:
    cdf = df_train[['date_id', 'stock_id', 'target', 'revealed_target']].head(10)
cdf
# Out:
#    date_id  stock_id    target  revealed_target
# 0        0         0 -3.029704              NaN
# 1        0         1 -5.519986              NaN
# 2        0         0  0.389814        -3.029704
# 3        0         1 -1.620054        -5.519986
# 4        0         0  4.220009         0.389814
# 5        0         1 -6.459951        -1.620054
# 6        0         0  5.450249         4.220009
# 7        0         1 -5.149841        -6.459951
# 8        0         0  3.169775         5.450249
# 9        0         1 -6.750226        -5.149841

# %%
# %%time

print("Step3. Normalized features")
prev_cols = list(df_train.columns)


# Global features for normarization
global_wap = df_train['wap'].describe()
global_mathch_balance = df_train['match_balance'].describe()
global_target = df_train['target'].describe()
global_reference_price = df_train['reference_price'].describe()

# 📈 Function to generate normalized features
def generate_normalized_features(df, is_train):
    print("generate_normalized_features")
    if is_train:
        df['n_target'] = (df['target'] - global_target['mean']) / global_target['std']
    df['n_wap'] = (df['wap'] - global_wap['mean']) / global_wap['std']
    df['n_match_balance'] = (df['match_balance'] - global_mathch_balance['mean']) / global_mathch_balance['std']
    df['n_reference_price'] = (df['reference_price'] - global_reference_price['mean']) / global_reference_price['std']
    
    df = reduce_mem_usage(df, "generate_normalized_features")
    return df

df_train = generate_normalized_features(df_train, True)
generated_feature_name = list(set(df_train.columns) - set(prev_cols))
generated_feature_name = [c for c in generated_feature_name if c not in ["n_target"]]

features += generated_feature_name
print(generated_feature_name)

collect();
print(GetMemUsage())
# Out:
# Step3. Normalized features
# generate_normalized_features
# Memory usage of generate_normalized_features is 31.69 MB
# Memory usage after optimization is: 31.69 MB
# Decreased by 0.00%
# ['n_reference_price', 'n_wap', 'n_match_balance']
# RAM memory GB usage = 1.531
# CPU times: user 211 ms, sys: 4.51 ms, total: 216 ms
# Wall time: 216 ms

# %%
df_train = reduce_mem_usage(df_train, 'train')

collect();
print(GetMemUsage())
# Out:
# Memory usage of train is 31.69 MB
# Memory usage after optimization is: 31.69 MB
# Decreased by 0.00%
# RAM memory GB usage = 1.539

# %% [markdown]
# # Feature selection

# %%
# feature selection
if not USE_ALL_FEATUTES:
    features  = [
        "revealed_target",
        "wap_diff_1",
        "index_mean_wap_diff_1",
        "seconds_in_bucket",
        "stock_id",
    ]
#df_valid = df_train["target"]
#df_train = df_train[features]
features.remove("revealed_target")
features
# Out:
# ['stock_id',
#  'seconds_in_bucket',
#  'imbalance_size',
#  'imbalance_buy_sell_flag',
#  'reference_price',
#  'matched_size',
#  'far_price',
#  'near_price',
#  'bid_price',
#  'bid_size',
#  'ask_price',
#  'ask_size',
#  'wap',
#  'bid_size_diff_3',
#  'near_price_ask_price_imb',
#  'imbalance_buy_sell_flag_shift_1',
#  'size_imbalance',
#  'price_pressure',
#  'ask_size_diff_2',
#  'imbalance_size_ret_1',
#  'liquidity_imbalance',
#  'matched_size_ret_1',
#  'bid_size_diff_2',
#  'imbalance_buy_sell_flag_ret_2',
#  'imbalance_momentum',
#  'matched_imbalance',
#  'bid_price_wap_reference_price_imb2',
#  'imbalance_size_shift_10',
#  'bid_price_wap_imb',
#  'ask_price_wap_reference_price_imb2',
#  'bid_price_diff_2',
#  'matched_size_bid_size_imbalance_size_imb2',
#  'reference_price_shift_2',
#  'ask_price_bid_price_wap_imb2',
#  'imbalance_buy_sell_flag_shift_2',
#  'imbalance_buy_sell_flag_shift_10',
#  'matched_size_shift_3',
#  'far_price_bid_price_imb',
#  'matched_size_ret_10',
#  'all_prices_mean',
#  'near_price_wap_imb',
#  'bid_size_ask_size_imbalance_size_imb2',
#  'reference_price_ask_price_imb',
#  'near_price_bid_price_imb',
#  'reference_price_ret_3',
#  'reference_price_far_price_imb',
#  'all_prices_skew',
#  'match_balance',
#  'imbalance_buy_sell_flag_ret_3',
#  'reference_price_shift_3',
#  'bid_price_diff_3',
#  'far_price_wap_imb',
#  'matched_size_ret_2',
#  'imbalance_size_shift_2',
#  'volume',
#  'reference_price_wap_imb',
#  'ask_price_diff_10',
#  'matched_size_ask_size_imbalance_size_imb2',
#  'ask_size_diff_10',
#  'imbalance_buy_sell_flag_ret_1',
#  'price_spread',
#  'bid_price_diff_1',
#  'imbalance_size_shift_3',
#  'far_price_ask_price_imb',
#  'all_sizes_kurt',
#  'reference_price_ret_2',
#  'imbalance_buy_sell_flag_ret_10',
#  'imbalance_size_ret_10',
#  'matched_size_bid_size_ask_size_imb2',
#  'reference_price_ret_1',
#  'imbalance_size_ret_2',
#  'ask_size_diff_1',
#  'all_prices_kurt',
#  'imbalance_buy_sell_flag_shift_3',
#  'ask_price_diff_1',
#  'ask_price_bid_price_reference_price_imb2',
#  'ask_price_diff_2',
#  'matched_size_shift_2',
#  'ask_price_wap_imb',
#  'ask_price_bid_price_imb',
#  'matched_size_shift_1',
#  'ask_price_diff_3',
#  'matched_size_ret_3',
#  'all_sizes_mean',
#  'reference_price_shift_10',
#  'all_sizes_std',
#  'spread_intensity',
#  'depth_pressure',
#  'reference_price_bid_price_imb',
#  'matched_size_shift_10',
#  'market_urgency',
#  'all_sizes_skew',
#  'bid_price_diff_10',
#  'far_price_near_price_imb',
#  'reference_price_ret_10',
#  'ask_size_diff_3',
#  'all_prices_std',
#  'imbalance_size_ret_3',
#  'bid_size_diff_1',
#  'mid_price',
#  'imbalance_size_shift_1',
#  'reference_price_shift_1',
#  'bid_size_diff_10',
#  'reference_price_near_price_imb',
#  'index_std_match_balance_vix_5',
#  'index_std_match_balance_vix_3',
#  'revealed_target_vix_5',
#  'index_std_wap_vix_7',
#  'revealed_target_diff_3',
#  'wap_diff_3',
#  'wap_diff_1',
#  'index_std_match_balance_vix_7',
#  'index_mean_wap_diff_7',
#  'index_mean_wap_diff_3',
#  'index_std_match_balance',
#  'wap_vix_3',
#  'index_std_wap_vix_5',
#  'index_std_wap_diff_7',
#  'index_std_match_balance_diff_3',
#  'wap_vix_7',
#  'index_std_wap_diff_3',
#  'match_balance_vix_3',
#  'index_std_wap',
#  'match_balance_diff_3',
#  'index_mean_wap',
#  'match_balance_vix_7',
#  'match_balance_diff_7',
#  'revealed_target_diff_7',
#  'index_mean_wap_vix_5',
#  'revealed_target_vix_7',
#  'index_mean_wap_vix_3',
#  'wap_diff_7',
#  'index_std_wap_diff_1',
#  'index_mean_wap_vix_7',
#  'index_mean_match_balance_vix_3',
#  'index_mean_match_balance_vix_5',
#  'index_mean_match_balance',
#  'revealed_target_diff_1',
#  'index_mean_match_balance_diff_1',
#  'index_mean_match_balance_diff_7',
#  'index_std_match_balance_diff_1',
#  'match_balance_diff_1',
#  'index_mean_wap_diff_1',
#  'index_mean_match_balance_diff_3',
#  'revealed_target_vix_3',
#  'index_std_match_balance_diff_7',
#  'match_balance_vix_5',
#  'wap_vix_5',
#  'index_std_wap_vix_3',
#  'index_mean_match_balance_vix_7',
#  'n_reference_price',
#  'n_wap',
#  'n_match_balance']

# %%
pd_display_max()
nan_count = df_train[features].isna().sum()
#df_train[features].to_csv('train.csv', index=False)
nan_count = nan_count[nan_count > 0].sort_values(ascending=False)
nan_count
# Out:
# revealed_target_vix_7                       48584
# revealed_target_vix_5                       45416
# revealed_target_vix_3                       40665
# far_price                                   29188
# far_price_bid_price_imb                     29188
# far_price_near_price_imb                    29188
# far_price_ask_price_imb                     29188
# far_price_wap_imb                           29188
# reference_price_far_price_imb               29188
# depth_pressure                              29188
# near_price_ask_price_imb                    28860
# reference_price_near_price_imb              28860
# near_price                                  28860
# near_price_wap_imb                          28860
# near_price_bid_price_imb                    28860
# imbalance_size_ret_1                        12851
# imbalance_buy_sell_flag_ret_1               12851
# index_std_match_balance_vix_7               12530
# imbalance_buy_sell_flag_ret_2               12108
# imbalance_size_ret_2                        12108
# imbalance_buy_sell_flag_ret_3               11477
# imbalance_size_ret_3                        11477
# index_std_match_balance_vix_5               10280
# imbalance_buy_sell_flag_ret_10               8208
# imbalance_size_ret_10                        8208
# index_std_match_balance_vix_3                7952
# match_balance_vix_7                          7944
# index_std_wap_vix_7                          7736
# index_mean_match_balance_vix_7               7586
# wap_vix_7                                    6734
# index_mean_wap_vix_7                         6734
# match_balance_vix_5                          5978
# index_std_wap_vix_5                          5804
# index_mean_match_balance_vix_5               5644
# wap_vix_5                                    4810
# index_mean_wap_vix_5                         4810
# bid_price_wap_reference_price_imb2           4803
# ask_price_bid_price_reference_price_imb2     4684
# match_balance_vix_3                          4009
# index_std_wap_vix_3                          3872
# index_mean_match_balance_vix_3               3700
# index_mean_wap_vix_3                         2886
# wap_vix_3                                    2886
# revealed_target_diff_7                       1936
# revealed_target_diff_3                       1928
# revealed_target_diff_1                       1924
# ask_price_wap_reference_price_imb2             80
# ask_price_bid_price_wap_imb2                   45
# reference_price_ret_10                         20
# matched_size_shift_10                          20
# imbalance_size_shift_10                        20
# bid_size_diff_10                               20
# ask_price_diff_10                              20
# ask_size_diff_10                               20
# bid_price_diff_10                              20
# reference_price_shift_10                       20
# imbalance_buy_sell_flag_shift_10               20
# matched_size_ret_10                            20
# index_std_wap_diff_7                           14
# wap_diff_7                                     14
# index_mean_wap_diff_7                          14
# index_mean_match_balance_diff_7                14
# match_balance_diff_7                           14
# index_std_match_balance_diff_7                 14
# match_balance_diff_3                            6
# wap_diff_3                                      6
# bid_size_diff_3                                 6
# index_mean_wap_diff_3                           6
# index_std_match_balance_diff_3                  6
# index_mean_match_balance_diff_3                 6
# index_std_wap_diff_3                            6
# ask_size_diff_3                                 6
# reference_price_ret_3                           6
# matched_size_ret_3                              6
# imbalance_buy_sell_flag_shift_3                 6
# bid_price_diff_3                                6
# reference_price_shift_3                         6
# ask_price_diff_3                                6
# imbalance_size_shift_3                          6
# matched_size_shift_3                            6
# ask_size_diff_2                                 4
# imbalance_buy_sell_flag_shift_2                 4
# matched_size_shift_2                            4
# reference_price_shift_2                         4
# bid_size_diff_2                                 4
# bid_price_diff_2                                4
# matched_size_ret_2                              4
# imbalance_size_shift_2                          4
# reference_price_ret_2                           4
# ask_price_diff_2                                4
# wap_diff_1                                      2
# index_std_match_balance_diff_1                  2
# match_balance_diff_1                            2
# index_mean_wap_diff_1                           2
# index_mean_match_balance_diff_1                 2
# bid_price_diff_1                                2
# matched_size_ret_1                              2
# index_std_wap_diff_1                            2
# imbalance_buy_sell_flag_shift_1                 2
# reference_price_ret_1                           2
# ask_size_diff_1                                 2
# ask_price_diff_1                                2
# matched_size_shift_1                            2
# spread_intensity                                2
# bid_size_diff_1                                 2
# imbalance_size_shift_1                          2
# reference_price_shift_1                         2
# imbalance_momentum                              2
# dtype: int64

# %%
pd_clear_display_max()

# %% [markdown]
# # PCA

# %%
"""
# %%time

import numpy as np
from sklearn.decomposition import PCA
from fancyimpute import KNN, NuclearNormMinimization, SoftImpute, BiScaler


# For Probabilistic PCA

knn = KNN(k=3)
#imputed = knn.fit_transform(df_train)
#imputed = NuclearNormMinimization().fit_transform(df_train)
#imputed = SoftImpute().fit_transform(df_train)
imputed = (df_train.groupby('stock_id', group_keys=False).transform(lambda col:
                             SoftImpute().fit_transform(col.to_frame()).flatten(),
                         ))

df_imputed = pd.DataFrame(imputed, columns=df_train.columns)

pca = PCA()
pca.fit(df_imputed)

explained_variance = pca.explained_variance_ratio_ # 各主成分の寄与率
cumulative_variance = np.cumsum(explained_variance) # 累積寄与率の計算


df_pca_result = pd.DataFrame({
    'Principal Component': np.arange(1, len(explained_variance) + 1),
    'Explained Variance': explained_variance,
    'Cumulative Variance': cumulative_variance
})

df_pca_result
"""
#df_imputed
# Out:
# "\n%%time\n\nimport numpy as np\nfrom sklearn.decomposition import PCA\nfrom fancyimpute import KNN, NuclearNormMinimization, SoftImpute, BiScaler\n\n\n# For Probabilistic PCA\n\nknn = KNN(k=3)\n#imputed = knn.fit_transform(df_train)\n#imputed = NuclearNormMinimization().fit_transform(df_train)\n#imputed = SoftImpute().fit_transform(df_train)\nimputed = (df_train.groupby('stock_id', group_keys=False).transform(lambda col:\n                             SoftImpute().fit_transform(col.to_frame()).flatten(),\n                         ))\n\ndf_imputed = pd.DataFrame(imputed, columns=df_train.columns)\n\npca = PCA()\npca.fit(df_imputed)\n\nexplained_variance = pca.explained_variance_ratio_ # 各主成分の寄与率\ncumulative_variance = np.cumsum(explained_variance) # 累積寄与率の計算\n\n\ndf_pca_result = pd.DataFrame({\n    'Principal Component': np.arange(1, len(explained_variance) + 1),\n    'Explained Variance': explained_variance,\n    'Cumulative Variance': cumulative_variance\n})\n\ndf_pca_result\n"

# %% [markdown]
# # Model Training

# %%
# 📦 Import necessary libraries
import numpy as np
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error
import gc
import os
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
import numpy as np
from dataclasses import dataclass
import sys
import shutil
import lightgbm as lgb

from warnings import simplefilter
simplefilter("ignore", category=RuntimeWarning)

@dataclass
class Model:
    booster: lgb.Booster
    fold: int
    feature_importance: pd.DataFrame
    score: float
    best_iteration: int
    train_time: float = None
    weight: float = None
    mem_usage: float = None
    train_func: str = None

def train_model(train_x, train_y, val_x, val_y, best_params=None):
    print("------ Model training start ------")
    trains = lgb.Dataset(train_x, train_y)
    valids = lgb.Dataset(val_x, val_y, reference=trains)

    verbose_eval = 0
    if best_params is None:
        params = lgb_params
    else:
        params = best_params

    print("Use params:")
    print(params)

    booster = lgb.train(
        params,
        trains,
        valid_sets=[valids, trains], # 検証データ
        valid_names=['Train', 'Valid'],    # データセット名前
        num_boost_round=num_boost_round,
        callbacks=[
                lgb.early_stopping(stopping_rounds=stopping_rounds, verbose=True),
                lgb.log_evaluation(verbose_eval)
        ]
    )

    print("------ Model training end ------")
    return booster

def cross_train(df, key, n_splits, features, valid_name, best_params=None):
    """ For Cross Train

    Args:
        df (_type_): _description_
        n_splits (_type_): _description_

    Returns:
        _type_: _description_
    """
    print("----------------------------------------")
    print(f"Cross Train key id {key}: start, shape: {df_train.shape}, n_splits: {n_splits}")
    print(f"num_boost_round: {num_boost_round}, stopping_rounds: {stopping_rounds}, folds: {num_folds}")

    models = []
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    df.reset_index(drop=True, inplace=True)
    
    for fold, (train_indices, valid_indices) in enumerate(kf.split(df)):
        print(f"{key}: {fold} start")
        now_time = time.time()
        X_train, X_valid = df[features].iloc[train_indices], df[features].iloc[valid_indices]
        y_train, y_valid = df[valid_name].loc[train_indices], df[valid_name].loc[valid_indices]
        print(f"X_train: {X_train.shape}, X_valid: {X_valid.shape}, y_train: {y_train.shape}, y_valid: {y_valid.shape}")


        booster = train_model(X_train, y_train, X_valid, y_valid, best_params)

        y_valid_pred = booster.predict(X_valid)
        
        score = mean_absolute_error(y_valid, y_valid_pred)
        train_time = time.time() - now_time
        mem_usage = sys.getsizeof(booster) / (1024 * 1024) # MB
        model = Model(booster, fold, booster.feature_importance(), score, booster.best_iteration, train_time, weight= 1 / n_splits, mem_usage=mem_usage, train_func="lightgbm")
        print(f"{key}: {fold} end, score: {score}, time: {model.train_time}, best_iteration: {model.best_iteration}, memory usage: {model.mem_usage}")
        
        models.append(model)
        
        del X_train, X_valid, y_train, y_valid
        gc.collect()

    print(f"Cross train {key} model len {len(models)}")
    print("----------------------------------------")
    return key, models

# %% [markdown]
# # Optuna tuner

# %%
# %%time

import optuna.integration.lightgbm as optuna_lgb
import optuna
import lightgbm
optuna.logging.set_verbosity(optuna.logging.ERROR)

class TunerCVCheckpointCallback(object):
    """Optuna の LightGBMTunerCV から学習済みモデルを取り出すためのコールバック"""

    def __init__(self):
        # Models
        self.models = []
        self.counter = 0

    def get_models(self):
        # https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.Booster.html#lightgbm.Booster
        return self.models

    def __call__(self, env: lightgbm.callback.CallbackEnv):
        """_summary_

        Args:
            env (lightgbm.callback.CallbackEnv): _description_
            "model",
            "params",
            "iteration",
            "begin_iteration",
            "end_iteration",
            "evaluation_result_list"
        """
        print("")

        self.counter += 1
        print("-------------------")
        print(f"Counter: {self.counter}")
        print(f"Iteration: {env.iteration}")
        print(f"Begin_iteration: {env.begin_iteration}")
        print(f"End_iteration: {env.end_iteration}")
        print(f"Evaluation_result_list: {env.evaluation_result_list}")
        print(f"Model best_iteration: {env.model.best_iteration}")
        print("Params: ", env.params)
        #self.models.append(env.model)
        del env

        collect();
        print(GetMemUsage())

def optuna_tuning(df, n_splits, features, valid_name, model_save_path):
    df_train = df[features]
    df_valid = df[valid_name]
    
    trains = optuna_lgb.Dataset(df_train, df_valid)
    
    print("------- Optuna Tuning Start -------")
    now_time = time.time()
    print(f"num_boost_round: {num_boost_round}, stopping_rounds: {stopping_rounds}, folds: {num_folds}")

    folds = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    checkpoint_cb = TunerCVCheckpointCallback()
    
    verbose_eval = 0
    # https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.lightgbm.LightGBMTunerCV.html
    tuner = optuna_lgb.LightGBMTunerCV(
        optuna_params,
        trains,
        num_boost_round=num_boost_round,
        folds=folds,
        show_progress_bar=False,
        return_cvbooster=True,
        verbosity=-1,
        model_dir=model_save_path,
        optuna_seed=seed,
        time_budget=OPTUNA_TIME_BUDGET,
        callbacks=[
                lgb.early_stopping(stopping_rounds=stopping_rounds, verbose=True),
                lgb.log_evaluation(verbose_eval),
                checkpoint_cb
        ]
    )
    
    tuner.run()
    best_params = tuner.best_params
    
    print("Params: ")
    for key, value in best_params.items():
        print(" {}: {}".format(key, value))

    print("")
    print("len(tuner.study.trials): ", len(tuner.study.trials))
    #print("len(checkpoint_cb.cv_boosters): ", len(checkpoint_cb.models))
    print("Tuner best_params", tuner.best_params)
    print("Tuner best score: ", tuner.best_score)
   
    # 最も良かったパラメータをキーにして学習済みモデルを取り出す
    best_booster = tuner.get_best_booster()
    score = -1
    train_time = time.time() - now_time
    mem_usage = sys.getsizeof(best_booster) / (1024 * 1024) # MB
    feature_importance = np.mean(best_booster.feature_importance(), axis=0)

    best_model = Model(best_booster, 1, feature_importance, score, best_booster.best_iteration, train_time, weight= 1, mem_usage=mem_usage, train_func="optuna_lgb")
    print("------- Optuna Tuning End -------")
    return best_params, best_model
# Out:
# CPU times: user 241 µs, sys: 304 µs, total: 545 µs
# Wall time: 913 µs

# %%
# %%time

KEY = "-1"

# Train
best_params = None
key_models = None
if USE_OPTUNA:
    model_save_base_path = f"{BASE_OUTPUT_PATH}/model"
    if os.path.exists(model_save_base_path):
        print(f"{model_save_base_path} already exists, clean up it.")
        shutil.rmtree(model_save_base_path)
    os.makedirs(model_save_base_path)
    print(f"model_save_base_path: {model_save_base_path}")

    best_params, best_model = optuna_tuning(df=df_train, n_splits=num_folds, features=features, valid_name="target", model_save_path=model_save_base_path)
    key_models = [(KEY, [best_model])]
else:
    #key_models = df_train.groupby("seconds_in_bucket").apply(lambda x: cross_train(df=x, key=x.name, n_splits=num_folds, feature_name=feature_name, valid_name="target", best_params=best_params))
    key_models = [cross_train(df_train, key=KEY, n_splits=num_folds, features=features, valid_name="target", best_params=best_params)]
    if IS_USE_SAVED_MODEL:
        model_save_base_path = f"{BASE_OUTPUT_PATH}/model"
        if os.path.exists(model_save_base_path):
            print(f"{model_save_base_path} already exists, clean up it.")
            shutil.rmtree(model_save_base_path)
        os.makedirs(model_save_base_path)

        key_model_paths = []
        for key, models in key_models:
            model_save_path = f"{model_save_base_path}/{key}"
            os.makedirs(model_save_path)
            model_paths = []
            for model in models:
                model_save_fullpath = f"{model_save_path}/model_{key}_{model.fold}.txt"
                model.model.save_model(model_save_fullpath)
                model_paths.append(model_save_fullpath)
            key_model_paths.append((key, model_paths))

        model_dict_saved = {key: model_paths for key, model_paths in key_model_paths}
        print(model_dict_saved)


model_dict = {key: model for key, model in key_models}

#del df_train, df_valid
collect()
print(GetMemUsage())
# Out:
# ../output/model already exists, clean up it.
# model_save_base_path: ../output/model
# ------- Optuna Tuning Start -------
# num_boost_round: 1, stopping_rounds: 1, folds: 8
#
# -------------------
# Counter: 1
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.902366253805596, False, 0.1475294423142797)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 31, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 1.839
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.90237 + 0.147529
#
# -------------------
# Counter: 2
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 9.018636952158314, False, 0.1476387582998922)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 31, 'feature_fraction': 0.6, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.201
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 9.01864 + 0.147639
#
# -------------------
# Counter: 3
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 9.02162987416711, False, 0.14780031540450214)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 31, 'feature_fraction': 0.4, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.288
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 9.02163 + 0.1478
#
# -------------------
# Counter: 4
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.91233186798823, False, 0.14387051475335438)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 31, 'feature_fraction': 0.7, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.307
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.91233 + 0.143871
#
# -------------------
# Counter: 5
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.912940758824158, False, 0.14389822709233965)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 31, 'feature_fraction': 0.8, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.335
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.91294 + 0.143898
#
# -------------------
# Counter: 6
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.902403334894748, False, 0.1475028071846814)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 31, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.33
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.9024 + 0.147503
#
# -------------------
# Counter: 7
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 9.018636952158314, False, 0.1476387582998922)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 31, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.29
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 9.01864 + 0.147639
#
# -------------------
# Counter: 8
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.861809152884339, False, 0.14725631682561105)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 84, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.31
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.86181 + 0.147256
#
# -------------------
# Counter: 9
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.833739578319976, False, 0.1464952659606883)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 229, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.7
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83374 + 0.146495
#
# -------------------
# Counter: 10
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.843815275488796, False, 0.14570861581671898)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 151, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.848
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.84382 + 0.145709
#
# -------------------
# Counter: 11
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.831158426565318, False, 0.14640621701666032)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 252, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.861
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83116 + 0.146406
#
# -------------------
# Counter: 12
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.831912903945367, False, 0.1466830108104183)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 245, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.88
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83191 + 0.146683
#
# -------------------
# Counter: 13
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.83084653404494, False, 0.14641815860895757)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.775
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83085 + 0.146418
#
# -------------------
# Counter: 14
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.831094215430857, False, 0.1464159679139416)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 249, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.796
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83109 + 0.146416
#
# -------------------
# Counter: 15
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.840958727213149, False, 0.14578550967332823)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 170, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.794
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.84096 + 0.145786
#
# -------------------
# Counter: 16
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.969810565263328, False, 0.1484399723228069)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 10, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.761
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.96981 + 0.14844
#
# -------------------
# Counter: 17
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.837058221772061, False, 0.14650091819401187)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 195, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.687
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83706 + 0.146501
#
# -------------------
# Counter: 18
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.85726374939889, False, 0.1469026666593696)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 93, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.541
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.85726 + 0.146903
#
# -------------------
# Counter: 19
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.836704752417393, False, 0.14660507275687906)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 201, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.35
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.8367 + 0.146605
#
# -------------------
# Counter: 20
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.836140889489348, False, 0.1466811133648557)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 206, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.252
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83614 + 0.146681
#
# -------------------
# Counter: 21
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.85176571772913, False, 0.14616827545303362)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 112, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.207
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.85177 + 0.146168
#
# -------------------
# Counter: 22
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.830855494284013, False, 0.14644552687122062)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 256, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.021
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83086 + 0.146446
#
# -------------------
# Counter: 23
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.831169595629216, False, 0.14637239598363241)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 250, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 1.994
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83117 + 0.146372
#
# -------------------
# Counter: 24
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.83514847960328, False, 0.14620897176305667)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 216, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.035
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83515 + 0.146209
#
# -------------------
# Counter: 25
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.830849473580276, False, 0.14633521239932518)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 255, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.095
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83085 + 0.146335
#
# -------------------
# Counter: 26
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.840101343882985, False, 0.14604940550523451)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 174, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.035
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.8401 + 0.146049
#
# -------------------
# Counter: 27
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.834356233478598, False, 0.14665265627261526)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 222, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 1.994
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83436 + 0.146653
#
# -------------------
# Counter: 28
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.837609551976602, False, 0.1503056661600612)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.5151610320217106, 'bagging_freq': 3, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.186
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83761 + 0.150306
#
# -------------------
# Counter: 29
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.83243828727251, False, 0.14795252241558118)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.9942447669177362, 'bagging_freq': 7, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.229
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83244 + 0.147953
#
# -------------------
# Counter: 30
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.838607586565438, False, 0.14934546644374863)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.41826254549889225, 'bagging_freq': 1, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.203
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83861 + 0.149345
#
# -------------------
# Counter: 31
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.839384951023984, False, 0.14903939516699136)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.7845857578255675, 'bagging_freq': 7, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.174
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83938 + 0.149039
#
# -------------------
# Counter: 32
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.839802152350373, False, 0.14779371363124466)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.6547308341709986, 'bagging_freq': 4, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.06
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.8398 + 0.147794
#
# -------------------
# Counter: 33
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.834420316344492, False, 0.14744727876537722)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.9771076003051028, 'bagging_freq': 1, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.012
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83442 + 0.147447
#
# -------------------
# Counter: 34
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.837524410923104, False, 0.1492498662563897)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.7641282139749592, 'bagging_freq': 5, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.052
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83752 + 0.14925
#
# -------------------
# Counter: 35
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.840006418787645, False, 0.14746055075591813)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.6031875168583338, 'bagging_freq': 3, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.047
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.84001 + 0.147461
#
# -------------------
# Counter: 36
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.83624070028241, False, 0.1471695248072851)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.8568228613145026, 'bagging_freq': 5, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.04
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83624 + 0.14717
#
# -------------------
# Counter: 37
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.840991800338866, False, 0.14909882163860835)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 0.4221493489218008, 'bagging_freq': 2, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.016
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.84099 + 0.149099
#
# -------------------
# Counter: 38
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.868756537968462, False, 0.14178228824396472)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.852, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.042
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.86876 + 0.141782
#
# -------------------
# Counter: 39
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.832975061656299, False, 0.14679522038742918)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.948, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 1.963
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.83298 + 0.146795
#
# -------------------
# Counter: 40
# Iteration: 0
# Begin_iteration: 0
# End_iteration: 1
# Evaluation_result_list: [('cv_agg', 'valid rmse', 8.869360851723222, False, 0.14194396334379628)]
# Model best_iteration: -1
# Params:  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.82, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1}
# RAM memory GB usage = 2.015
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's valid rmse: 8.86936 + 0.141944
# Params:
#  boosting_type: gbdt
#  objective: regression
#  metric: rmse
#  verbosity: -1
#  deterministic: True
#  force_row_wise: True
#  device: cpu
#  feature_pre_filter: False
#  lambda_l1: 0.0
#  lambda_l2: 0.0
#  num_leaves: 254
#  feature_fraction: 0.8999999999999999
#  bagging_fraction: 1.0
#  bagging_freq: 0
#  min_child_samples: 20
#
# len(tuner.study.trials):  40
# Tuner best_params {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'deterministic': True, 'force_row_wise': True, 'device': 'cpu', 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 254, 'feature_fraction': 0.8999999999999999, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20}
# Tuner best score:  8.83084653404494
# ------- Optuna Tuning End -------
# RAM memory GB usage = 2.0
# CPU times: user 2min 27s, sys: 27.4 s, total: 2min 54s
# Wall time: 1min 1s

# %%
# Show results
print("")
print(f"Total model len {(sum([len(models) for key, models in key_models]))}")
print(f"Total model mem usage {sum([sum([model.mem_usage for model in models]) for key, models in key_models]):2f} MB")
print(f"Model dict len {len(model_dict)}")
# Out:
# Total model len 1
# Total model mem usage 0.000053 MB
# Model dict len 1

# %%
# Check model quality
data = []

for key, i_models in model_dict.items():
    for model in i_models:
        score = model.score
        best_iteration = model.best_iteration
        fold = model.fold
        train_time = model.train_time
        data.append({"key": key, "fold": fold, "score": score, "best_iteration": best_iteration, "train_time": train_time})

df_model = pd.DataFrame(data)
df_model.describe()
# Out:
#        fold  score  best_iteration  train_time
# count   1.0    1.0             1.0    1.000000
# mean    1.0   -1.0             1.0   61.316679
# std     NaN    NaN             NaN         NaN
# min     1.0   -1.0             1.0   61.316679
# 25%     1.0   -1.0             1.0   61.316679
# 50%     1.0   -1.0             1.0   61.316679
# 75%     1.0   -1.0             1.0   61.316679
# max     1.0   -1.0             1.0   61.316679

# %%
# Initialize an empty DataFrame for aggregated importances
aggregated_importance = pd.DataFrame(index=features, columns=['importance'])

# Aggregate the importances from each model
for key, i_models in model_dict.items():
    for model in i_models:
        importance = pd.DataFrame({'feature': features, 'importance': model.feature_importance})
        aggregated_importance = aggregated_importance.add(importance.set_index('feature'), fill_value=0)

aggregated_importance['importance'] /= len(df_model)

pd_display_max()
# Sort the features by importance
aggregated_importance = aggregated_importance.sort_values(by='importance', ascending=False)
aggregated_importance
# Out:
#                                           importance
# wap_diff_1                                      41.0
# revealed_target_diff_3                        30.125
# revealed_target_diff_7                        22.375
# revealed_target_diff_1                          16.5
# market_urgency                                12.125
# wap_diff_7                                    11.875
# revealed_target_vix_3                         10.625
# wap_vix_5                                       10.5
# bid_price_diff_10                              5.875
# ask_price_diff_10                                5.0
# reference_price_wap_imb                        4.375
# ask_price_wap_imb                              4.125
# wap_vix_3                                        3.5
# bid_price_wap_imb                                3.0
# revealed_target_vix_7                            3.0
# index_mean_wap_diff_1                            2.5
# index_std_wap_diff_1                           2.375
# price_spread                                    2.25
# ask_price_diff_2                               1.875
# size_imbalance                                 1.875
# bid_size_diff_1                                1.875
# reference_price_bid_price_imb                    1.5
# index_mean_wap_vix_5                             1.5
# bid_size                                         1.5
# index_std_wap_vix_3                              1.5
# reference_price_ret_1                          1.375
# index_mean_wap_vix_7                            1.25
# index_std_match_balance_vix_5                   1.25
# reference_price_ask_price_imb                   1.25
# bid_size_diff_10                                1.25
# index_std_match_balance_vix_3                   1.25
# match_balance_vix_5                             1.25
# spread_intensity                               1.125
# matched_size_ret_10                            1.125
# ask_size_diff_1                                1.125
# wap_diff_3                                     1.125
# ask_price_diff_1                                 1.0
# index_mean_match_balance_diff_1                  1.0
# index_mean_match_balance_vix_3                   1.0
# imbalance_size_ret_2                             1.0
# reference_price_ret_3                          0.875
# all_prices_skew                                0.875
# index_mean_match_balance_diff_7                0.875
# all_sizes_std                                   0.75
# bid_price_diff_2                                0.75
# seconds_in_bucket                               0.75
# ask_price_diff_3                                0.75
# match_balance_diff_7                            0.75
# matched_size_ret_1                              0.75
# reference_price_shift_10                        0.75
# index_mean_match_balance_vix_5                  0.75
# index_mean_wap                                 0.625
# ask_size_diff_3                                0.625
# ask_price_bid_price_wap_imb2                   0.625
# all_prices_kurt                                0.625
# index_std_wap_vix_5                            0.625
# index_std_wap_vix_7                            0.625
# imbalance_size_shift_3                         0.625
# bid_size_diff_3                                0.625
# revealed_target_vix_5                          0.625
# all_sizes_mean                                 0.625
# imbalance_size_shift_1                         0.625
# index_std_match_balance_diff_1                 0.625
# imbalance_size_ret_3                           0.625
# imbalance_size_shift_2                         0.625
# ask_size                                         0.5
# bid_price                                        0.5
# reference_price_shift_1                          0.5
# index_mean_match_balance_diff_3                  0.5
# matched_size_ret_2                               0.5
# matched_size_bid_size_ask_size_imb2              0.5
# bid_size_diff_2                                  0.5
# ask_price_wap_reference_price_imb2               0.5
# matched_size_shift_3                             0.5
# ask_size_diff_10                                 0.5
# volume                                           0.5
# far_price_bid_price_imb                        0.375
# all_prices_mean                                0.375
# bid_size_ask_size_imbalance_size_imb2          0.375
# index_mean_wap_vix_3                           0.375
# index_mean_match_balance                       0.375
# match_balance                                  0.375
# ask_price                                      0.375
# reference_price_shift_2                        0.375
# bid_price_diff_3                               0.375
# index_mean_wap_diff_3                          0.375
# matched_size_ret_3                             0.375
# ask_price_bid_price_imb                        0.375
# index_std_wap                                  0.375
# match_balance_diff_3                           0.375
# imbalance_size_ret_10                          0.375
# index_std_match_balance                        0.375
# near_price                                      0.25
# matched_size_shift_10                           0.25
# reference_price_shift_3                         0.25
# imbalance_size_shift_10                         0.25
# near_price_ask_price_imb                        0.25
# index_std_wap_diff_3                            0.25
# index_std_match_balance_diff_3                  0.25
# index_mean_match_balance_vix_7                  0.25
# matched_size_shift_2                            0.25
# index_std_match_balance_diff_7                 0.125
# match_balance_diff_1                           0.125
# match_balance_vix_3                            0.125
# stock_id                                       0.125
# price_pressure                                 0.125
# matched_size_bid_size_imbalance_size_imb2      0.125
# imbalance_size                                 0.125
# matched_size_ask_size_imbalance_size_imb2      0.125
# reference_price                                0.125
# depth_pressure                                 0.125
# matched_imbalance                              0.125
# bid_price_diff_1                               0.125
# imbalance_momentum                             0.125
# liquidity_imbalance                            0.125
# imbalance_size_ret_1                             0.0
# imbalance_buy_sell_flag_shift_2                  0.0
# bid_price_wap_reference_price_imb2               0.0
# imbalance_buy_sell_flag_ret_2                    0.0
# reference_price_near_price_imb                   0.0
# ask_size_diff_2                                  0.0
# near_price_wap_imb                               0.0
# imbalance_buy_sell_flag_shift_1                  0.0
# wap                                              0.0
# far_price                                        0.0
# matched_size                                     0.0
# imbalance_buy_sell_flag                          0.0
# n_reference_price                                0.0
# n_wap                                            0.0
# imbalance_buy_sell_flag_shift_10                 0.0
# reference_price_far_price_imb                    0.0
# near_price_bid_price_imb                         0.0
# mid_price                                        0.0
# all_prices_std                                   0.0
# reference_price_ret_10                           0.0
# far_price_near_price_imb                         0.0
# all_sizes_skew                                   0.0
# index_std_match_balance_vix_7                    0.0
# index_mean_wap_diff_7                            0.0
# matched_size_shift_1                             0.0
# ask_price_bid_price_reference_price_imb2         0.0
# imbalance_buy_sell_flag_shift_3                  0.0
# index_std_wap_diff_7                             0.0
# imbalance_buy_sell_flag_ret_10                   0.0
# wap_vix_7                                        0.0
# reference_price_ret_2                            0.0
# all_sizes_kurt                                   0.0
# far_price_ask_price_imb                          0.0
# imbalance_buy_sell_flag_ret_1                    0.0
# match_balance_vix_7                              0.0
# far_price_wap_imb                                0.0
# imbalance_buy_sell_flag_ret_3                    0.0
# n_match_balance                                  0.0

# %%
# Clean up
pd_clear_display_max()
del key_models
if IS_USE_SAVED_MODEL:
    print("Delete model_dict")
    del model_dict
collect()
print(GetMemUsage())
# Out:
# RAM memory GB usage = 1.955

# %% [markdown]
# # Infer

# %%
# %%time

# 📉 Define a function to adjust prices based on volumes
def zero_sum(prices, volumes):
    std_error = np.sqrt(volumes)  # 🧮 Calculate standard error based on volumes
    step = np.sum(prices) / np.sum(std_error)  # 🧮 Calculate the step size based on prices and standard error
    out = prices - std_error * step  # 💰 Adjust prices by subtracting the standardized step size
    return out

def zero_clip(df, predictions):
    # Adjust the predictions based on the order book imbalance
    zerosum_predictions = zero_sum(predictions, df['bid_size'] + df['ask_size'])
    clipped_predictions = np.clip(zerosum_predictions, y_min, y_max)
    clipped_predictions.replace([np.nan, np.inf, -np.inf], 0, inplace=True)
    clipped_predictions = clipped_predictions.astype('float64').values  
    return clipped_predictions

def predict_scaler(df):
    pred_mean = df['pred'].mean()
    pred_std = df['pred'].std()
    
    target_mean = global_target['mean']
    target_std = global_target['std']

    df['scaled_pred'] = (df['pred'] - pred_mean) / pred_std * target_std + target_mean
    return df

def model_infer(key, df_feat):
    def predictor(boosters):
        print(f"Predictor target models len {len(boosters)}")
        #print(f"Predictor Feat len {len(df_feat)}")
        if USE_OPTUNA:
            predictions_list = [np.mean(booster.predict(df_feat), 0) for booster in boosters]
        else:
            predictions_list = [booster.predict(df_feat) for booster in boosters]
        predictions = np.mean(predictions_list, 0)
        return predictions
    
    if IS_USE_SAVED_MODEL:
        model_paths = model_dict_saved[key]
        models = [lgb.Booster(model_file=model_path) for model_path in model_paths]
        predictions = predictor(models)
        del models
    else:
        boosters = [m.booster for m in model_dict[key]]
        predictions = predictor(boosters)
    collect()
    return predictions
# Out:
# CPU times: user 16 µs, sys: 1e+03 ns, total: 17 µs
# Wall time: 19.8 µs

# %%
# %%time

y_min, y_max = -64, 64
predictions = []
cache = pd.DataFrame()
df_result = pd.DataFrame()

counter = 0
df_revealed_targets = None

if IS_INFER:
    if IS_LOCAL:
        print("Infer Local")
        env = make_env()
    else:
        print("Infer Submission")
        import optiver2023
        env = optiver2023.make_env()
    iter_test = env.iter_test()

    for (test, revealed_targets, sample_prediction) in iter_test:
        now_time = time.time()
        print(f"------- counter {counter} start -------")

        # It faults due to test is iterator
        #seconds_in_bucket = test['seconds_in_bucket'][0]
        #print(f"prdict: {test['date_id'][0]}, {seconds_in_bucket}")
        
        # Generate cahce
        cache = pd.concat([cache, test], ignore_index=True, axis=0)
        cache = reduce_mem_usage(cache, 'cache')
        if counter > 0:
            # 🔄 If not the first iteration, limit the cache to the last 21 rows for each stock
            cache = cache.groupby(['stock_id']).tail(21).sort_values(by=['date_id', 'seconds_in_bucket', 'stock_id']).reset_index(drop=True)
            cache = cache.drop(['revealed_target'], axis=1)
        print(f"cache len {len(cache)}")

        # Add revealed target
        copy_revealed_targets = revealed_targets.copy()
        copy_revealed_targets = copy_revealed_targets.dropna()
        print("copy_revealed_targets len", len(copy_revealed_targets))


        if len(copy_revealed_targets) > 0:
            print("update revealed_targets")
            df_revealed_targets = copy_revealed_targets
            df_revealed_targets['date_id'] = df_revealed_targets['date_id'].astype(int).astype(str)
            df_revealed_targets['seconds_in_bucket'] = df_revealed_targets['seconds_in_bucket'].astype(str)
            df_revealed_targets['stock_id'] = df_revealed_targets['stock_id'].astype(int).astype(str)  # Converting to int first to remove any decimal points
            df_revealed_targets['row_id'] = df_revealed_targets['date_id'] + '_' + df_revealed_targets['seconds_in_bucket'] + '_' + df_revealed_targets['stock_id']
            df_revealed_targets = df_revealed_targets[['row_id', 'revealed_target']]

        cache = pd.merge(cache, df_revealed_targets, how='left', on='row_id')
        cache['revealed_target'] = cache['revealed_target'].astype('float32')
        cache.reset_index(drop=True, inplace=True)

        # 📊 Generate features
        df_test = generate_basic_features(cache)
        df_test = generate_enhance_features(df_test)
        df_test = generate_normalized_features(df_test, False)
        df_test = df_test[-len(test):].reset_index(drop=True)

        # Select features
        df_feat = df_test[features]

        # Get seconds_in_bucket and date_id
        seconds_in_bucket = df_test['seconds_in_bucket'][0]
        date_id = df_test['date_id'][0]
        print(f"Predict: {date_id}, {seconds_in_bucket}")
        
        # Predict
        predictions = model_infer(KEY, df_feat)
        df_test['pred'] = predictions
        scaled_predictions = zero_clip(df_test, predictions)
        df_test['scaled_pred'] = scaled_predictions
        # For save
        df_result = pd.concat([df_result, df_test], ignore_index=True, axis=0)

        # Submit
        sample_prediction['target'] = scaled_predictions
        env.predict(sample_prediction)
        print(sample_prediction.head())
        
        # Clean up
        del df_feat, df_test, predictions, scaled_predictions
        collect()
        counter += 1

collect()
print(GetMemUsage())
df_result.to_csv(f"{BASE_OUTPUT_PATH}/result.csv", index=False)
# Out:
# Infer Local
# ------- counter 0 start -------
# Memory usage of cache is 0.02 MB
# Memory usage after optimization is: 0.01 MB
# Decreased by 55.96%
# cache len 200
# copy_revealed_targets len 11000
# update revealed_targets
# Memory usage of generate_basic_features is 0.09 MB
# Memory usage after optimization is: 0.08 MB
# Decreased by 13.10%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 0.13 MB
# Memory usage after optimization is: 0.12 MB
# Decreased by 12.13%
# generate_normalized_features
# Memory usage of generate_normalized_features is 0.12 MB
# Memory usage after optimization is: 0.12 MB
# Decreased by 0.00%
# Predict: 478, 0
# Predictor target models len 1
#    time_id   row_id    target
# 0    26290  478_0_0 -0.050862
# 1    26290  478_0_1 -0.104098
# 2    26290  478_0_2 -0.034336
# 3    26290  478_0_3 -0.073575
# 4    26290  478_0_4 -0.074152
# ------- counter 1 start -------
# Memory usage of cache is 0.18 MB
# Memory usage after optimization is: 0.14 MB
# Decreased by 22.40%
# cache len 400
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 0.19 MB
# Memory usage after optimization is: 0.16 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 0.26 MB
# Memory usage after optimization is: 0.23 MB
# Decreased by 12.13%
# generate_normalized_features
# Memory usage of generate_normalized_features is 0.24 MB
# Memory usage after optimization is: 0.24 MB
# Decreased by 0.00%
# Predict: 478, 10
# Predictor target models len 1
#    time_id    row_id    target
# 0    26291  478_10_0 -0.032456
# 1    26291  478_10_1 -0.062698
# 2    26291  478_10_2  0.005129
# 3    26291  478_10_3 -0.060385
# 4    26291  478_10_4  0.001280
# ------- counter 2 start -------
# Memory usage of cache is 0.27 MB
# Memory usage after optimization is: 0.21 MB
# Decreased by 22.40%
# cache len 600
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 0.28 MB
# Memory usage after optimization is: 0.24 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 0.40 MB
# Memory usage after optimization is: 0.35 MB
# Decreased by 12.13%
# generate_normalized_features
# Memory usage of generate_normalized_features is 0.35 MB
# Memory usage after optimization is: 0.35 MB
# Decreased by 0.00%
# Predict: 478, 20
# Predictor target models len 1
#    time_id    row_id    target
# 0    26292  478_20_0  0.008642
# 1    26292  478_20_1 -0.029348
# 2    26292  478_20_2 -0.043870
# 3    26292  478_20_3  0.043146
# 4    26292  478_20_4 -0.028095
# ------- counter 3 start -------
# Memory usage of cache is 0.35 MB
# Memory usage after optimization is: 0.27 MB
# Decreased by 22.41%
# cache len 800
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 0.37 MB
# Memory usage after optimization is: 0.32 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 0.53 MB
# Memory usage after optimization is: 0.46 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 0.47 MB
# Memory usage after optimization is: 0.47 MB
# Decreased by 0.00%
# Predict: 478, 30
# Predictor target models len 1
#    time_id    row_id    target
# 0    26293  478_30_0 -0.638057
# 1    26293  478_30_1  0.073747
# 2    26293  478_30_2 -0.427316
# 3    26293  478_30_3  0.121869
# 4    26293  478_30_4 -0.448669
# ------- counter 4 start -------
# Memory usage of cache is 0.44 MB
# Memory usage after optimization is: 0.34 MB
# Decreased by 22.41%
# cache len 1000
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 0.47 MB
# Memory usage after optimization is: 0.40 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 0.66 MB
# Memory usage after optimization is: 0.58 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 0.59 MB
# Memory usage after optimization is: 0.59 MB
# Decreased by 0.00%
# Predict: 478, 40
# Predictor target models len 1
#    time_id    row_id    target
# 0    26294  478_40_0 -0.162778
# 1    26294  478_40_1  0.088751
# 2    26294  478_40_2  0.335369
# 3    26294  478_40_3  0.231124
# 4    26294  478_40_4 -0.322194
# ------- counter 5 start -------
# Memory usage of cache is 0.53 MB
# Memory usage after optimization is: 0.41 MB
# Decreased by 22.41%
# cache len 1200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 0.56 MB
# Memory usage after optimization is: 0.49 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 0.79 MB
# Memory usage after optimization is: 0.70 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 0.71 MB
# Memory usage after optimization is: 0.71 MB
# Decreased by 0.00%
# Predict: 478, 50
# Predictor target models len 1
#    time_id    row_id    target
# 0    26295  478_50_0 -0.125064
# 1    26295  478_50_1 -0.218647
# 2    26295  478_50_2  0.407689
# 3    26295  478_50_3 -0.193547
# 4    26295  478_50_4 -0.141676
# ------- counter 6 start -------
# Memory usage of cache is 0.62 MB
# Memory usage after optimization is: 0.48 MB
# Decreased by 22.41%
# cache len 1400
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 0.65 MB
# Memory usage after optimization is: 0.57 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 0.92 MB
# Memory usage after optimization is: 0.81 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 0.83 MB
# Memory usage after optimization is: 0.83 MB
# Decreased by 0.00%
# Predict: 478, 60
# Predictor target models len 1
#    time_id    row_id    target
# 0    26296  478_60_0 -0.058752
# 1    26296  478_60_1  0.006946
# 2    26296  478_60_2  1.911805
# 3    26296  478_60_3 -0.109636
# 4    26296  478_60_4 -0.090666
# ------- counter 7 start -------
# Memory usage of cache is 0.71 MB
# Memory usage after optimization is: 0.55 MB
# Decreased by 22.41%
# cache len 1600
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 0.74 MB
# Memory usage after optimization is: 0.65 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 1.06 MB
# Memory usage after optimization is: 0.93 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 0.95 MB
# Memory usage after optimization is: 0.95 MB
# Decreased by 0.00%
# Predict: 478, 70
# Predictor target models len 1
#    time_id    row_id    target
# 0    26297  478_70_0  0.168886
# 1    26297  478_70_1  0.272780
# 2    26297  478_70_2  1.322025
# 3    26297  478_70_3 -0.255947
# 4    26297  478_70_4 -0.226123
# ------- counter 8 start -------
# Memory usage of cache is 0.80 MB
# Memory usage after optimization is: 0.62 MB
# Decreased by 22.41%
# cache len 1800
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 0.84 MB
# Memory usage after optimization is: 0.73 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 1.19 MB
# Memory usage after optimization is: 1.04 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 1.06 MB
# Memory usage after optimization is: 1.06 MB
# Decreased by 0.00%
# Predict: 478, 80
# Predictor target models len 1
#    time_id    row_id    target
# 0    26298  478_80_0  0.314323
# 1    26298  478_80_1 -0.108878
# 2    26298  478_80_2  1.090793
# 3    26298  478_80_3 -0.217866
# 4    26298  478_80_4  0.106376
# ------- counter 9 start -------
# Memory usage of cache is 0.89 MB
# Memory usage after optimization is: 0.69 MB
# Decreased by 22.41%
# cache len 2000
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 0.93 MB
# Memory usage after optimization is: 0.81 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 1.32 MB
# Memory usage after optimization is: 1.16 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 1.18 MB
# Memory usage after optimization is: 1.18 MB
# Decreased by 0.00%
# Predict: 478, 90
# Predictor target models len 1
#    time_id    row_id    target
# 0    26299  478_90_0  0.329687
# 1    26299  478_90_1  1.182058
# 2    26299  478_90_2  1.072595
# 3    26299  478_90_3 -0.034941
# 4    26299  478_90_4  0.142586
# ------- counter 10 start -------
# Memory usage of cache is 0.97 MB
# Memory usage after optimization is: 0.76 MB
# Decreased by 22.41%
# cache len 2200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.02 MB
# Memory usage after optimization is: 0.89 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 1.45 MB
# Memory usage after optimization is: 1.28 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 1.30 MB
# Memory usage after optimization is: 1.30 MB
# Decreased by 0.00%
# Predict: 478, 100
# Predictor target models len 1
#    time_id     row_id    target
# 0    26300  478_100_0  0.173951
# 1    26300  478_100_1 -0.486446
# 2    26300  478_100_2  1.200082
# 3    26300  478_100_3  0.044547
# 4    26300  478_100_4  0.152440
# ------- counter 11 start -------
# Memory usage of cache is 1.06 MB
# Memory usage after optimization is: 0.82 MB
# Decreased by 22.41%
# cache len 2400
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.12 MB
# Memory usage after optimization is: 0.97 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 1.58 MB
# Memory usage after optimization is: 1.39 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 1.42 MB
# Memory usage after optimization is: 1.42 MB
# Decreased by 0.00%
# Predict: 478, 110
# Predictor target models len 1
#    time_id     row_id    target
# 0    26301  478_110_0  0.106637
# 1    26301  478_110_1 -0.008272
# 2    26301  478_110_2  0.178266
# 3    26301  478_110_3 -0.137422
# 4    26301  478_110_4 -0.136495
# ------- counter 12 start -------
# Memory usage of cache is 1.15 MB
# Memory usage after optimization is: 0.89 MB
# Decreased by 22.41%
# cache len 2600
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.21 MB
# Memory usage after optimization is: 1.05 MB
# Decreased by 13.11%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 1.72 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 12.14%
# generate_normalized_features
# Memory usage of generate_normalized_features is 1.54 MB
# Memory usage after optimization is: 1.54 MB
# Decreased by 0.00%
# Predict: 478, 120
# Predictor target models len 1
#    time_id     row_id    target
# 0    26302  478_120_0 -0.104386
# 1    26302  478_120_1 -0.056982
# 2    26302  478_120_2 -0.673757
# 3    26302  478_120_3 -0.290649
# 4    26302  478_120_4 -0.270700
# ------- counter 13 start -------
# Memory usage of cache is 1.24 MB
# Memory usage after optimization is: 0.96 MB
# Decreased by 22.20%
# cache len 2800
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.31 MB
# Memory usage after optimization is: 1.13 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 1.85 MB
# Memory usage after optimization is: 1.63 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 1.66 MB
# Memory usage after optimization is: 1.66 MB
# Decreased by 0.00%
# Predict: 478, 130
# Predictor target models len 1
#    time_id     row_id    target
# 0    26303  478_130_0 -0.483614
# 1    26303  478_130_1 -0.331763
# 2    26303  478_130_2 -1.863902
# 3    26303  478_130_3 -0.217802
# 4    26303  478_130_4 -0.303946
# ------- counter 14 start -------
# Memory usage of cache is 1.33 MB
# Memory usage after optimization is: 1.03 MB
# Decreased by 22.20%
# cache len 3000
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.40 MB
# Memory usage after optimization is: 1.22 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 1.98 MB
# Memory usage after optimization is: 1.74 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 1.78 MB
# Memory usage after optimization is: 1.78 MB
# Decreased by 0.00%
# Predict: 478, 140
# Predictor target models len 1
#    time_id     row_id    target
# 0    26304  478_140_0 -0.344012
# 1    26304  478_140_1  0.927192
# 2    26304  478_140_2 -2.691909
# 3    26304  478_140_3 -0.287319
# 4    26304  478_140_4 -0.284118
# ------- counter 15 start -------
# Memory usage of cache is 1.42 MB
# Memory usage after optimization is: 1.10 MB
# Decreased by 22.20%
# cache len 3200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.49 MB
# Memory usage after optimization is: 1.30 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.11 MB
# Memory usage after optimization is: 1.86 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 1.90 MB
# Memory usage after optimization is: 1.90 MB
# Decreased by 0.00%
# Predict: 478, 150
# Predictor target models len 1
#    time_id     row_id    target
# 0    26305  478_150_0 -0.273115
# 1    26305  478_150_1  0.479929
# 2    26305  478_150_2 -1.425051
# 3    26305  478_150_3 -0.106731
# 4    26305  478_150_4 -0.361635
# ------- counter 16 start -------
# Memory usage of cache is 1.50 MB
# Memory usage after optimization is: 1.17 MB
# Decreased by 22.20%
# cache len 3400
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.59 MB
# Memory usage after optimization is: 1.38 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.25 MB
# Memory usage after optimization is: 1.97 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.01 MB
# Memory usage after optimization is: 2.01 MB
# Decreased by 0.00%
# Predict: 478, 160
# Predictor target models len 1
#    time_id     row_id    target
# 0    26306  478_160_0 -0.030729
# 1    26306  478_160_1 -0.124240
# 2    26306  478_160_2 -1.591158
# 3    26306  478_160_3  0.328235
# 4    26306  478_160_4 -0.581029
# ------- counter 17 start -------
# Memory usage of cache is 1.59 MB
# Memory usage after optimization is: 1.24 MB
# Decreased by 22.20%
# cache len 3600
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.68 MB
# Memory usage after optimization is: 1.46 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.38 MB
# Memory usage after optimization is: 2.09 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.13 MB
# Memory usage after optimization is: 2.13 MB
# Decreased by 0.00%
# Predict: 478, 170
# Predictor target models len 1
#    time_id     row_id    target
# 0    26307  478_170_0  0.094062
# 1    26307  478_170_1 -0.793659
# 2    26307  478_170_2 -0.870249
# 3    26307  478_170_3 -0.299179
# 4    26307  478_170_4 -0.272460
# ------- counter 18 start -------
# Memory usage of cache is 1.68 MB
# Memory usage after optimization is: 1.31 MB
# Decreased by 22.20%
# cache len 3800
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.77 MB
# Memory usage after optimization is: 1.54 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.51 MB
# Memory usage after optimization is: 2.21 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.25 MB
# Memory usage after optimization is: 2.25 MB
# Decreased by 0.00%
# Predict: 478, 180
# Predictor target models len 1
#    time_id     row_id    target
# 0    26308  478_180_0 -0.100515
# 1    26308  478_180_1 -0.367245
# 2    26308  478_180_2 -0.675294
# 3    26308  478_180_3  0.024093
# 4    26308  478_180_4 -0.573508
# ------- counter 19 start -------
# Memory usage of cache is 1.77 MB
# Memory usage after optimization is: 1.38 MB
# Decreased by 22.20%
# cache len 4000
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.87 MB
# Memory usage after optimization is: 1.62 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.64 MB
# Memory usage after optimization is: 2.32 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.37 MB
# Memory usage after optimization is: 2.37 MB
# Decreased by 0.00%
# Predict: 478, 190
# Predictor target models len 1
#    time_id     row_id    target
# 0    26309  478_190_0  0.063122
# 1    26309  478_190_1 -0.028247
# 2    26309  478_190_2  0.403093
# 3    26309  478_190_3 -0.337944
# 4    26309  478_190_4  0.035891
# ------- counter 20 start -------
# Memory usage of cache is 1.86 MB
# Memory usage after optimization is: 1.45 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 200
# Predictor target models len 1
#    time_id     row_id    target
# 0    26310  478_200_0  0.138606
# 1    26310  478_200_1 -1.006209
# 2    26310  478_200_2  1.032170
# 3    26310  478_200_3 -0.067331
# 4    26310  478_200_4  0.081263
# ------- counter 21 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 210
# Predictor target models len 1
#    time_id     row_id    target
# 0    26311  478_210_0  0.041089
# 1    26311  478_210_1 -0.693014
# 2    26311  478_210_2  1.070769
# 3    26311  478_210_3 -0.588833
# 4    26311  478_210_4  0.279571
# ------- counter 22 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 220
# Predictor target models len 1
#    time_id     row_id    target
# 0    26312  478_220_0 -0.326421
# 1    26312  478_220_1 -0.855062
# 2    26312  478_220_2  0.433868
# 3    26312  478_220_3 -0.594255
# 4    26312  478_220_4  0.178432
# ------- counter 23 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 230
# Predictor target models len 1
#    time_id     row_id    target
# 0    26313  478_230_0 -0.196737
# 1    26313  478_230_1 -0.903186
# 2    26313  478_230_2  1.045980
# 3    26313  478_230_3 -0.420599
# 4    26313  478_230_4  0.418598
# ------- counter 24 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 240
# Predictor target models len 1
#    time_id     row_id    target
# 0    26314  478_240_0 -0.261491
# 1    26314  478_240_1 -0.833520
# 2    26314  478_240_2 -0.526930
# 3    26314  478_240_3 -0.498490
# 4    26314  478_240_4  1.063447
# ------- counter 25 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 250
# Predictor target models len 1
#    time_id     row_id    target
# 0    26315  478_250_0 -0.466040
# 1    26315  478_250_1 -0.655175
# 2    26315  478_250_2 -0.510732
# 3    26315  478_250_3 -0.466982
# 4    26315  478_250_4  0.817033
# ------- counter 26 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 260
# Predictor target models len 1
#    time_id     row_id    target
# 0    26316  478_260_0 -0.363564
# 1    26316  478_260_1 -0.129676
# 2    26316  478_260_2 -0.788774
# 3    26316  478_260_3 -0.334629
# 4    26316  478_260_4  0.673368
# ------- counter 27 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 270
# Predictor target models len 1
#    time_id     row_id    target
# 0    26317  478_270_0 -0.165978
# 1    26317  478_270_1  0.865067
# 2    26317  478_270_2 -0.692507
# 3    26317  478_270_3 -0.021080
# 4    26317  478_270_4  0.467047
# ------- counter 28 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 280
# Predictor target models len 1
#    time_id     row_id    target
# 0    26318  478_280_0 -0.352592
# 1    26318  478_280_1  0.633285
# 2    26318  478_280_2 -1.410899
# 3    26318  478_280_3 -0.098302
# 4    26318  478_280_4  0.401278
# ------- counter 29 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 290
# Predictor target models len 1
#    time_id     row_id    target
# 0    26319  478_290_0 -0.369983
# 1    26319  478_290_1 -0.638295
# 2    26319  478_290_2 -0.955533
# 3    26319  478_290_3  0.164958
# 4    26319  478_290_4  0.323561
# ------- counter 30 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 300
# Predictor target models len 1
#    time_id     row_id    target
# 0    26320  478_300_0 -0.114831
# 1    26320  478_300_1  0.522742
# 2    26320  478_300_2 -0.293937
# 3    26320  478_300_3  0.205828
# 4    26320  478_300_4  0.390807
# ------- counter 31 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 310
# Predictor target models len 1
#    time_id     row_id    target
# 0    26321  478_310_0 -0.182157
# 1    26321  478_310_1  0.316824
# 2    26321  478_310_2  0.352569
# 3    26321  478_310_3  0.274479
# 4    26321  478_310_4 -0.569624
# ------- counter 32 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 320
# Predictor target models len 1
#    time_id     row_id    target
# 0    26322  478_320_0  0.015488
# 1    26322  478_320_1 -0.051349
# 2    26322  478_320_2 -0.348575
# 3    26322  478_320_3  0.343686
# 4    26322  478_320_4 -0.605508
# ------- counter 33 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 330
# Predictor target models len 1
#    time_id     row_id    target
# 0    26323  478_330_0 -0.126910
# 1    26323  478_330_1 -0.478354
# 2    26323  478_330_2  0.000180
# 3    26323  478_330_3  0.107975
# 4    26323  478_330_4 -0.559375
# ------- counter 34 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 340
# Predictor target models len 1
#    time_id     row_id    target
# 0    26324  478_340_0 -0.202696
# 1    26324  478_340_1  0.584280
# 2    26324  478_340_2 -0.569621
# 3    26324  478_340_3 -0.003166
# 4    26324  478_340_4 -0.171869
# ------- counter 35 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 350
# Predictor target models len 1
#    time_id     row_id    target
# 0    26325  478_350_0 -0.027349
# 1    26325  478_350_1  0.597618
# 2    26325  478_350_2  0.184977
# 3    26325  478_350_3 -0.035714
# 4    26325  478_350_4 -0.292235
# ------- counter 36 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 360
# Predictor target models len 1
#    time_id     row_id    target
# 0    26326  478_360_0 -0.064202
# 1    26326  478_360_1  1.118695
# 2    26326  478_360_2  0.082391
# 3    26326  478_360_3 -0.046061
# 4    26326  478_360_4 -0.383909
# ------- counter 37 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 370
# Predictor target models len 1
#    time_id     row_id    target
# 0    26327  478_370_0  0.030033
# 1    26327  478_370_1  0.644822
# 2    26327  478_370_2 -0.286829
# 3    26327  478_370_3  0.075997
# 4    26327  478_370_4 -0.187097
# ------- counter 38 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 380
# Predictor target models len 1
#    time_id     row_id    target
# 0    26328  478_380_0  0.127848
# 1    26328  478_380_1 -0.470328
# 2    26328  478_380_2 -0.054931
# 3    26328  478_380_3  0.105842
# 4    26328  478_380_4 -0.149367
# ------- counter 39 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 390
# Predictor target models len 1
#    time_id     row_id    target
# 0    26329  478_390_0 -0.020325
# 1    26329  478_390_1 -0.251098
# 2    26329  478_390_2 -0.214481
# 3    26329  478_390_3  0.038097
# 4    26329  478_390_4 -0.164127
# ------- counter 40 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 400
# Predictor target models len 1
#    time_id     row_id    target
# 0    26330  478_400_0 -0.194974
# 1    26330  478_400_1 -0.334366
# 2    26330  478_400_2 -0.059854
# 3    26330  478_400_3  0.624908
# 4    26330  478_400_4 -0.092113
# ------- counter 41 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 410
# Predictor target models len 1
#    time_id     row_id    target
# 0    26331  478_410_0 -0.083926
# 1    26331  478_410_1 -0.338490
# 2    26331  478_410_2 -0.373968
# 3    26331  478_410_3  0.486241
# 4    26331  478_410_4  0.117722
# ------- counter 42 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 420
# Predictor target models len 1
#    time_id     row_id    target
# 0    26332  478_420_0  0.541238
# 1    26332  478_420_1 -0.053729
# 2    26332  478_420_2 -0.059913
# 3    26332  478_420_3  0.336262
# 4    26332  478_420_4  0.268527
# ------- counter 43 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 430
# Predictor target models len 1
#    time_id     row_id    target
# 0    26333  478_430_0  0.142873
# 1    26333  478_430_1 -0.224515
# 2    26333  478_430_2  0.251253
# 3    26333  478_430_3  0.273737
# 4    26333  478_430_4  0.192487
# ------- counter 44 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 440
# Predictor target models len 1
#    time_id     row_id    target
# 0    26334  478_440_0  0.293951
# 1    26334  478_440_1 -0.223138
# 2    26334  478_440_2  0.217246
# 3    26334  478_440_3 -0.231324
# 4    26334  478_440_4  0.198006
# ------- counter 45 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 450
# Predictor target models len 1
#    time_id     row_id    target
# 0    26335  478_450_0  0.501049
# 1    26335  478_450_1 -0.142790
# 2    26335  478_450_2 -0.201971
# 3    26335  478_450_3 -0.391033
# 4    26335  478_450_4 -0.194304
# ------- counter 46 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 460
# Predictor target models len 1
#    time_id     row_id    target
# 0    26336  478_460_0  0.351619
# 1    26336  478_460_1 -0.111584
# 2    26336  478_460_2  0.044003
# 3    26336  478_460_3 -0.255385
# 4    26336  478_460_4 -0.223476
# ------- counter 47 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 470
# Predictor target models len 1
#    time_id     row_id    target
# 0    26337  478_470_0  0.381669
# 1    26337  478_470_1 -0.222533
# 2    26337  478_470_2 -0.252284
# 3    26337  478_470_3 -0.388792
# 4    26337  478_470_4 -0.497591
# ------- counter 48 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 480
# Predictor target models len 1
#    time_id     row_id    target
# 0    26338  478_480_0 -0.365493
# 1    26338  478_480_1 -0.079467
# 2    26338  478_480_2  0.168178
# 3    26338  478_480_3 -0.376068
# 4    26338  478_480_4 -0.294461
# ------- counter 49 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 490
# Predictor target models len 1
#    time_id     row_id    target
# 0    26339  478_490_0 -0.316768
# 1    26339  478_490_1  0.339269
# 2    26339  478_490_2 -0.491978
# 3    26339  478_490_3 -0.281889
# 4    26339  478_490_4 -0.167195
# ------- counter 50 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 500
# Predictor target models len 1
#    time_id     row_id    target
# 0    26340  478_500_0 -0.119280
# 1    26340  478_500_1 -0.750081
# 2    26340  478_500_2  0.094743
# 3    26340  478_500_3 -0.344608
# 4    26340  478_500_4  0.135276
# ------- counter 51 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 510
# Predictor target models len 1
#    time_id     row_id    target
# 0    26341  478_510_0  0.010635
# 1    26341  478_510_1  0.324002
# 2    26341  478_510_2 -0.056982
# 3    26341  478_510_3 -0.228216
# 4    26341  478_510_4  0.123472
# ------- counter 52 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 520
# Predictor target models len 1
#    time_id     row_id    target
# 0    26342  478_520_0 -0.093285
# 1    26342  478_520_1 -0.474846
# 2    26342  478_520_2  0.284613
# 3    26342  478_520_3 -0.208825
# 4    26342  478_520_4  0.048387
# ------- counter 53 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 530
# Predictor target models len 1
#    time_id     row_id    target
# 0    26343  478_530_0  0.021867
# 1    26343  478_530_1 -0.056729
# 2    26343  478_530_2  1.189993
# 3    26343  478_530_3  0.111143
# 4    26343  478_530_4  0.027762
# ------- counter 54 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 478, 540
# Predictor target models len 1
#    time_id     row_id    target
# 0    26344  478_540_0 -0.044448
# 1    26344  478_540_1 -0.442917
# 2    26344  478_540_2  0.530182
# 3    26344  478_540_3  0.578624
# 4    26344  478_540_4  0.478447
# ------- counter 55 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 11000
# update revealed_targets
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 479, 0
# Predictor target models len 1
#    time_id   row_id    target
# 0    26345  479_0_0  0.003444
# 1    26345  479_0_1 -0.373428
# 2    26345  479_0_2  0.110257
# 3    26345  479_0_3 -0.145679
# 4    26345  479_0_4  0.044305
# ------- counter 56 start -------
# Memory usage of cache is 1.95 MB
# ...
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 360
# Predictor target models len 1
#    time_id     row_id    target
# 0    26436  480_360_0 -0.126882
# 1    26436  480_360_1 -0.662921
# 2    26436  480_360_2 -0.595591
# 3    26436  480_360_3 -0.838580
# 4    26436  480_360_4  0.629213
# ------- counter 147 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 370
# Predictor target models len 1
#    time_id     row_id    target
# 0    26437  480_370_0 -0.175197
# 1    26437  480_370_1 -0.172430
# 2    26437  480_370_2 -0.603385
# 3    26437  480_370_3 -0.291424
# 4    26437  480_370_4  0.278063
# ------- counter 148 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 380
# Predictor target models len 1
#    time_id     row_id    target
# 0    26438  480_380_0 -0.169580
# 1    26438  480_380_1 -0.322545
# 2    26438  480_380_2 -0.288119
# 3    26438  480_380_3 -0.179233
# 4    26438  480_380_4  0.246669
# ------- counter 149 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 390
# Predictor target models len 1
#    time_id     row_id    target
# 0    26439  480_390_0 -0.129878
# 1    26439  480_390_1 -0.279628
# 2    26439  480_390_2  0.131139
# 3    26439  480_390_3  0.073985
# 4    26439  480_390_4 -0.272318
# ------- counter 150 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 400
# Predictor target models len 1
#    time_id     row_id    target
# 0    26440  480_400_0 -0.185530
# 1    26440  480_400_1 -0.535372
# 2    26440  480_400_2  0.156062
# 3    26440  480_400_3  0.147078
# 4    26440  480_400_4 -0.203811
# ------- counter 151 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 410
# Predictor target models len 1
#    time_id     row_id    target
# 0    26441  480_410_0  0.288316
# 1    26441  480_410_1  0.448047
# 2    26441  480_410_2  0.045801
# 3    26441  480_410_3  0.182883
# 4    26441  480_410_4 -0.331068
# ------- counter 152 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 420
# Predictor target models len 1
#    time_id     row_id    target
# 0    26442  480_420_0  0.172591
# 1    26442  480_420_1  0.271376
# 2    26442  480_420_2 -0.169896
# 3    26442  480_420_3  0.005031
# 4    26442  480_420_4 -0.377452
# ------- counter 153 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 430
# Predictor target models len 1
#    time_id     row_id    target
# 0    26443  480_430_0  0.197534
# 1    26443  480_430_1  0.247223
# 2    26443  480_430_2 -0.041726
# 3    26443  480_430_3 -0.022230
# 4    26443  480_430_4 -0.316884
# ------- counter 154 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 440
# Predictor target models len 1
#    time_id     row_id    target
# 0    26444  480_440_0 -0.040764
# 1    26444  480_440_1  0.121512
# 2    26444  480_440_2  0.093726
# 3    26444  480_440_3  0.240792
# 4    26444  480_440_4 -0.085556
# ------- counter 155 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 450
# Predictor target models len 1
#    time_id     row_id    target
# 0    26445  480_450_0 -0.009805
# 1    26445  480_450_1  0.085751
# 2    26445  480_450_2 -0.250352
# 3    26445  480_450_3  0.302535
# 4    26445  480_450_4  0.012422
# ------- counter 156 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 460
# Predictor target models len 1
#    time_id     row_id    target
# 0    26446  480_460_0  0.263611
# 1    26446  480_460_1  0.061259
# 2    26446  480_460_2 -0.497962
# 3    26446  480_460_3  0.219839
# 4    26446  480_460_4 -0.318715
# ------- counter 157 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 470
# Predictor target models len 1
#    time_id     row_id    target
# 0    26447  480_470_0  0.355741
# 1    26447  480_470_1  0.499019
# 2    26447  480_470_2 -0.522766
# 3    26447  480_470_3  0.304474
# 4    26447  480_470_4 -0.228917
# ------- counter 158 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 480
# Predictor target models len 1
#    time_id     row_id    target
# 0    26448  480_480_0  0.375761
# 1    26448  480_480_1  0.740171
# 2    26448  480_480_2 -0.144526
# 3    26448  480_480_3  0.113030
# 4    26448  480_480_4 -0.080368
# ------- counter 159 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 490
# Predictor target models len 1
#    time_id     row_id    target
# 0    26449  480_490_0  0.495510
# 1    26449  480_490_1 -0.845899
# 2    26449  480_490_2 -0.283977
# 3    26449  480_490_3  0.305042
# 4    26449  480_490_4 -0.201025
# ------- counter 160 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 500
# Predictor target models len 1
#    time_id     row_id    target
# 0    26450  480_500_0  0.446918
# 1    26450  480_500_1 -0.555006
# 2    26450  480_500_2 -0.317670
# 3    26450  480_500_3  0.236086
# 4    26450  480_500_4 -0.238609
# ------- counter 161 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 510
# Predictor target models len 1
#    time_id     row_id    target
# 0    26451  480_510_0 -0.108347
# 1    26451  480_510_1 -0.768723
# 2    26451  480_510_2 -0.383680
# 3    26451  480_510_3  0.587017
# 4    26451  480_510_4 -0.202002
# ------- counter 162 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 520
# Predictor target models len 1
#    time_id     row_id    target
# 0    26452  480_520_0 -0.265528
# 1    26452  480_520_1 -0.612946
# 2    26452  480_520_2  0.059277
# 3    26452  480_520_3  0.535641
# 4    26452  480_520_4  0.048512
# ------- counter 163 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 530
# Predictor target models len 1
#    time_id     row_id    target
# 0    26453  480_530_0 -0.073749
# 1    26453  480_530_1 -0.571137
# 2    26453  480_530_2 -0.328222
# 3    26453  480_530_3  0.581291
# 4    26453  480_530_4  0.080334
# ------- counter 164 start -------
# Memory usage of cache is 1.95 MB
# Memory usage after optimization is: 1.51 MB
# Decreased by 22.20%
# cache len 4200
# copy_revealed_targets len 0
# Memory usage of generate_basic_features is 1.96 MB
# Memory usage after optimization is: 1.70 MB
# Decreased by 13.09%
# Use index
# generate_index_features
# generate_historical_features
# Memory usage of generate_enhance_features is 2.78 MB
# Memory usage after optimization is: 2.44 MB
# Decreased by 12.12%
# generate_normalized_features
# Memory usage of generate_normalized_features is 2.49 MB
# Memory usage after optimization is: 2.49 MB
# Decreased by 0.00%
# Predict: 480, 540
# Predictor target models len 1
#    time_id     row_id    target
# 0    26454  480_540_0  0.220955
# 1    26454  480_540_1 -0.377213
# 2    26454  480_540_2 -0.108415
# 3    26454  480_540_3 -0.203521
# 4    26454  480_540_4  0.115242
# RAM memory GB usage = 0.5665
# CPU times: user 5min 4s, sys: 2.88 s, total: 5min 7s
# Wall time: 5min 9s
