# %% [markdown]
# # Incremental Learning Model
# This origin comming from https://www.kaggle.com/code/lblhandsome/optiver-robust-best-single-model/notebook

# %% [markdown]
# # Global params

# %%
from pathlib import Path
import os
import warnings
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import gc  # Garbage collection for memory management
import os  # Operating system-related functions
import time  # Time-related functions
import warnings  # Handling warnings
from itertools import combinations  # For creating combinations of elements
from warnings import simplefilter  # Simplifying warning handling
import joblib  # For saving and loading models
import numpy as np  # Numerical operations
import pandas as pd  # Data manipulation and analysis
from sklearn.metrics import mean_absolute_error  # Metric for evaluation
from sklearn.model_selection import KFold, TimeSeriesSplit  # Cross-validation techniques

# Disable warnings to keep the code clean
warnings.filterwarnings("ignore")
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

warnings.filterwarnings("ignore")

seed = 2023
DATA_COUNT_IN_SAME_BUCKET = 55 # 同じbucket内のデータ数

# valid_split_day = 435  # Split day for time series data

# For kaggle environment
if os.environ.get("KAGGLE_DATA_PROXY_TOKEN") != None:
    BASE_OUTPUT_PATH = Path(f'/kaggle/working')
    BASE_INPUT_PATH = Path(f'/kaggle/input/optiver-trading-at-the-close')
    TRAIN_FILE = Path(f'{BASE_INPUT_PATH}/train.csv')
    TEST_FILE = Path(f'{BASE_INPUT_PATH}/example_test_files/test.csv')
    
    IS_LOCAL = False # If kaggle environment, set False
    IS_INFER = True # If kaggle environment, set True
    IS_USE_SAVED_MODEL = False # Use saved model or not
    IS_MIN_LEARN = False # Use min learning or not
    USE_OPTUNA = False # Use optuna or not
    USE_CONTINUOUS_UPDATE = True # Use test date on train or not
    USE_ALL_FEATUTES = True # Use all features or not
    USE_REVEALED_TARGETS = True # Use revealed targets or not
    USE_INDEX = True # Use index or not
    IS_DEBUG = False

    SAMPLE_SUBMISSION_FILE = Path(f'{BASE_INPUT_PATH}/example_test_files/sample_submission.csv')
    REVEALED_TARGETS_FILE = Path(f'{BASE_INPUT_PATH}/example_test_files/revealed_targets.csv')

    stopping_rounds = 100 # early_stopping用コールバック関数
    num_boost_round = 50000 # 計算回数
    update_num_boost_round = 50000 # 再学習の計算回数
    num_folds = 10 # クロスバリデーションの分割数
    continuos_dataset_span = 3 # DATA_COUNT_IN_SAME_BUCKET * continuos_dataset_span が更新の使用する対象のデータ
    continuos_train_span = 1 # DATA_COUNT_IN_SAME_BUCKET * continuos_train_span が更新の頻度

    DEVICE = 'cpu' # cpu or gpu
    OPTUNA_TIME_BUDGET = 60 * 60 * 4 # 1 hours
    TARGET_STOCK_IDS = [0, 1]

    optuna_params = {
        'boosting_type': 'gbdt',
        'objective': 'regression',         # 回帰
        'metric': 'rmse',                  # 損失（誤差）
        'verbosity': -1,
        'deterministic':True, #再現性確保用のパラメータ
        'force_row_wise':True,  #再現性確保用のパラメータ
        'device': DEVICE
    }

    """
    lgb_params = {
        'boosting_type': 'gbdt',
        'objective': 'regression', 
        'metric': 'rmse', 
        'verbosity': -1, 
        'device': DEVICE,
        'feature_pre_filter': False, 
        'lambda_l1': 0.0,
        'lambda_l2': 0.0,
        'num_leaves': 31, 
        'feature_fraction': 0.8, 
        'bagging_fraction': 1.0, 
        'bagging_freq': 0, 
        'min_child_samples': 20
    }
    """
   
    lgb_params = {
        'task': 'train',                   # 学習
        'objective': 'regression',                # 目的関数の種類。ここでは回帰タスクを指定
        'metric': 'rmse',                          # 評価指標
        'boosting_type': 'gbdt',                  # ブースティングタイプ。勾配ブースティング決定木
        "n_estimators": 32,                        # ブースティングに使用する木の数。多いほど性能が向上するが計算コストが増加
        "num_leaves": 64,                         # 木に存在する最大の葉の数。大きい値は精度を向上させるが過学習のリスクが増加
        "subsample": 0.8,                         # 各木のトレーニングに使用されるデータの割合。過学習を防ぐために一部のデータをサンプリング
        "colsample_bytree": 0.8,                  # 木を構築する際に使用される特徴の割合。特徴のサブセットを使用し過学習を防ぐ
        "learning_rate": 0.01,                 # 学習率。小さい値は堅牢なモデルを生成するが収束に時間がかかる
        'max_depth': 32,                           # 木の最大の深さ。深い木は複雑なモデルを作成するが過学習のリスクがある
        "device": DEVICE,                         # トレーニングに使用するデバイス（CPUまたはGPU）
        "verbosity": -1,                          # LightGBMのログ出力のレベル。-1はログを出力しないことを意味する
       # "importance_type": "gain",                # 特徴重要度を計算する際の指標。"gain"は分割による平均情報利得
        'lambda_l1': 0.5,                         # L1正則化項の係数。過学習を防ぐためにモデルの複雑さにペナルティを課す
        'lambda_l2': 0.5,                         # L2正則化項の係数。同じく過学習を防ぐ
        'bagging_freq': 5,                 # バギング実施頻度
        'min_child_samples': 10,           # 葉に含まれる最小データ数
        'seed': seed,                       # シード値
    }

# For local environment
else:
    BASE_OUTPUT_PATH = Path(f'../output')
    BASE_INPUT_PATH = Path(f'../kaggle/input/optiver-trading-at-the-close')
    TRAIN_FILE = Path(f'{BASE_INPUT_PATH}/train.csv')
    TEST_FILE = Path(f'{BASE_INPUT_PATH}/test.csv')

    SAMPLE_SUBMISSION_FILE = Path(f'{BASE_INPUT_PATH}/sample_submission.csv')
    REVEALED_TARGETS_FILE = Path(f'{BASE_INPUT_PATH}/revealed_targets.csv')

    IS_LOCAL = True
    IS_INFER = True
    IS_USE_SAVED_MODEL = False # Use saved model or not
    IS_MIN_LEARN = True
    USE_OPTUNA = False # Use optuna or not
    USE_ALL_FEATUTES = True # Use all features or not
    USE_CONTINUOUS_UPDATE = True # Use test date on train or not
    USE_REVEALED_TARGETS = False # Use revealed targets or not 
    USE_INDEX = True # Use index or not
    IS_DEBUG = True
    TARGET_STOCK_IDS = [0]

    # For training
    stopping_rounds = 1 # early_stopping用コールバック関数
    num_boost_round = 1 # 計算回数
    update_num_boost_round = 1
    num_folds = 2 # クロスバリデーションの分割数
    continuos_dataset_span = 3 # DATA_COUNT_IN_SAME_BUCKET * continuos_dataset_span が更新の使用する対象のデータ
    continuos_train_span = 2 # DATA_COUNT_IN_SAME_BUCKET * continuos_train_span が更新の頻度

    DEVICE = 'cpu' # cpu or gpu
    OPTUNA_TIME_BUDGET = 60 # 1 min

    optuna_params = {
        'boosting_type': 'gbdt',
        'objective': 'regression',         # 回帰
        'metric': 'rmse',                  # 損失（誤差）
        'verbosity': -1,
        'deterministic':True, #再現性確保用のパラメータ
        'force_row_wise':True,  #再現性確保用のパラメータ
        'device': DEVICE
    }

    lgb_params = {
        'task': 'train',                   # 学習
        'boosting_type': 'gbdt',           # GBDT
        'objective': 'regression',         # 回帰
        'metric': 'rmse',                  # 損失（誤差）
        'learning_rate': 0.01,             # 学習率
        'lambda_l1': 0.5,                  # L1正則化項の係数
        'lambda_l2': 0.5,                  # L2正則化項の係数
        'num_leaves': 10,                  # 最大葉枚数
        'feature_fraction': 0.5,           # ランダムに抽出される列の割合
        'bagging_fraction': 0.5,           # ランダムに抽出される標本の割合
        'bagging_freq': 5,                 # バギング実施頻度
        'min_child_samples': 10,           # 葉に含まれる最小データ数
        'seed': seed,                       # シード値
        "device": DEVICE,
        'verbosity': -1
    }


print(f"BASE_OUTPUT_PATH: {BASE_OUTPUT_PATH}")
print(f"BASE_INPUT_PATH: {BASE_INPUT_PATH}")
print(f"TRAIN_FILE: {TRAIN_FILE}")
print(f"TEST_FILE: {TEST_FILE}")
print(f"IS_LOCAL: {IS_LOCAL}")
print(f"IS_INFER: {IS_INFER}")
print(f"IS_USE_SAVED_MODEL: {IS_USE_SAVED_MODEL}")
print(f"IS_MIN_LEARN: {IS_MIN_LEARN}")
print(f"USE_OPTUNA: {USE_OPTUNA}")
print(f"USE_CONTINUOUS_UPDATE: {USE_CONTINUOUS_UPDATE}")
print(f"USE_ALL_FEATUTES: {USE_ALL_FEATUTES}")
print(f"USE_REVEALED_TARGETS: {USE_REVEALED_TARGETS}")
print(f"USE_INDEX: {USE_INDEX}")
# Out:
# BASE_OUTPUT_PATH: ../output
# BASE_INPUT_PATH: ../kaggle/input/optiver-trading-at-the-close
# TRAIN_FILE: ../kaggle/input/optiver-trading-at-the-close/train.csv
# TEST_FILE: ../kaggle/input/optiver-trading-at-the-close/test.csv
# IS_LOCAL: True
# IS_INFER: True
# IS_USE_SAVED_MODEL: False
# IS_MIN_LEARN: True
# USE_OPTUNA: False
# USE_CONTINUOUS_UPDATE: True
# USE_ALL_FEATUTES: True
# USE_REVEALED_TARGETS: False
# USE_INDEX: True

# %% [markdown]
# # Functions

# %% [markdown]
# ## Memory Functions

# %%
# %%time 

from gc import collect;
from psutil import Process;
from os import system, getpid, walk;

# Defining global configurations and functions:-

    
def GetMemUsage():
    """
    This function defines the memory usage across the kernel. 
    Source-
    https://stackoverflow.com/questions/61366458/how-to-find-memory-usage-of-kaggle-notebook
    """;
    
    pid = getpid();
    py = Process(pid);
    memory_use = py.memory_info()[0] / 2. ** 30;
    return f"RAM memory GB usage = {memory_use :.4}";


collect();
print(GetMemUsage())
# Out:
# RAM memory GB usage = 0.4344
# CPU times: user 82 ms, sys: 2.16 ms, total: 84.2 ms
# Wall time: 84.9 ms

# %%
# 🧹 Function to reduce memory usage of a Pandas DataFrame
def reduce_mem_usage(df, name: str, show_optimization: bool = False):
    """
    Iterate through all numeric columns of a dataframe and modify the data type
    to reduce memory usage.
    """
    
    # 📏 Calculate the initial memory usage of the DataFrame
    start_mem = df.memory_usage().sum() / 1024**2

    # 🔄 Iterate through each column in the DataFrame
    for col in df.columns:
        col_type = df[col].dtype

        # Check if the column's data type is not 'object' (i.e., numeric)
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            
            # Check if the column's data type is an integer
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                # Check if the column's data type is a float
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float32)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float32)

    if show_optimization:
        print(f"Memory usage of {name} is {start_mem:.2f} MB")
        end_mem = df.memory_usage().sum() / 1024**2
        print(f"Memory usage after optimization is: {end_mem:.2f} MB")
        decrease = 100 * (start_mem - end_mem) / start_mem
        print(f"Decreased by {decrease:.2f}%")

    # 🔄 Return the DataFrame with optimized memory usage

    start_mem = df.memory_usage().sum() / 1024**2
    return df

# %% [markdown]
# ## API Function

# %%
# %%time 

from typing import Sequence, Tuple
import pandas as pd

# for local execution
class MockApi:
    def __init__(self):
        '''
        YOU MUST UPDATE THE FIRST THREE LINES of this method.
        They've been intentionally left in an invalid state.

        Variables to set:
            input_paths: a list of two or more paths to the csv files to be served
            group_id_column: the column that identifies which groups of rows the API should serve.
                A call to iter_test serves all rows of all dataframes with the current group ID value.
            export_group_id_column: if true, the dataframes iter_test serves will include the group_id_column values.
        '''
        self.input_paths: Sequence[str] = [TEST_FILE, REVEALED_TARGETS_FILE, SAMPLE_SUBMISSION_FILE]
        self.group_id_column: str = 'time_id'
        self.export_group_id_column: bool = True
        # iter_test is only designed to support at least two dataframes, such as test and sample_submission
        assert len(self.input_paths) >= 2

        self._status = 'initialized'
        self.predictions = []

    def iter_test(self) -> Tuple[pd.DataFrame]:
        '''
        Loads all of the dataframes specified in self.input_paths,
        then yields all rows in those dataframes that equal the current self.group_id_column value.
        '''
        if self._status != 'initialized':

            raise Exception('WARNING: the real API can only iterate over `iter_test()` once.')

        dataframes = []
        for pth in self.input_paths:
            dataframes.append(pd.read_csv(pth, low_memory=False))
        group_order = dataframes[0][self.group_id_column].drop_duplicates().tolist()
        dataframes = [df.set_index(self.group_id_column) for df in dataframes]

        for group_id in group_order:
            self._status = 'prediction_needed'
            current_data = []
            for df in dataframes:
                cur_df = df.loc[group_id].copy()
                # returning single line dataframes from df.loc requires special handling
                if not isinstance(cur_df, pd.DataFrame):
                    cur_df = pd.DataFrame({a: b for a, b in zip(cur_df.index.values, cur_df.values)}, index=[group_id])
                    cur_df.index.name = self.group_id_column
                cur_df = cur_df.reset_index(drop=not(self.export_group_id_column))
                current_data.append(cur_df)
            yield tuple(current_data)

            while self._status != 'prediction_received':
                print('You must call `predict()` successfully before you can continue with `iter_test()`', flush=True)
                yield None

        with open('submission.csv', 'w') as f_open:
            pd.concat(self.predictions).to_csv(f_open, index=False)
        self._status = 'finished'

    def predict(self, user_predictions: pd.DataFrame):
        '''
        Accepts and stores the user's predictions and unlocks iter_test once that is done
        '''
        if self._status == 'finished':
            raise Exception('You have already made predictions for the full test set.')
        if self._status != 'prediction_needed':
            raise Exception('You must get the next test sample from `iter_test()` first.')
        if not isinstance(user_predictions, pd.DataFrame):
            raise Exception('You must provide a DataFrame.')

        self.predictions.append(user_predictions)
        self._status = 'prediction_received'

def make_env():
    return MockApi()
# Out:
# CPU times: user 45 µs, sys: 1 µs, total: 46 µs
# Wall time: 48.2 µs

# %% [markdown]
# ## Pandas Functions

# %%
def pd_display_max():
    pd.set_option('display.max_rows', None)  # 行の最大表示数を無制限に設定
    pd.set_option('display.max_columns', None)  # 列の最大表示数を無制限に設定
    pd.set_option('display.width', None)  # 表示幅を拡張
    pd.set_option('display.max_colwidth', None)  # 列の幅を最大に設定

def pd_clear_display_max():
    pd.set_option('display.max_rows', 10)
    pd.set_option('display.max_columns', 10)
    pd.set_option('display.width', None)  # 表示幅を拡張
    pd.set_option('display.max_colwidth', None)  # 列の幅を最大に設定

# %% [markdown]
# ## Feature Functions

# %%
# 🏎️ Import Numba for just-in-time (JIT) compilation and parallel processing
from numba import njit, prange

# 📊 Function to compute triplet imbalance in parallel using Numba
@njit(parallel=True)
def compute_triplet_imbalance(df_values, comb_indices):
    num_rows = df_values.shape[0]
    num_combinations = len(comb_indices)
    imbalance_features = np.empty((num_rows, num_combinations))

    # 🔁 Loop through all combinations of triplets
    for i in prange(num_combinations):
        a, b, c = comb_indices[i]
        
        # 🔁 Loop through rows of the DataFrame
        for j in range(num_rows):
            max_val = max(df_values[j, a], df_values[j, b], df_values[j, c])
            min_val = min(df_values[j, a], df_values[j, b], df_values[j, c])
            mid_val = df_values[j, a] + df_values[j, b] + df_values[j, c] - min_val - max_val
            
            # 🚫 Prevent division by zero
            if mid_val == min_val:
                imbalance_features[j, i] = np.nan
            else:
                imbalance_features[j, i] = (max_val - mid_val) / (mid_val - min_val)

    return imbalance_features

# 📈 Function to calculate triplet imbalance for given price data and a DataFrame
def calculate_triplet_imbalance_numba(price, df):
    # Convert DataFrame to numpy array for Numba compatibility
    df_values = df[price].values
    comb_indices = [(price.index(a), price.index(b), price.index(c)) for a, b, c in combinations(price, 3)]

    # Calculate the triplet imbalance using the Numba-optimized function
    features_array = compute_triplet_imbalance(df_values, comb_indices)

    # Create a DataFrame from the results
    columns = [f"{a}_{b}_{c}_imb2" for a, b, c in combinations(price, 3)]
    features = pd.DataFrame(features_array, columns=columns)

    return features

# %%
# 📊 Function to generate imbalance features
def imbalance_features(df):
    if DEVICE == 'gpu':
        import cudf
        df = cudf.from_pandas(df)
    
    # Define lists of price and size-related column names
    prices = ["reference_price", "far_price", "near_price", "ask_price", "bid_price", "wap"]
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]

    # V1 features
    # Calculate various features using Pandas eval function
    df["volume"] = df.eval("ask_size + bid_size")
    df["mid_price"] = df.eval("ask_price + bid_price")/2
    df["liquidity_imbalance"] = df.eval("(bid_size-ask_size)/(bid_size+ask_size)")
    df["matched_imbalance"] = df.eval("imbalance_size-matched_size")/df.eval("matched_size+imbalance_size")
    df["size_imbalance"] = df.eval("bid_size / ask_size")
    
    # Create features for pairwise price imbalances
    for c in combinations(prices, 2):
        df[f"{c[0]}_{c[1]}_imb"] = df.eval(f"({c[0]} - {c[1]})/({c[0]} + {c[1]})")
        
    # V2 features
    # Calculate additional features
    df["imbalance_momentum"] = df.groupby(['stock_id'])['imbalance_size'].diff(periods=1) / df['matched_size']
    df["price_spread"] = df["ask_price"] - df["bid_price"]
    df["spread_intensity"] = df.groupby(['stock_id'])['price_spread'].diff()
    df['price_pressure'] = df['imbalance_size'] * (df['ask_price'] - df['bid_price'])
    df['market_urgency'] = df['price_spread'] * df['liquidity_imbalance']
    df['depth_pressure'] = (df['ask_size'] - df['bid_size']) * (df['far_price'] - df['near_price'])
    # Calculate the imbalance ratio
    df['match_balance'] = ( df['matched_size']  + (df['imbalance_buy_sell_flag'] * df['imbalance_size'])) / df['matched_size']
    
    # Calculate various statistical aggregation features
    
        
    # V3 features
    # Calculate shifted and return features for specific columns
    for col in ['matched_size', 'imbalance_size', 'reference_price', 'imbalance_buy_sell_flag']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_shift_{window}"] = df.groupby('stock_id')[col].shift(window)
            df[f"{col}_ret_{window}"] = df.groupby('stock_id')[col].pct_change(window)
    
    # Calculate diff features for specific columns
    for col in ['ask_price', 'bid_price', 'ask_size', 'bid_size']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_diff_{window}"] = df.groupby("stock_id")[col].diff(window)
    if DEVICE == 'gpu':
        df = df.to_pandas()
    # Replace infinite values with 0
    return df.replace([np.inf, -np.inf], 0)

def numba_imb_features(df):
    prices = ["reference_price", "far_price", "near_price", "ask_price", "bid_price", "wap"]
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]
    
    for func in ["mean", "std", "skew", "kurt"]:
        df[f"all_prices_{func}"] = df[prices].agg(func, axis=1)
        df[f"all_sizes_{func}"] = df[sizes].agg(func, axis=1)
        
    # Calculate triplet imbalance features using the Numba-optimized function
    for c in [['ask_price', 'bid_price', 'wap', 'reference_price'], sizes]:
        triplet_feature = calculate_triplet_imbalance_numba(c, df)
        df[triplet_feature.columns] = triplet_feature.values
    return df

# 📅 Function to generate time and stock-related features
def other_features(df):
    df["dow"] = df["date_id"] % 5  # Day of the week
    df["seconds"] = df["seconds_in_bucket"] % 60  # Seconds
    df["minute"] = df["seconds_in_bucket"] // 60  # Minutes

    # Map global features to the DataFrame
    for key, value in global_stock_id_feats.items():
        df[f"global_{key}"] = df["stock_id"].map(value.to_dict())

    return df

# 🚀 Function to generate all features by combining imbalance and other features
def generate_basic_features(df):
    prev_cols = list(df.columns)

    # Generate imbalance features
    df = imbalance_features(df)
    df = numba_imb_features(df)

    df = reduce_mem_usage(df, "generate_basic_features")

    collect()  # Perform garbage collection to free up memory

    return df

# %% [markdown]
# # Generationg train dataset

# %%
def load_train_dataset():
    df = pd.read_csv(TRAIN_FILE)
    # 🧹 Remove rows with missing values in the "target" column
    df = df.dropna(subset=["target"])
    # 🔁 Reset the index of the DataFrame and apply the changes in place
    df.reset_index(drop=True, inplace=True)
    return df

def load_test_dataset():
    df_test = pd.read_csv(TEST_FILE)
    
    df_revealed_targets = pd.read_csv(REVEALED_TARGETS_FILE)
    df_revealed_targets = df_revealed_targets.dropna(subset=['date_id', 'seconds_in_bucket', 'stock_id'])
    df_revealed_targets['revealed_date_id'] = df_revealed_targets['revealed_date_id'].astype(int).astype(str)
    df_revealed_targets['seconds_in_bucket'] = df_revealed_targets['seconds_in_bucket'].astype(int).astype(str)
    df_revealed_targets['stock_id'] = df_revealed_targets['stock_id'].astype(int).astype(str)  # Converting to int first to remove any decimal points
    df_revealed_targets['date_id'] = df_revealed_targets['date_id'].astype(int).astype(str)
    df_revealed_targets['row_id'] = df_revealed_targets['date_id'] + '_' + df_revealed_targets['seconds_in_bucket'] + '_' + df_revealed_targets['stock_id']
    df_revealed_targets['revealed_row_id'] = df_revealed_targets['revealed_date_id'] + '_' + df_revealed_targets['seconds_in_bucket'] + '_' + df_revealed_targets['stock_id']

    # USE_CONTINUOUS_UPDATEが有効の時、cacheのrow_idとdf_revealed_targetsのrevealed_row_idをleft joinする
    if USE_CONTINUOUS_UPDATE:
        df_r = df_revealed_targets[['revealed_row_id', 'revealed_target']]
        df_r.rename(columns={'revealed_target': 'target'}, inplace=True)
        df_r.rename(columns={'revealed_row_id': 'row_id'}, inplace=True)
        df_test = pd.merge(df_test, df_r, how='left', on='row_id')
        
    # USE_REVEALED_TARGETSが有効の時、cacheのrow_idとdf_revealed_targetsのrow_idをleft joinする
    if USE_REVEALED_TARGETS:
        df_r = df_revealed_targets[['row_id', 'revealed_target']]
        df_test = pd.merge(df_test, df_r, how='left', on='row_id')
        
    df_test = df_test.dropna(subset=["target"])
    df_test.reset_index(drop=True, inplace=True)
    return df_test

# %%
# %%time
# Check if the code is running in offline or online mode
print("Load train dataset")

df_train = load_train_dataset()

if IS_MIN_LEARN:
    print("MIN LEARN MODE :", TARGET_STOCK_IDS)
    # In local mode, stock id TARGET_STOCK_ID is used for training
    df_train = df_train[df_train["stock_id"].isin(TARGET_STOCK_IDS)]
    
features = [c for c in df_train.columns if c not in ["row_id", "target", "time_id", "row_id", "date_id", "currently_scored"]]
print(features)

collect();
print(GetMemUsage())
# Out:
# Load train dataset
# MIN LEARN MODE : [0]
# ['stock_id', 'seconds_in_bucket', 'imbalance_size', 'imbalance_buy_sell_flag', 'reference_price', 'matched_size', 'far_price', 'near_price', 'bid_price', 'bid_size', 'ask_price', 'ask_size', 'wap']
# RAM memory GB usage = 1.825
# CPU times: user 6.27 s, sys: 853 ms, total: 7.12 s
# Wall time: 7.17 s

# %%
# %%time

print("Step1. Generate general Global Stock ID Features and basic features")
prev_cols = list(df_train.columns)
global_stock_id_feats = {
    "median_size": df_train.groupby("stock_id")["bid_size"].median() + df_train.groupby("stock_id")["ask_size"].median(),
    "std_size": df_train.groupby("stock_id")["bid_size"].std() + df_train.groupby("stock_id")["ask_size"].std(),
    "ptp_size": df_train.groupby("stock_id")["bid_size"].max() - df_train.groupby("stock_id")["bid_size"].min(),
    "median_price": df_train.groupby("stock_id")["bid_price"].median() + df_train.groupby("stock_id")["ask_price"].median(),
    "std_price": df_train.groupby("stock_id")["bid_price"].std() + df_train.groupby("stock_id")["ask_price"].std(),
    "ptp_price": df_train.groupby("stock_id")["bid_price"].max() - df_train.groupby("stock_id")["ask_price"].min(),
}

df_train = generate_basic_features(df_train)

generated_feature_name = list(set(df_train.columns) - set(prev_cols))
features += generated_feature_name
print(generated_feature_name)

collect()
print(GetMemUsage())
# Out:
# Step1. Generate general Global Stock ID Features and basic features
# ['ask_price_bid_price_imb', 'matched_size_shift_3', 'far_price_wap_imb', 'reference_price_bid_price_imb', 'depth_pressure', 'imbalance_buy_sell_flag_shift_1', 'reference_price_ret_3', 'imbalance_momentum', 'imbalance_size_shift_2', 'bid_size_diff_3', 'ask_price_diff_2', 'ask_price_diff_10', 'matched_size_shift_2', 'reference_price_shift_2', 'imbalance_size_ret_1', 'reference_price_shift_1', 'imbalance_buy_sell_flag_shift_3', 'market_urgency', 'bid_size_diff_1', 'price_pressure', 'matched_size_bid_size_ask_size_imb2', 'all_prices_mean', 'matched_size_ask_size_imbalance_size_imb2', 'matched_size_ret_3', 'bid_size_diff_2', 'bid_price_diff_3', 'reference_price_ask_price_imb', 'reference_price_wap_imb', 'near_price_ask_price_imb', 'bid_size_diff_10', 'ask_price_diff_1', 'near_price_bid_price_imb', 'bid_price_diff_1', 'imbalance_size_ret_2', 'imbalance_buy_sell_flag_ret_10', 'bid_price_diff_2', 'bid_price_diff_10', 'all_sizes_kurt', 'imbalance_size_ret_3', 'reference_price_shift_10', 'reference_price_shift_3', 'match_balance', 'bid_price_wap_reference_price_imb2', 'all_sizes_std', 'imbalance_buy_sell_flag_ret_3', 'ask_price_wap_reference_price_imb2', 'reference_price_ret_1', 'reference_price_far_price_imb', 'ask_price_bid_price_wap_imb2', 'liquidity_imbalance', 'ask_price_wap_imb', 'reference_price_near_price_imb', 'imbalance_buy_sell_flag_ret_1', 'far_price_near_price_imb', 'reference_price_ret_2', 'imbalance_buy_sell_flag_shift_2', 'reference_price_ret_10', 'mid_price', 'far_price_bid_price_imb', 'imbalance_buy_sell_flag_shift_10', 'imbalance_size_shift_10', 'bid_price_wap_imb', 'matched_size_shift_1', 'matched_imbalance', 'matched_size_ret_1', 'far_price_ask_price_imb', 'size_imbalance', 'ask_size_diff_1', 'imbalance_size_ret_10', 'matched_size_bid_size_imbalance_size_imb2', 'ask_size_diff_10', 'ask_size_diff_2', 'all_sizes_skew', 'price_spread', 'all_prices_skew', 'ask_price_bid_price_reference_price_imb2', 'matched_size_shift_10', 'ask_size_diff_3', 'volume', 'bid_size_ask_size_imbalance_size_imb2', 'all_prices_kurt', 'all_sizes_mean', 'ask_price_diff_3', 'near_price_wap_imb', 'imbalance_size_shift_3', 'imbalance_buy_sell_flag_ret_2', 'matched_size_ret_10', 'spread_intensity', 'matched_size_ret_2', 'all_prices_std', 'imbalance_size_shift_1']
# RAM memory GB usage = 1.785
# CPU times: user 423 ms, sys: 22.2 ms, total: 445 ms
# Wall time: 442 ms

# %% [markdown]
# ## Generation train features

# %%
# %%time

from concurrent.futures import ThreadPoolExecutor

print("Step2. Generate enhanced features")
prev_cols = list(df_train.columns)

def generate_historical_features(df):
    print("generate_historical_features")
    target_cols = ['wap', 'match_balance']
    if USE_REVEALED_TARGETS:
        target_cols.append('revealed_target')
    if USE_INDEX:
        target_cols.append('index_mean_wap')
        target_cols.append('index_mean_match_balance')

    grouped = df.groupby(['stock_id', 'date_id'])

    for col in target_cols:
        for window in [3, 7]:
            col_diff_name = f"{col}_diff_{window}"
            df[col_diff_name] = grouped[col].diff(window)

            col_vix_name = f"{col}_vix_{window}"
            log_diff = np.log(grouped[col].transform('shift')) - np.log(grouped[col].transform('shift', periods=window))
            df[col_vix_name] = log_diff.rolling(window=window).std()

            # df[col_name] =  = df.groupby(group_key)[target_col].transform(lambda x: np.log(x).diff().rolling(period).std())
    df = df.replace([np.inf, -np.inf], 0)

    return df

# サブセットを処理する関数
def subset_generate_historical_features(df_subset):
    return generate_historical_features(df_subset)

# 並列処理を実行する関数
def parallel_generate_historical_features(df, num_threads=4):
    # DataFrameを 'stock_id' でグループ化
    grouped = df.groupby('stock_id')

    # 並列処理の実行
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        results = executor.map(subset_generate_historical_features, [group for _, group in grouped])

    # 結果の統合
    results = pd.concat(results)
    return results

def generate_index_features(df):
    print("generate_index_features")
     # Calculating mean and std for 'wap' and 'match_balance'
    wap_stats = df.groupby(['date_id', 'seconds_in_bucket'])['wap'].agg(['mean', 'std']).reset_index()
    match_balance_stats = df.groupby(['date_id', 'seconds_in_bucket'])['match_balance'].agg(['mean', 'std']).reset_index()

    # Adding prefix and suffix
    wap_stats = wap_stats.add_prefix('index_').add_suffix('_wap')
    match_balance_stats = match_balance_stats.add_prefix('index_').add_suffix('_match_balance')

    # Adjusting column names for merging
    wap_stats = wap_stats.rename(columns={'index_date_id_wap': 'date_id', 'index_seconds_in_bucket_wap': 'seconds_in_bucket'})
    match_balance_stats = match_balance_stats.rename(columns={'index_date_id_match_balance': 'date_id', 'index_seconds_in_bucket_match_balance': 'seconds_in_bucket'})

    # Merging with the original dataframe
    df = df.merge(wap_stats, on=['date_id', 'seconds_in_bucket'], how='left')
    df = df.merge(match_balance_stats, on=['date_id', 'seconds_in_bucket'], how='left')

    del wap_stats, match_balance_stats
    return df

def generate_enhance_features(df, is_train=False):
    if is_train:
        if USE_REVEALED_TARGETS:
            print("Use revealed targets")
            df[f"revealed_target"] = df.groupby(['date_id', 'stock_id'])['target'].shift(1)
        else:
            print("Dosent't use revealed targets")
    if USE_INDEX:
        print("Use index")
        current_time = time.time()
        df = generate_index_features(df)
        print(f"generate_index_features {time.time() - current_time:.2f} [sec]")
    current_time = time.time()
    df = generate_historical_features(df)
    print(f"generate_historical_features {time.time() - current_time:.2f} [sec]")
    df = reduce_mem_usage(df, "generate_enhance_features")
    collect()
    return df

df_train = generate_enhance_features(df_train, is_train=True)
generated_feature_name = list(set(df_train.columns) - set(prev_cols))
features += generated_feature_name
print(generated_feature_name)

collect()
print(GetMemUsage())
# Out:
# Step2. Generate enhanced features
# Dosent't use revealed targets
# Use index
# generate_index_features
# generate_index_features 0.03 [sec]
# generate_historical_features
# generate_historical_features 0.03 [sec]
# ['index_mean_wap_vix_3', 'wap_diff_7', 'index_mean_wap_vix_7', 'index_mean_wap_diff_3', 'wap_vix_7', 'index_mean_match_balance_diff_7', 'wap_vix_3', 'index_mean_match_balance_diff_3', 'index_mean_match_balance_vix_3', 'match_balance_vix_3', 'match_balance_diff_3', 'index_std_wap', 'index_mean_match_balance_vix_7', 'index_mean_wap_diff_7', 'index_std_match_balance', 'match_balance_diff_7', 'index_mean_match_balance', 'match_balance_vix_7', 'wap_diff_3', 'index_mean_wap']
# RAM memory GB usage = 1.733
# CPU times: user 345 ms, sys: 18.9 ms, total: 364 ms
# Wall time: 362 ms

# %%
print(df_train[["stock_id", "date_id", "seconds_in_bucket", "index_mean_match_balance_diff_3"]])
# Out:
#        stock_id  date_id  seconds_in_bucket  index_mean_match_balance_diff_3
# 0             0        0                  0                              NaN
# 1             0        0                 10                              NaN
# 2             0        0                 20                              NaN
# 3             0        0                 30                        -0.152539
# 4             0        0                 40                        -0.005769
# ...         ...      ...                ...                              ...
# 26450         0      480                500                         0.040343
# 26451         0      480                510                         0.012177
# 26452         0      480                520                        -0.011407
# 26453         0      480                530                        -0.011407
# 26454         0      480                540                        -0.011407
#
# [26455 rows x 4 columns]

# %%
cdf=None
if USE_REVEALED_TARGETS:
    cdf = df_train[['date_id', 'seconds_in_bucket', 'stock_id', 'target', 'revealed_target']].head(100)
cdf

# %%
# %%time

"""
print("Step3. Normalized features")
prev_cols = list(df_train.columns)


# Global features for normarization
global_wap = df_train['wap'].describe()
global_mathch_balance = df_train['match_balance'].describe()
global_target = df_train['target'].describe()
global_reference_price = df_train['reference_price'].describe()

# 📈 Function to generate normalized features
def generate_normalized_features(df, is_train):
    print("generate_normalized_features")
    if is_train:
        df['n_target'] = (df['target'] - global_target['mean']) / global_target['std']
    df['n_wap'] = (df['wap'] - global_wap['mean']) / global_wap['std']
    df['n_match_balance'] = (df['match_balance'] - global_mathch_balance['mean']) / global_mathch_balance['std']
    df['n_reference_price'] = (df['reference_price'] - global_reference_price['mean']) / global_reference_price['std']
    
    df = reduce_mem_usage(df, "generate_normalized_features")
    return df

df_train = generate_normalized_features(df_train, True)
generated_feature_name = list(set(df_train.columns) - set(prev_cols))
generated_feature_name = [c for c in generated_feature_name if c not in ["n_target"]]

features += generated_feature_name
print(generated_feature_name)

collect();
print(GetMemUsage())
"""
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 4.05 µs
# '\nprint("Step3. Normalized features")\nprev_cols = list(df_train.columns)\n\n\n# Global features for normarization\nglobal_wap = df_train[\'wap\'].describe()\nglobal_mathch_balance = df_train[\'match_balance\'].describe()\nglobal_target = df_train[\'target\'].describe()\nglobal_reference_price = df_train[\'reference_price\'].describe()\n\n# 📈 Function to generate normalized features\ndef generate_normalized_features(df, is_train):\n    print("generate_normalized_features")\n    if is_train:\n        df[\'n_target\'] = (df[\'target\'] - global_target[\'mean\']) / global_target[\'std\']\n    df[\'n_wap\'] = (df[\'wap\'] - global_wap[\'mean\']) / global_wap[\'std\']\n    df[\'n_match_balance\'] = (df[\'match_balance\'] - global_mathch_balance[\'mean\']) / global_mathch_balance[\'std\']\n    df[\'n_reference_price\'] = (df[\'reference_price\'] - global_reference_price[\'mean\']) / global_reference_price[\'std\']\n    \n    df = reduce_mem_usage(df, "generate_normalized_features")\n    return df\n\ndf_train = generate_normalized_features(df_train, True)\ngenerated_feature_name = list(set(df_train.columns) - set(prev_cols))\ngenerated_feature_name = [c for c in generated_feature_name if c not in ["n_target"]]\n\nfeatures += generated_feature_name\nprint(generated_feature_name)\n\ncollect();\nprint(GetMemUsage())\n'

# %%
df_train = reduce_mem_usage(df_train, 'train')

collect();
print(GetMemUsage())
# Out:
# RAM memory GB usage = 0.97

# %% [markdown]
# # Feature selection

# %%
# feature selection
if not USE_ALL_FEATUTES:
    features  = [
        "revealed_target",
        "wap_diff_1",
        "index_mean_wap_diff_1",
        "seconds_in_bucket",
        "stock_id",
    ]
#df_valid = df_train["target"]
#df_train = df_train[features]
if USE_REVEALED_TARGETS:
    features.remove("revealed_target")
features
# Out:
# ['stock_id',
#  'seconds_in_bucket',
#  'imbalance_size',
#  'imbalance_buy_sell_flag',
#  'reference_price',
#  'matched_size',
#  'far_price',
#  'near_price',
#  'bid_price',
#  'bid_size',
#  'ask_price',
#  'ask_size',
#  'wap',
#  'all_sizes_skew',
#  'imbalance_size_shift_2',
#  'all_prices_kurt',
#  'matched_size_bid_size_imbalance_size_imb2',
#  'bid_price_wap_imb',
#  'bid_price_wap_reference_price_imb2',
#  'reference_price_shift_3',
#  'bid_price_diff_10',
#  'imbalance_size_shift_3',
#  'reference_price_shift_10',
#  'all_prices_std',
#  'reference_price_ret_10',
#  'size_imbalance',
#  'reference_price_ret_3',
#  'far_price_ask_price_imb',
#  'bid_price_diff_1',
#  'matched_size_shift_2',
#  'imbalance_size_ret_2',
#  'reference_price_wap_imb',
#  'bid_size_diff_3',
#  'imbalance_buy_sell_flag_ret_1',
#  'price_spread',
#  'ask_price_wap_imb',
#  'matched_size_bid_size_ask_size_imb2',
#  'imbalance_size_shift_1',
#  'all_prices_mean',
#  'reference_price_near_price_imb',
#  'ask_price_wap_reference_price_imb2',
#  'reference_price_bid_price_imb',
#  'imbalance_buy_sell_flag_ret_10',
#  'imbalance_size_ret_10',
#  'reference_price_shift_2',
#  'match_balance',
#  'ask_size_diff_10',
#  'near_price_wap_imb',
#  'price_pressure',
#  'reference_price_ret_2',
#  'ask_price_diff_10',
#  'bid_price_diff_2',
#  'liquidity_imbalance',
#  'matched_size_ask_size_imbalance_size_imb2',
#  'all_sizes_std',
#  'bid_size_ask_size_imbalance_size_imb2',
#  'ask_price_diff_1',
#  'ask_size_diff_1',
#  'imbalance_buy_sell_flag_shift_10',
#  'ask_price_diff_2',
#  'matched_size_ret_3',
#  'imbalance_buy_sell_flag_shift_2',
#  'far_price_near_price_imb',
#  'bid_size_diff_10',
#  'near_price_ask_price_imb',
#  'imbalance_momentum',
#  'matched_size_ret_2',
#  'imbalance_size_shift_10',
#  'matched_size_ret_10',
#  'imbalance_size_ret_1',
#  'reference_price_shift_1',
#  'matched_size_shift_10',
#  'depth_pressure',
#  'far_price_wap_imb',
#  'all_sizes_kurt',
#  'volume',
#  'ask_size_diff_3',
#  'bid_price_diff_3',
#  'bid_size_diff_1',
#  'imbalance_size_ret_3',
#  'market_urgency',
#  'ask_price_bid_price_imb',
#  'bid_size_diff_2',
#  'reference_price_far_price_imb',
#  'reference_price_ask_price_imb',
#  'near_price_bid_price_imb',
#  'spread_intensity',
#  'imbalance_buy_sell_flag_shift_3',
#  'ask_price_bid_price_reference_price_imb2',
#  'imbalance_buy_sell_flag_ret_3',
#  'far_price_bid_price_imb',
#  'matched_size_shift_3',
#  'all_sizes_mean',
#  'ask_price_diff_3',
#  'matched_imbalance',
#  'imbalance_buy_sell_flag_ret_2',
#  'all_prices_skew',
#  'ask_size_diff_2',
#  'matched_size_shift_1',
#  'matched_size_ret_1',
#  'mid_price',
#  'ask_price_bid_price_wap_imb2',
#  'imbalance_buy_sell_flag_shift_1',
#  'reference_price_ret_1',
#  'index_std_wap_diff_3',
#  'index_std_match_balance_diff_7',
#  'index_std_match_balance_vix_7',
#  'index_std_wap_diff_1',
#  'index_std_wap_vix_3',
#  'match_balance_vix_5',
#  'wap_diff_3',
#  'wap_diff_7',
#  'index_mean_match_balance_vix_5',
#  'match_balance_diff_7',
#  'match_balance_diff_3',
#  'index_std_match_balance_vix_5',
#  'match_balance_vix_7',
#  'index_std_wap',
#  'match_balance_vix_3',
#  'index_mean_match_balance_diff_7',
#  'wap_diff_1',
#  'wap_vix_3',
#  'index_std_wap_vix_7',
#  'index_mean_wap_vix_7',
#  'index_std_wap_vix_5',
#  'match_balance_diff_1',
#  'index_mean_wap_diff_7',
#  'index_mean_wap_vix_5',
#  'index_mean_match_balance',
#  'index_mean_wap_diff_3',
#  'index_std_match_balance_vix_3',
#  'index_mean_match_balance_vix_3',
#  'index_mean_wap',
#  'index_mean_match_balance_diff_1',
#  'index_mean_wap_diff_1',
#  'index_std_match_balance',
#  'wap_vix_5',
#  'index_mean_match_balance_diff_3',
#  'index_mean_wap_vix_3',
#  'index_std_match_balance_diff_3',
#  'index_mean_match_balance_vix_7',
#  'wap_vix_7',
#  'index_std_match_balance_diff_1',
#  'index_std_wap_diff_7']

# %%
pd_display_max()
nan_count = df_train[features].isna().sum()
#df_train[features].to_csv('train.csv', index=False)
nan_count = nan_count[nan_count > 0].sort_values(ascending=False)
nan_count
# Out:
# index_std_wap_diff_7                        26455
# index_std_wap                               26455
# index_std_wap_diff_3                        26455
# index_std_match_balance_diff_7              26455
# index_std_match_balance_vix_7               26455
# index_std_wap_diff_1                        26455
# index_std_wap_vix_3                         26455
# index_std_match_balance_vix_5               26455
# index_std_wap_vix_7                         26455
# index_std_wap_vix_5                         26455
# index_std_match_balance_vix_3               26455
# index_std_match_balance                     26455
# index_std_match_balance_diff_3              26455
# index_std_match_balance_diff_1              26455
# far_price_near_price_imb                    14517
# far_price_bid_price_imb                     14517
# reference_price_far_price_imb               14517
# far_price_wap_imb                           14517
# depth_pressure                              14517
# far_price                                   14517
# far_price_ask_price_imb                     14517
# near_price                                  14430
# reference_price_near_price_imb              14430
# near_price_wap_imb                          14430
# near_price_bid_price_imb                    14430
# near_price_ask_price_imb                    14430
# imbalance_size_ret_1                         4207
# imbalance_buy_sell_flag_ret_1                4207
# match_balance_vix_7                          3893
# index_mean_match_balance_vix_7               3893
# imbalance_size_ret_2                         3855
# imbalance_buy_sell_flag_ret_2                3855
# bid_price_wap_reference_price_imb2           3614
# imbalance_size_ret_3                         3568
# imbalance_buy_sell_flag_ret_3                3568
# ask_price_bid_price_reference_price_imb2     3528
# wap_vix_7                                    3367
# index_mean_wap_vix_7                         3367
# match_balance_vix_5                          2920
# index_mean_match_balance_vix_5               2920
# wap_vix_5                                    2405
# index_mean_wap_vix_5                         2405
# imbalance_size_ret_10                        2239
# imbalance_buy_sell_flag_ret_10               2239
# index_mean_match_balance_vix_3               1946
# match_balance_vix_3                          1946
# index_mean_wap_vix_3                         1443
# wap_vix_3                                    1443
# ask_price_wap_reference_price_imb2             56
# ask_price_bid_price_wap_imb2                   38
# bid_price_diff_10                              10
# ask_size_diff_10                               10
# reference_price_shift_10                       10
# reference_price_ret_10                         10
# ask_price_diff_10                              10
# imbalance_buy_sell_flag_shift_10               10
# matched_size_shift_10                          10
# matched_size_ret_10                            10
# imbalance_size_shift_10                        10
# bid_size_diff_10                               10
# wap_diff_7                                      7
# index_mean_wap_diff_7                           7
# index_mean_match_balance_diff_7                 7
# match_balance_diff_7                            7
# wap_diff_3                                      3
# imbalance_size_shift_3                          3
# ask_size_diff_3                                 3
# bid_price_diff_3                                3
# index_mean_match_balance_diff_3                 3
# reference_price_ret_3                           3
# match_balance_diff_3                            3
# ask_price_diff_3                                3
# matched_size_shift_3                            3
# bid_size_diff_3                                 3
# reference_price_shift_3                         3
# matched_size_ret_3                              3
# imbalance_buy_sell_flag_shift_3                 3
# index_mean_wap_diff_3                           3
# ask_size_diff_2                                 2
# ask_price_diff_2                                2
# reference_price_shift_2                         2
# imbalance_buy_sell_flag_shift_2                 2
# bid_price_diff_2                                2
# bid_size_diff_2                                 2
# imbalance_size_shift_2                          2
# matched_size_ret_2                              2
# reference_price_ret_2                           2
# matched_size_shift_2                            2
# index_mean_match_balance_diff_1                 1
# index_mean_wap_diff_1                           1
# matched_size_ret_1                              1
# match_balance_diff_1                            1
# wap_diff_1                                      1
# bid_price_diff_1                                1
# reference_price_ret_1                           1
# imbalance_buy_sell_flag_shift_1                 1
# matched_size_shift_1                            1
# imbalance_size_shift_1                          1
# bid_size_diff_1                                 1
# reference_price_shift_1                         1
# imbalance_momentum                              1
# ask_size_diff_1                                 1
# ask_price_diff_1                                1
# spread_intensity                                1
# dtype: int64

# %%
pd_clear_display_max()

# %% [markdown]
# # Train function (lightgbm)

# %%
# 📦 Import necessary libraries
import numpy as np
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error
import gc
import os
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
import numpy as np
from dataclasses import dataclass
import sys
import shutil
import lightgbm as lgb

from warnings import simplefilter
simplefilter("ignore", category=RuntimeWarning)

@dataclass
class Model:
    booster: lgb.Booster
    fold: int
    feature_importance: pd.DataFrame
    score: float
    best_iteration: int
    train_time: float = None
    weight: float = None
    mem_usage: float = None
    train_func: str = None
    is_latest: bool = False

def train_model(train_x, train_y, val_x, val_y, best_params=None):
    trains = lgb.Dataset(train_x, train_y)
    valids = lgb.Dataset(val_x, val_y, reference=trains)

    verbose_eval = -1
    if best_params is None:
        params = lgb_params
    else:
        params = best_params

    print("Use params:")
    print(params)

    booster = lgb.train(
        params,
        trains,
        valid_sets=valids, # 検証データ
        num_boost_round=num_boost_round,
        keep_training_booster=True,
        callbacks=[
                lgb.early_stopping(stopping_rounds=stopping_rounds, verbose=True),
                lgb.log_evaluation(verbose_eval)
        ]
    )

    del trains, valids
    return booster

def cross_train(df, key, n_splits, features, valid_name, best_params=None):
    """ For Cross Train

    Args:
        df (_type_): _description_
        n_splits (_type_): _description_

    Returns:
        _type_: _description_
    """
    print("----------------------------------------")
    print(f"Cross Train key id {key}: start, shape: {df_train.shape}, n_splits: {n_splits}")
    print(f"num_boost_round: {num_boost_round}, stopping_rounds: {stopping_rounds}, folds: {num_folds}")

    models = []
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    df.reset_index(drop=True, inplace=True)
    
    for fold, (train_indices, valid_indices) in enumerate(kf.split(df)):
        print(f"----- Train {key}: {fold} start -----")
        now_time = time.time()

        print(f"train_indices: {train_indices}, valid_indices: {valid_indices}")
        X_train, X_valid = df[features].iloc[train_indices], df[features].iloc[valid_indices]
        y_train, y_valid = df[valid_name].loc[train_indices], df[valid_name].loc[valid_indices]
        print(f"X_train: {X_train.shape}, X_valid: {X_valid.shape}, y_train: {y_train.shape}, y_valid: {y_valid.shape}")

        booster = train_model(X_train, y_train, X_valid, y_valid, best_params)
        print(booster.best_score)
        y_valid_pred = booster.predict(X_valid)
        
        score = mean_absolute_error(y_valid, y_valid_pred)
        train_time = time.time() - now_time
        mem_usage = sys.getsizeof(booster) / (1024 * 1024) # MB
        model = Model(booster, fold, booster.feature_importance(), score, booster.best_iteration, train_time, weight= 1 / n_splits, mem_usage=mem_usage, train_func="lightgbm", is_latest=True)
        print(f"{key}: {fold} end, score: {score}, time: {model.train_time}, best_iteration: {model.best_iteration}, memory usage: {model.mem_usage}")
        
        models.append(model)
        
        del X_train, X_valid, y_train, y_valid
        gc.collect()
        print(GetMemUsage())
        print(f"----- Train {key}: {fold} end -----")

    print(f"Cross train {key} model len {len(models)}")
    print("----------------------------------------")
    return key, models

# %% [markdown]
# # Train function (optuna)

# %%
# %%time

import optuna.integration.lightgbm as optuna_lgb
import optuna
import lightgbm
optuna.logging.set_verbosity(optuna.logging.ERROR)

class TunerCVCheckpointCallback(object):
    """Optuna の LightGBMTunerCV から学習済みモデルを取り出すためのコールバック"""

    def __init__(self):
        # Models
        self.models = []
        self.counter = 0

    def get_models(self):
        # https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.Booster.html#lightgbm.Booster
        return self.models

    def __call__(self, env: lightgbm.callback.CallbackEnv):
        """_summary_

        Args:
            env (lightgbm.callback.CallbackEnv): _description_
            "model",
            "params",
            "iteration",
            "begin_iteration",
            "end_iteration",
            "evaluation_result_list"
        """
        print("")

        self.counter += 1
        print("-------------------")
        print(f"Counter: {self.counter}")
        print(f"Iteration: {env.iteration}")
        print(f"Begin_iteration: {env.begin_iteration}")
        print(f"End_iteration: {env.end_iteration}")
        print(f"Evaluation_result_list: {env.evaluation_result_list}")
        print(f"Model best_iteration: {env.model.best_iteration}")
        print("Params: ", env.params)
        #self.models.append(env.model)
        del env

        collect();
        print(GetMemUsage())

def optuna_tuning(df, n_splits, features, valid_name, model_save_path):
    df_train = df[features]
    df_valid = df[valid_name]
    
    trains = optuna_lgb.Dataset(df_train, df_valid)
    
    print("------- Optuna Tuning Start -------")
    now_time = time.time()
    print(f"num_boost_round: {num_boost_round}, stopping_rounds: {stopping_rounds}, folds: {num_folds}")

    folds = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    checkpoint_cb = TunerCVCheckpointCallback()
    
    verbose_eval = 0
    # https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.lightgbm.LightGBMTunerCV.html
    tuner = optuna_lgb.LightGBMTunerCV(
        optuna_params,
        trains,
        num_boost_round=num_boost_round,
        folds=folds,
        show_progress_bar=False,
        return_cvbooster=True,
        verbosity=-1,
        model_dir=model_save_path,
        optuna_seed=seed,
        time_budget=OPTUNA_TIME_BUDGET,
        callbacks=[
                lgb.early_stopping(stopping_rounds=stopping_rounds, verbose=True),
                lgb.log_evaluation(verbose_eval),
                checkpoint_cb
        ]
    )
    
    tuner.run()
    best_params = tuner.best_params
    
    print("Params: ")
    for key, value in best_params.items():
        print(" {}: {}".format(key, value))

    print("")
    print("len(tuner.study.trials): ", len(tuner.study.trials))
    #print("len(checkpoint_cb.cv_boosters): ", len(checkpoint_cb.models))
    print("Tuner best_params", tuner.best_params)
    print("Tuner best score: ", tuner.best_score)
   
    # 最も良かったパラメータをキーにして学習済みモデルを取り出す
    best_booster = tuner.get_best_booster()
    score = -1
    train_time = time.time() - now_time
    mem_usage = sys.getsizeof(best_booster) / (1024 * 1024) # MB
    feature_importance = np.mean(best_booster.feature_importance(), axis=0)

    best_model = Model(best_booster, 1, feature_importance, score, best_booster.best_iteration, train_time, weight= 1, mem_usage=mem_usage, train_func="optuna_lgb")
    print("------- Optuna Tuning End -------")
    return best_params, best_model
# Out:
# CPU times: user 243 ms, sys: 47.6 ms, total: 291 ms
# Wall time: 361 ms

# %% [markdown]
# # Training

# %%
# %%time

KEY = "-1"

# Train
best_params = None
key_models = None
if USE_OPTUNA:
    model_save_base_path = f"{BASE_OUTPUT_PATH}/model"
    if os.path.exists(model_save_base_path):
        print(f"{model_save_base_path} already exists, clean up it.")
        shutil.rmtree(model_save_base_path)
    os.makedirs(model_save_base_path)
    print(f"model_save_base_path: {model_save_base_path}")

    best_params, best_model = optuna_tuning(df=df_train, n_splits=num_folds, features=features, valid_name="target", model_save_path=model_save_base_path)
    key_models = [(KEY, [best_model])]
else:
    #key_models = df_train.groupby("seconds_in_bucket").apply(lambda x: cross_train(df=x, key=x.name, n_splits=num_folds, feature_name=feature_name, valid_name="target", best_params=best_params))
    key_models = [cross_train(df_train, key=KEY, n_splits=num_folds, features=features, valid_name="target", best_params=best_params)]
    if IS_USE_SAVED_MODEL:
        model_save_base_path = f"{BASE_OUTPUT_PATH}/model"
        if os.path.exists(model_save_base_path):
            print(f"{model_save_base_path} already exists, clean up it.")
            shutil.rmtree(model_save_base_path)
        os.makedirs(model_save_base_path)

        key_model_paths = []
        for key, models in key_models:
            model_save_path = f"{model_save_base_path}/{key}"
            os.makedirs(model_save_path)
            model_paths = []
            for model in models:
                model_save_fullpath = f"{model_save_path}/model_{key}_{model.fold}.txt"
                model.model.save_model(model_save_fullpath)
                model_paths.append(model_save_fullpath)
            key_model_paths.append((key, model_paths))

        model_dict_saved = {key: model_paths for key, model_paths in key_model_paths}
        print(model_dict_saved)


model_dict = {key: model for key, model in key_models}
collect()
print(GetMemUsage())
# Out:
# ----------------------------------------
# Cross Train key id -1: start, shape: (26455, 148), n_splits: 2
# num_boost_round: 1, stopping_rounds: 1, folds: 2
# ----- Train -1: 0 start -----
# train_indices: [    1     2     7 ... 26451 26453 26454], valid_indices: [    0     3     4 ... 26445 26446 26452]
# X_train: (13227, 144), X_valid: (13228, 144), y_train: (13227,), y_valid: (13228,)
# Use params:
# {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'learning_rate': 0.01, 'lambda_l1': 0.5, 'lambda_l2': 0.5, 'num_leaves': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_child_samples': 10, 'seed': 2023, 'device': 'cpu', 'verbosity': -1}
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	valid_0's rmse: 6.07255
# defaultdict(<class 'collections.OrderedDict'>, {'valid_0': OrderedDict([('rmse', 6.072553867478358)])})
# -1: 0 end, score: 4.39563872548573, time: 0.2656991481781006, best_iteration: 1, memory usage: 5.340576171875e-05
# RAM memory GB usage = 1.025
# ----- Train -1: 0 end -----
# ----- Train -1: 1 start -----
# train_indices: [    0     3     4 ... 26445 26446 26452], valid_indices: [    1     2     7 ... 26451 26453 26454]
# X_train: (13228, 144), X_valid: (13227, 144), y_train: (13228,), y_valid: (13227,)
# Use params:
# {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'learning_rate': 0.01, 'lambda_l1': 0.5, 'lambda_l2': 0.5, 'num_leaves': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_child_samples': 10, 'seed': 2023, 'device': 'cpu', 'verbosity': -1}
# Training until validation scores don't improve for 1 rounds
# Did not meet early stopping. Best iteration is:
# [1]	valid_0's rmse: 6.03588
# defaultdict(<class 'collections.OrderedDict'>, {'valid_0': OrderedDict([('rmse', 6.03588406397485)])})
# -1: 1 end, score: 4.363006259769119, time: 0.19659209251403809, best_iteration: 1, memory usage: 5.340576171875e-05
# RAM memory GB usage = 1.073
# ----- Train -1: 1 end -----
# Cross train -1 model len 2
# ----------------------------------------
# RAM memory GB usage = 1.073
# CPU times: user 1.34 s, sys: 74.2 ms, total: 1.42 s
# Wall time: 822 ms

# %% [markdown]
# # Update model using test

# %%
# %%time

# global train cache for continuous update
global_train_cache = df_train.copy()
# origin 0 is train, 1 is test, 2 is revaled
global_train_cache['origin'] = 0
date_duration = DATA_COUNT_IN_SAME_BUCKET * continuos_dataset_span
print("date_duration", date_duration)

def update_global_train_cache(df, origin, valid_key: str = 'target'):
    global global_train_cache
    df['origin'] = origin
    print("update_global_train_cache")
    global_train_cache = pd.concat([global_train_cache, df], axis=0)
    global_train_cache = global_train_cache.dropna(subset=['target'])
    global_train_cache = global_train_cache.sort_values(by=['date_id', 'seconds_in_bucket', 'stock_id', 'origin'])
    global_train_cache = global_train_cache.drop_duplicates(['date_id', 'seconds_in_bucket', 'stock_id'], keep='last')
    global_train_cache = global_train_cache.reset_index(drop=True)
    global_train_cache = global_train_cache.groupby(['stock_id']).tail(date_duration).sort_values(by=['date_id', 'seconds_in_bucket', 'stock_id']).reset_index(drop=True)

    global_train_cache = reduce_mem_usage(global_train_cache, 'global_train_cache')
    print(f"Updated global_train_cache, len: ", len(global_train_cache))
    if IS_DEBUG:
        print(len(global_train_cache))
        if USE_REVEALED_TARGETS:
            cdf = global_train_cache[['date_id', 'seconds_in_bucket', 'stock_id', 'origin', 'revealed_target', 'target']]
        else:
            cdf = global_train_cache[['date_id', 'seconds_in_bucket', 'stock_id', 'origin', 'target']]
        print(cdf)

def update_models(df, models, features, valid_name):
    """ For Update Model

    Args:
        df (_type_): _description_
        n_splits (_type_): _description_

    Returns:
        _type_: _description_
    """

    kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
    df.reset_index(drop=True, inplace=True)
    
    for fold, (train_indices, valid_indices) in enumerate(kf.split(df)):
        print(f"{key}: {fold} update")
        now_time = time.time()
        X_train, X_valid = df[features].iloc[train_indices], df[features].iloc[valid_indices]
        y_train, y_valid = df[valid_name].loc[train_indices], df[valid_name].loc[valid_indices]
        trains = lgb.Dataset(X_train, y_train, free_raw_data=False)
        valids = lgb.Dataset(X_valid, y_valid, reference=trains)

        print(f"X_train: {X_train.shape}, X_valid: {X_valid.shape}, y_train: {y_train.shape}, y_valid: {y_valid.shape}")
        models[fold].booster.update(trains)

def keep_train_models(df, models, features, valid_name, is_append=False):
    print(f"----------------- keep_train_models, is_append: {is_append}, model len: {len(models)}, df len: {len(df)} ---------------------")
    train_x = df[features]
    train_y = df[valid_name]
    trains = lgb.Dataset(train_x, train_y, free_raw_data=False)
    verbose_eval = -1

    counter = 0
    r_models = []
    if IS_DEBUG:
        print(f"Re-train dataset:")
        if USE_REVEALED_TARGETS:
            print(df[['date_id', 'seconds_in_bucket', 'stock_id', 'target', 'revealed_target']])
        else:
            print(df[['date_id', 'seconds_in_bucket', 'stock_id', 'target']])
    for model in models:
        print(f"---- train start, counter: {counter} ----")
        if model.is_latest:
            print("Update latest model")
            now_time = time.time()
            booster = lgb.train(
                lgb_params,
                trains,
                num_boost_round=update_num_boost_round,
                keep_training_booster=True,
                init_model=model.booster,
            )
            train_time = time.time() - now_time
            updated_model = Model(
                booster=booster,
                fold=1,
                best_iteration=booster.best_iteration, 
                feature_importance=booster.feature_importance(),
                score=-1, 
                train_time=train_time, 
                weight=-1, 
                mem_usage=-1,
                is_latest=True,
                train_func="lightgbm update by test")
            r_models.append(updated_model)
            if is_append:
                print("Adding previous model")
                model.is_latest = False
                r_models.append(model)
        else:
            print("Dose not latest, just append")
            r_models.append(model)
        counter = counter + 1
    print(f"---- train end, train time: {train_time}, updated model len {len(r_models)} ----")
    return r_models

if USE_CONTINUOUS_UPDATE:
    try:
        print("Update model with test date")
        df_test = load_test_dataset()
        if IS_MIN_LEARN:
            print("MIN LEARN MODE :", TARGET_STOCK_IDS)
            df_test = df_test[df_test["stock_id"].isin(TARGET_STOCK_IDS)]
        df_test = generate_basic_features(df_test)
        df_test = generate_enhance_features(df_test)
        update_global_train_cache(df_test, 1)
        #model_dict[KEY] = keep_train_models(global_train_cache, model_dict[KEY], features, "target", is_append=True)
        print("Update model with test date end")
    except Exception as e:
        print("Cannot get test date", e)

collect()
print(GetMemUsage())
# Out:
# date_duration 165
# Update model with test date
# MIN LEARN MODE : [0]
# Use index
# generate_index_features
# generate_historical_features
# update_global_train_cache
# Updated global_train_cache, len:  165
# 165
#      date_id  seconds_in_bucket  stock_id  origin    target
# 0        478                  0         0       1 -5.429983
# 1        478                 10         0       1 -3.489852
# 2        478                 20         0       1 -3.330112
# 3        478                 30         0       1 -1.900196
# 4        478                 40         0       1  2.189875
# ..       ...                ...       ...     ...       ...
# 160      480                500         0       0  3.999472
# 161      480                510         0       0  3.190041
# 162      480                520         0       0 -0.169873
# 163      480                530         0       0  3.110170
# 164      480                540         0       0  0.760555
#
# [165 rows x 5 columns]
# Update model with test date end
# RAM memory GB usage = 1.071
# CPU times: user 623 ms, sys: 28.3 ms, total: 651 ms
# Wall time: 652 ms

# %%
# Show results

for key, models in model_dict.items():
    print(f"Key: {key}, model len: {len(models)}")
    data = []
    for model in models:
        score = model.score
        best_iteration = model.best_iteration
        fold = model.fold
        train_time = model.train_time
        data.append({"key": key, "fold": fold, "score": score, "best_iteration": best_iteration, "train_time": train_time})

    df_model = pd.DataFrame(data)
    print(df_model.describe())
# Out:
# Key: -1, model len: 2
#            fold     score  best_iteration  train_time
# count  2.000000  2.000000             2.0    2.000000
# mean   0.500000  4.379322             1.0    0.231146
# std    0.707107  0.023075             0.0    0.048866
# min    0.000000  4.363006             1.0    0.196592
# 25%    0.250000  4.371164             1.0    0.213869
# 50%    0.500000  4.379322             1.0    0.231146
# 75%    0.750000  4.387481             1.0    0.248422
# max    1.000000  4.395639             1.0    0.265699

# %%
# Check model quality
data = []

for key, i_models in model_dict.items():
    for model in i_models:
        score = model.score
        best_iteration = model.best_iteration
        fold = model.fold
        train_time = model.train_time
        data.append({"key": key, "fold": fold, "score": score, "best_iteration": best_iteration, "train_time": train_time})

df_model = pd.DataFrame(data)
df_model.describe()
# Out:
#            fold     score  best_iteration  train_time
# count  2.000000  2.000000             2.0    2.000000
# mean   0.500000  4.379322             1.0    0.231146
# std    0.707107  0.023075             0.0    0.048866
# min    0.000000  4.363006             1.0    0.196592
# 25%    0.250000  4.371164             1.0    0.213869
# 50%    0.500000  4.379322             1.0    0.231146
# 75%    0.750000  4.387481             1.0    0.248422
# max    1.000000  4.395639             1.0    0.265699

# %%
# Initialize an empty DataFrame for aggregated importances
aggregated_importance = pd.DataFrame(index=features, columns=['importance'])

# Aggregate the importances from each model
for key, i_models in model_dict.items():
    for model in i_models:
        importance = pd.DataFrame({'feature': features, 'importance': model.feature_importance})
        aggregated_importance = aggregated_importance.add(importance.set_index('feature'), fill_value=0)

aggregated_importance['importance'] /= len(df_model)

pd_display_max()
# Sort the features by importance
aggregated_importance = aggregated_importance.sort_values(by='importance', ascending=False)
aggregated_importance
# Out:
#                                           importance
# imbalance_size                                   1.0
# market_urgency                                   1.0
# reference_price_shift_10                         1.0
# reference_price_wap_imb                          1.0
# reference_price_ret_3                            0.5
# index_mean_match_balance                         0.5
# price_spread                                     0.5
# imbalance_size_shift_2                           0.5
# matched_size_shift_3                             0.5
# imbalance_size_shift_10                          0.5
# reference_price_ask_price_imb                    0.5
# ask_price                                        0.5
# bid_price_wap_imb                                0.5
# matched_size_ret_3                               0.5
# matched_size_shift_1                             0.0
# ask_size_diff_2                                  0.0
# matched_size_ret_1                               0.0
# stock_id                                         0.0
# mid_price                                        0.0
# all_prices_skew                                  0.0
# imbalance_buy_sell_flag_shift_1                  0.0
# reference_price_ret_1                            0.0
# index_std_wap_diff_3                             0.0
# index_std_match_balance_diff_7                   0.0
# index_std_match_balance_vix_7                    0.0
# index_std_wap_diff_1                             0.0
# ask_price_bid_price_wap_imb2                     0.0
# all_sizes_mean                                   0.0
# imbalance_buy_sell_flag_ret_2                    0.0
# matched_imbalance                                0.0
# ask_price_diff_3                                 0.0
# match_balance_vix_5                              0.0
# far_price_bid_price_imb                          0.0
# imbalance_buy_sell_flag_ret_3                    0.0
# ask_price_bid_price_reference_price_imb2         0.0
# imbalance_buy_sell_flag_shift_3                  0.0
# spread_intensity                                 0.0
# near_price_bid_price_imb                         0.0
# reference_price_far_price_imb                    0.0
# bid_size_diff_2                                  0.0
# ask_price_bid_price_imb                          0.0
# imbalance_size_ret_3                             0.0
# index_std_wap_vix_3                              0.0
# match_balance_diff_3                             0.0
# wap_diff_3                                       0.0
# index_mean_wap_vix_5                             0.0
# index_std_match_balance_diff_1                   0.0
# wap_vix_7                                        0.0
# index_mean_match_balance_vix_7                   0.0
# index_std_match_balance_diff_3                   0.0
# index_mean_wap_vix_3                             0.0
# index_mean_match_balance_diff_3                  0.0
# wap_vix_5                                        0.0
# index_std_match_balance                          0.0
# index_mean_wap_diff_1                            0.0
# index_mean_match_balance_diff_1                  0.0
# index_mean_wap                                   0.0
# index_mean_match_balance_vix_3                   0.0
# index_std_match_balance_vix_3                    0.0
# index_mean_wap_diff_3                            0.0
# index_mean_wap_diff_7                            0.0
# wap_diff_7                                       0.0
# match_balance_diff_1                             0.0
# index_std_wap_vix_5                              0.0
# index_mean_wap_vix_7                             0.0
# index_std_wap_vix_7                              0.0
# wap_vix_3                                        0.0
# wap_diff_1                                       0.0
# index_mean_match_balance_diff_7                  0.0
# match_balance_vix_3                              0.0
# index_std_wap                                    0.0
# match_balance_vix_7                              0.0
# index_std_match_balance_vix_5                    0.0
# bid_price_diff_3                                 0.0
# match_balance_diff_7                             0.0
# index_mean_match_balance_vix_5                   0.0
# bid_size_diff_1                                  0.0
# depth_pressure                                   0.0
# ask_size_diff_3                                  0.0
# imbalance_size_shift_3                           0.0
# reference_price_near_price_imb                   0.0
# all_prices_mean                                  0.0
# imbalance_size_shift_1                           0.0
# matched_size_bid_size_ask_size_imb2              0.0
# ask_price_wap_imb                                0.0
# imbalance_buy_sell_flag_ret_1                    0.0
# bid_size_diff_3                                  0.0
# imbalance_size_ret_2                             0.0
# matched_size_shift_2                             0.0
# bid_price_diff_1                                 0.0
# far_price_ask_price_imb                          0.0
# size_imbalance                                   0.0
# reference_price_ret_10                           0.0
# all_prices_std                                   0.0
# bid_price_diff_10                                0.0
# volume                                           0.0
# reference_price_shift_3                          0.0
# bid_price_wap_reference_price_imb2               0.0
# matched_size_bid_size_imbalance_size_imb2        0.0
# all_prices_kurt                                  0.0
# all_sizes_skew                                   0.0
# wap                                              0.0
# ask_size                                         0.0
# bid_size                                         0.0
# bid_price                                        0.0
# near_price                                       0.0
# far_price                                        0.0
# matched_size                                     0.0
# reference_price                                  0.0
# imbalance_buy_sell_flag                          0.0
# ask_price_wap_reference_price_imb2               0.0
# reference_price_bid_price_imb                    0.0
# imbalance_buy_sell_flag_ret_10                   0.0
# imbalance_size_ret_10                            0.0
# all_sizes_kurt                                   0.0
# far_price_wap_imb                                0.0
# seconds_in_bucket                                0.0
# matched_size_shift_10                            0.0
# reference_price_shift_1                          0.0
# imbalance_size_ret_1                             0.0
# matched_size_ret_10                              0.0
# matched_size_ret_2                               0.0
# imbalance_momentum                               0.0
# near_price_ask_price_imb                         0.0
# bid_size_diff_10                                 0.0
# far_price_near_price_imb                         0.0
# imbalance_buy_sell_flag_shift_2                  0.0
# ask_price_diff_2                                 0.0
# imbalance_buy_sell_flag_shift_10                 0.0
# ask_size_diff_1                                  0.0
# ask_price_diff_1                                 0.0
# bid_size_ask_size_imbalance_size_imb2            0.0
# all_sizes_std                                    0.0
# matched_size_ask_size_imbalance_size_imb2        0.0
# liquidity_imbalance                              0.0
# bid_price_diff_2                                 0.0
# ask_price_diff_10                                0.0
# reference_price_ret_2                            0.0
# price_pressure                                   0.0
# near_price_wap_imb                               0.0
# ask_size_diff_10                                 0.0
# match_balance                                    0.0
# reference_price_shift_2                          0.0
# index_std_wap_diff_7                             0.0

# %% [markdown]
# # Dataset types

# %%
features_types = df_train[features].dtypes
features_types
# Out:
# stock_id                                        int8
# seconds_in_bucket                              int16
# imbalance_size                               float32
# imbalance_buy_sell_flag                         int8
# reference_price                              float32
# matched_size                                 float32
# far_price                                    float32
# near_price                                   float32
# bid_price                                    float32
# bid_size                                     float32
# ask_price                                    float32
# ask_size                                     float32
# wap                                          float32
# all_sizes_skew                               float32
# imbalance_size_shift_2                       float32
# all_prices_kurt                              float32
# matched_size_bid_size_imbalance_size_imb2    float32
# bid_price_wap_imb                            float32
# bid_price_wap_reference_price_imb2           float32
# reference_price_shift_3                      float32
# bid_price_diff_10                            float32
# imbalance_size_shift_3                       float32
# reference_price_shift_10                     float32
# all_prices_std                               float32
# reference_price_ret_10                       float32
# size_imbalance                               float32
# reference_price_ret_3                        float32
# far_price_ask_price_imb                      float32
# bid_price_diff_1                             float32
# matched_size_shift_2                         float32
# imbalance_size_ret_2                         float32
# reference_price_wap_imb                      float32
# bid_size_diff_3                              float32
# imbalance_buy_sell_flag_ret_1                float32
# price_spread                                 float32
# ask_price_wap_imb                            float32
# matched_size_bid_size_ask_size_imb2          float32
# imbalance_size_shift_1                       float32
# all_prices_mean                              float32
# reference_price_near_price_imb               float32
# ask_price_wap_reference_price_imb2           float32
# reference_price_bid_price_imb                float32
# imbalance_buy_sell_flag_ret_10               float32
# imbalance_size_ret_10                        float32
# reference_price_shift_2                      float32
# match_balance                                float32
# ask_size_diff_10                             float32
# near_price_wap_imb                           float32
# price_pressure                               float32
# reference_price_ret_2                        float32
# ask_price_diff_10                            float32
# bid_price_diff_2                             float32
# liquidity_imbalance                          float32
# matched_size_ask_size_imbalance_size_imb2    float32
# all_sizes_std                                float32
# bid_size_ask_size_imbalance_size_imb2        float32
# ask_price_diff_1                             float32
# ask_size_diff_1                              float32
# imbalance_buy_sell_flag_shift_10             float32
# ask_price_diff_2                             float32
# matched_size_ret_3                           float32
# imbalance_buy_sell_flag_shift_2              float32
# far_price_near_price_imb                     float32
# bid_size_diff_10                             float32
# near_price_ask_price_imb                     float32
# imbalance_momentum                           float32
# matched_size_ret_2                           float32
# imbalance_size_shift_10                      float32
# matched_size_ret_10                          float32
# imbalance_size_ret_1                         float32
# reference_price_shift_1                      float32
# matched_size_shift_10                        float32
# depth_pressure                               float32
# far_price_wap_imb                            float32
# all_sizes_kurt                               float32
# volume                                       float32
# ask_size_diff_3                              float32
# bid_price_diff_3                             float32
# bid_size_diff_1                              float32
# imbalance_size_ret_3                         float32
# market_urgency                               float32
# ask_price_bid_price_imb                      float32
# bid_size_diff_2                              float32
# reference_price_far_price_imb                float32
# reference_price_ask_price_imb                float32
# near_price_bid_price_imb                     float32
# spread_intensity                             float32
# imbalance_buy_sell_flag_shift_3              float32
# ask_price_bid_price_reference_price_imb2     float32
# imbalance_buy_sell_flag_ret_3                float32
# far_price_bid_price_imb                      float32
# matched_size_shift_3                         float32
# all_sizes_mean                               float32
# ask_price_diff_3                             float32
# matched_imbalance                            float32
# imbalance_buy_sell_flag_ret_2                float32
# all_prices_skew                              float32
# ask_size_diff_2                              float32
# matched_size_shift_1                         float32
# matched_size_ret_1                           float32
# mid_price                                    float32
# ask_price_bid_price_wap_imb2                 float32
# imbalance_buy_sell_flag_shift_1              float32
# reference_price_ret_1                        float32
# index_std_wap_diff_3                         float32
# index_std_match_balance_diff_7               float32
# index_std_match_balance_vix_7                float32
# index_std_wap_diff_1                         float32
# index_std_wap_vix_3                          float32
# match_balance_vix_5                          float32
# wap_diff_3                                   float32
# wap_diff_7                                   float32
# index_mean_match_balance_vix_5               float32
# match_balance_diff_7                         float32
# match_balance_diff_3                         float32
# index_std_match_balance_vix_5                float32
# match_balance_vix_7                          float32
# index_std_wap                                float32
# match_balance_vix_3                          float32
# index_mean_match_balance_diff_7              float32
# wap_diff_1                                   float32
# wap_vix_3                                    float32
# index_std_wap_vix_7                          float32
# index_mean_wap_vix_7                         float32
# index_std_wap_vix_5                          float32
# match_balance_diff_1                         float32
# index_mean_wap_diff_7                        float32
# index_mean_wap_vix_5                         float32
# index_mean_match_balance                     float32
# index_mean_wap_diff_3                        float32
# index_std_match_balance_vix_3                float32
# index_mean_match_balance_vix_3               float32
# index_mean_wap                               float32
# index_mean_match_balance_diff_1              float32
# index_mean_wap_diff_1                        float32
# index_std_match_balance                      float32
# wap_vix_5                                    float32
# index_mean_match_balance_diff_3              float32
# index_mean_wap_vix_3                         float32
# index_std_match_balance_diff_3               float32
# index_mean_match_balance_vix_7               float32
# wap_vix_7                                    float32
# index_std_match_balance_diff_1               float32
# index_std_wap_diff_7                         float32
# dtype: object

# %%
def convert_dtypes(df):
    df_types = df[features].dtypes
    different_types = [col for col in df_types.index if col in features_types and df_types[col] != features_types[col]]
    print(f"Different Types: {different_types}")
    return different_types

def update_dtypes_by_origin(df):
    diff_types = convert_dtypes(df)
    for col in diff_types:
        df[col] = df[col].astype(features_types[col])
    return df

# %% [markdown]
# # Clear trains

# %%
# Clean up
pd_clear_display_max()
del key_models
if IS_USE_SAVED_MODEL:
    print("Delete model_dict")
    del model_dict
# del df_train
collect()
print(GetMemUsage())
# Out:
# RAM memory GB usage = 1.072

# %% [markdown]
# # Infer

# %%
# %%time

# 📉 Define a function to adjust prices based on volumes
def zero_sum(prices, volumes):
    std_error = np.sqrt(volumes)  # 🧮 Calculate standard error based on volumes
    step = np.sum(prices) / np.sum(std_error)  # 🧮 Calculate the step size based on prices and standard error
    out = prices - std_error * step  # 💰 Adjust prices by subtracting the standardized step size
    return out

def zero_clip(df, predictions):
    # Adjust the predictions based on the order book imbalance
    zerosum_predictions = zero_sum(predictions, df['bid_size'] + df['ask_size'])
    clipped_predictions = np.clip(zerosum_predictions, y_min, y_max)
    clipped_predictions.replace([np.nan, np.inf, -np.inf], 0, inplace=True)
    clipped_predictions = clipped_predictions.astype('float64').values  
    return clipped_predictions

def predict_scaler(df):
    pred_mean = df['pred'].mean()
    pred_std = df['pred'].std()
    
    target_mean = global_target['mean']
    target_std = global_target['std']

    df['scaled_pred'] = (df['pred'] - pred_mean) / pred_std * target_std + target_mean
    return df

def model_infer(key, df_feat):
    def predictor(boosters):
        print(f"Predictor target models len {len(boosters)}")
        #print(f"Predictor Feat len {len(df_feat)}")
        if USE_OPTUNA:
            predictions_list = [np.mean(booster.predict(df_feat), 0) for booster in boosters]
        else:
            predictions_list = [booster.predict(df_feat) for booster in boosters]
        predictions = np.mean(predictions_list, 0)
        std_predictions = np.std(predictions_list, 0)
        #print("std_predictions", std_predictions)
        return predictions
    
    if IS_USE_SAVED_MODEL:
        model_paths = model_dict_saved[key]
        models = [lgb.Booster(model_file=model_path) for model_path in model_paths]
        predictions = predictor(models)
        del models
    else:
        boosters = [m.booster for m in model_dict[key]]
        predictions = predictor(boosters)
    collect()
    return predictions
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 5.96 µs

# %%
# %%time

y_min, y_max = -64, 64
predictions = []
cache = pd.DataFrame()
df_result = pd.DataFrame()

counter = 0
df_revealed_targets = pd.DataFrame()

if IS_INFER:
    if IS_LOCAL or IS_DEBUG:
        print("Infer Local")
        env = make_env()
    else:
        print("Infer Submission")
        import optiver2023
        env = optiver2023.make_env()
    iter_test = env.iter_test()

    try:
        for (test, revealed_targets, sample_prediction) in iter_test:
            now_time = time.time()
            print(f"------- counter {counter} start -------")

            # It faults due to test is iterator
            #seconds_in_bucket = test['seconds_in_bucket'][0]
            #print(f"prdict: {test['date_id'][0]}, {seconds_in_bucket}")

            # Generate cahce
            cache = pd.concat([cache, test], ignore_index=True, axis=0)
            if IS_MIN_LEARN:
                print("MIN LEARN MODE :", TARGET_STOCK_IDS)
                cache = cache[cache["stock_id"].isin(TARGET_STOCK_IDS)]
            if counter > 0:
                # Clear cache data
                cache = cache.groupby(['stock_id']).tail(DATA_COUNT_IN_SAME_BUCKET * continuos_train_span + 1).sort_values(by=['date_id', 'seconds_in_bucket', 'stock_id']).reset_index(drop=True)
                if USE_CONTINUOUS_UPDATE:
                    cache = cache.drop(['target'], axis=1)
                if USE_REVEALED_TARGETS:
                    cache = cache.drop(['revealed_target'], axis=1)
            print(f"cache len {len(cache)}")

            # Add revealed target as target for counituous update
            copy_revealed_targets = revealed_targets.copy()
            copy_revealed_targets = copy_revealed_targets.dropna()
            print("copy_revealed_targets len", len(copy_revealed_targets))

            if len(copy_revealed_targets) > 0:
                print("Update revealed_targets")
                copy_revealed_targets['revealed_date_id'] = copy_revealed_targets['revealed_date_id'].astype(int).astype(str)
                copy_revealed_targets['date_id'] = copy_revealed_targets['date_id'].astype(int).astype(str)
                copy_revealed_targets['seconds_in_bucket'] = copy_revealed_targets['seconds_in_bucket'].astype(int).astype(str)
                copy_revealed_targets['stock_id'] = copy_revealed_targets['stock_id'].astype(int).astype(str)  # Converting to int first to remove any decimal points
                copy_revealed_targets['revealed_row_id'] = copy_revealed_targets['revealed_date_id'] + '_' + copy_revealed_targets['seconds_in_bucket'] + '_' + copy_revealed_targets['stock_id']
                copy_revealed_targets['row_id'] = copy_revealed_targets['date_id'] + '_' + copy_revealed_targets['seconds_in_bucket'] + '_' + copy_revealed_targets['stock_id']
                copy_revealed_targets['revealed_target'] = copy_revealed_targets['revealed_target'].astype('float32')

                df_revealed_targets = pd.concat([df_revealed_targets, copy_revealed_targets], ignore_index=True, axis=0)
                # 余分なデータを削除する、範囲はcacheの2倍必要
                df_revealed_targets = df_revealed_targets.groupby(['stock_id']).tail((DATA_COUNT_IN_SAME_BUCKET * continuos_train_span + 1) * 3).sort_values(by=['date_id', 'seconds_in_bucket', 'stock_id']).reset_index(drop=True)
                df_revealed_targets = reduce_mem_usage(df_revealed_targets, 'df_revealed_targets')

            # USE_CONTINUOUS_UPDATEが有効の時、cacheのrow_idとdf_revealed_targetsのrevealed_row_idをleft joinする
            if USE_CONTINUOUS_UPDATE:
                df_r = df_revealed_targets[['revealed_row_id', 'revealed_target']]
                df_r.rename(columns={'revealed_target': 'target'}, inplace=True)
                df_r.rename(columns={'revealed_row_id': 'row_id'}, inplace=True)
                cache = pd.merge(cache, df_r, how='left', on='row_id')


            # USE_REVEALED_TARGETSが有効の時、cacheのrow_idとdf_revealed_targetsのrow_idをleft joinする
            if USE_REVEALED_TARGETS:
                df_r = df_revealed_targets[['row_id', 'revealed_target']]
                cache = pd.merge(cache, df_r, how='left', on='row_id')

            cache = reduce_mem_usage(cache, 'cache')

            # Generate features
            df_valid = generate_basic_features(cache)
            df_valid = generate_enhance_features(df_valid)
            df_valid = reduce_mem_usage(df_valid, 'df_valid')

            # Update model
            if (counter > 0) and (counter % (DATA_COUNT_IN_SAME_BUCKET * continuos_train_span) == 0) and USE_CONTINUOUS_UPDATE:
                train_now_time = time.time()
                print("Update model with revealed_target date start")
                print(f"df_valid len {len(df_valid)}")
                df_train_tmp = df_valid.copy()
                df_train_tmp.dropna(subset=['target'], inplace=True)
                df_train_tmp = update_dtypes_by_origin(df_train_tmp)
                df_train_tmp.reset_index(drop=True, inplace=True)

                update_global_train_cache(df_train_tmp, 2)
                model_dict[KEY] = keep_train_models(global_train_cache, model_dict[KEY], features, "target", True)
                print(f"ReTrain Time: {time.time() - train_now_time}")
                del df_train_tmp

            if not IS_MIN_LEARN:
                # stockの数分取得する
                df_valid = df_valid[-len(test):].reset_index(drop=True)
            else:
                df_valid = df_valid[-len(TARGET_STOCK_IDS):].reset_index(drop=True)

            # Get seconds_in_bucket and date_id
            seconds_in_bucket = df_test['seconds_in_bucket'][0]
            date_id = df_test['date_id'][0]
            print(f"Predict: {date_id}, {seconds_in_bucket}")

            # Predict
            predictions = model_infer(KEY, df_valid[features])
            df_valid['pred'] = predictions
            scaled_predictions = zero_clip(df_valid, predictions)
            df_valid['scaled_pred'] = scaled_predictions

            # For save
            if IS_DEBUG:
                df_result = pd.concat([df_result, df_valid], ignore_index=True, axis=0)

            # Submit
            if not IS_MIN_LEARN:
                print("Submit prediction")
                sample_prediction['target'] = scaled_predictions
                env.predict(sample_prediction)
            else:
                print("Submit dummy prediction")
                sample_prediction['target'] = 0
                env.predict(sample_prediction)

            # Clean up
            execution_time = time.time() - now_time
            del df_valid, predictions, scaled_predictions
            collect()
            print(GetMemUsage())
            print(f"------- counter {counter}, execution_time {execution_time} end -------")
            counter += 1
    except Exception as e:
        print("Error", e)

collect()
print(GetMemUsage())
if IS_DEBUG:
    df_result.to_csv(f"{BASE_OUTPUT_PATH}/result.csv", index=False)
# Out:
# Infer Local
# ------- counter 0 start -------
# MIN LEARN MODE : [0]
# cache len 1
# copy_revealed_targets len 11000
# Update revealed_targets
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.079
# ------- counter 0, execution_time 1.0562798976898193 end -------
# ------- counter 1 start -------
# MIN LEARN MODE : [0]
# cache len 2
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 1, execution_time 0.933434009552002 end -------
# ------- counter 2 start -------
# MIN LEARN MODE : [0]
# cache len 3
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 2, execution_time 0.537642240524292 end -------
# ------- counter 3 start -------
# MIN LEARN MODE : [0]
# cache len 4
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 3, execution_time 0.5773587226867676 end -------
# ------- counter 4 start -------
# MIN LEARN MODE : [0]
# cache len 5
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 4, execution_time 0.5634379386901855 end -------
# ------- counter 5 start -------
# MIN LEARN MODE : [0]
# cache len 6
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 5, execution_time 0.8490118980407715 end -------
# ------- counter 6 start -------
# MIN LEARN MODE : [0]
# cache len 7
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 6, execution_time 0.7064647674560547 end -------
# ------- counter 7 start -------
# MIN LEARN MODE : [0]
# cache len 8
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 7, execution_time 0.5125818252563477 end -------
# ------- counter 8 start -------
# MIN LEARN MODE : [0]
# cache len 9
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 8, execution_time 0.5460169315338135 end -------
# ------- counter 9 start -------
# MIN LEARN MODE : [0]
# cache len 10
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 9, execution_time 0.524061918258667 end -------
# ------- counter 10 start -------
# MIN LEARN MODE : [0]
# cache len 11
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 10, execution_time 0.5267646312713623 end -------
# ------- counter 11 start -------
# MIN LEARN MODE : [0]
# cache len 12
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 11, execution_time 0.5411529541015625 end -------
# ------- counter 12 start -------
# MIN LEARN MODE : [0]
# cache len 13
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 12, execution_time 0.5965430736541748 end -------
# ------- counter 13 start -------
# MIN LEARN MODE : [0]
# cache len 14
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 13, execution_time 0.5529031753540039 end -------
# ------- counter 14 start -------
# MIN LEARN MODE : [0]
# cache len 15
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 14, execution_time 0.7533092498779297 end -------
# ------- counter 15 start -------
# MIN LEARN MODE : [0]
# cache len 16
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.08
# ------- counter 15, execution_time 0.7091929912567139 end -------
# ------- counter 16 start -------
# MIN LEARN MODE : [0]
# cache len 17
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 16, execution_time 0.9839599132537842 end -------
# ------- counter 17 start -------
# MIN LEARN MODE : [0]
# cache len 18
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 17, execution_time 0.5259630680084229 end -------
# ------- counter 18 start -------
# MIN LEARN MODE : [0]
# cache len 19
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 18, execution_time 0.5008771419525146 end -------
# ------- counter 19 start -------
# MIN LEARN MODE : [0]
# cache len 20
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 19, execution_time 0.4997091293334961 end -------
# ------- counter 20 start -------
# MIN LEARN MODE : [0]
# cache len 21
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 20, execution_time 0.5401859283447266 end -------
# ------- counter 21 start -------
# MIN LEARN MODE : [0]
# cache len 22
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 21, execution_time 0.535628080368042 end -------
# ------- counter 22 start -------
# MIN LEARN MODE : [0]
# cache len 23
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 22, execution_time 0.49488091468811035 end -------
# ------- counter 23 start -------
# MIN LEARN MODE : [0]
# cache len 24
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 23, execution_time 0.5084578990936279 end -------
# ------- counter 24 start -------
# MIN LEARN MODE : [0]
# cache len 25
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 24, execution_time 0.5353689193725586 end -------
# ------- counter 25 start -------
# MIN LEARN MODE : [0]
# cache len 26
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 25, execution_time 0.5156569480895996 end -------
# ------- counter 26 start -------
# MIN LEARN MODE : [0]
# cache len 27
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 26, execution_time 0.5048089027404785 end -------
# ------- counter 27 start -------
# MIN LEARN MODE : [0]
# cache len 28
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 27, execution_time 0.5029869079589844 end -------
# ------- counter 28 start -------
# MIN LEARN MODE : [0]
# cache len 29
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 28, execution_time 0.5151658058166504 end -------
# ------- counter 29 start -------
# MIN LEARN MODE : [0]
# cache len 30
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.043
# ------- counter 29, execution_time 0.5263769626617432 end -------
# ------- counter 30 start -------
# MIN LEARN MODE : [0]
# cache len 31
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 30, execution_time 0.6049389839172363 end -------
# ------- counter 31 start -------
# MIN LEARN MODE : [0]
# cache len 32
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 31, execution_time 0.48146796226501465 end -------
# ------- counter 32 start -------
# MIN LEARN MODE : [0]
# cache len 33
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 32, execution_time 0.5045268535614014 end -------
# ------- counter 33 start -------
# MIN LEARN MODE : [0]
# cache len 34
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 33, execution_time 0.5016517639160156 end -------
# ------- counter 34 start -------
# MIN LEARN MODE : [0]
# cache len 35
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 34, execution_time 0.49896979331970215 end -------
# ------- counter 35 start -------
# MIN LEARN MODE : [0]
# cache len 36
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 35, execution_time 0.4997379779815674 end -------
# ------- counter 36 start -------
# MIN LEARN MODE : [0]
# cache len 37
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 36, execution_time 0.5089530944824219 end -------
# ------- counter 37 start -------
# MIN LEARN MODE : [0]
# cache len 38
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 37, execution_time 0.6193978786468506 end -------
# ------- counter 38 start -------
# MIN LEARN MODE : [0]
# cache len 39
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 38, execution_time 0.6678149700164795 end -------
# ------- counter 39 start -------
# MIN LEARN MODE : [0]
# cache len 40
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 39, execution_time 0.5640759468078613 end -------
# ------- counter 40 start -------
# MIN LEARN MODE : [0]
# cache len 41
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 1.044
# ------- counter 40, execution_time 0.5788960456848145 end -------
# ------- counter 41 start -------
# MIN LEARN MODE : [0]
# cache len 42
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.9139
# ------- counter 41, execution_time 0.5709390640258789 end -------
# ------- counter 42 start -------
# MIN LEARN MODE : [0]
# cache len 43
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.9146
# ------- counter 42, execution_time 0.6275880336761475 end -------
# ------- counter 43 start -------
# MIN LEARN MODE : [0]
# cache len 44
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.9146
# ------- counter 43, execution_time 0.5164749622344971 end -------
# ------- counter 44 start -------
# MIN LEARN MODE : [0]
# cache len 45
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.9146
# ------- counter 44, execution_time 0.5397448539733887 end -------
# ------- counter 45 start -------
# MIN LEARN MODE : [0]
# cache len 46
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.8892
# ------- counter 45, execution_time 0.5204992294311523 end -------
# ------- counter 46 start -------
# MIN LEARN MODE : [0]
# cache len 47
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.8893
# ------- counter 46, execution_time 0.5467240810394287 end -------
# ------- counter 47 start -------
# MIN LEARN MODE : [0]
# cache len 48
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.8893
# ------- counter 47, execution_time 0.5139851570129395 end -------
# ------- counter 48 start -------
# MIN LEARN MODE : [0]
# cache len 49
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.8893
# ------- counter 48, execution_time 0.5043790340423584 end -------
# ------- counter 49 start -------
# MIN LEARN MODE : [0]
# cache len 50
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.7682
# ------- counter 49, execution_time 0.6527590751647949 end -------
# ------- counter 50 start -------
# MIN LEARN MODE : [0]
# cache len 51
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.7447
# ------- counter 50, execution_time 0.5561542510986328 end -------
# ------- counter 51 start -------
# MIN LEARN MODE : [0]
# cache len 52
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.7447
# ------- counter 51, execution_time 0.5370187759399414 end -------
# ------- counter 52 start -------
# MIN LEARN MODE : [0]
# cache len 53
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.7447
# ------- counter 52, execution_time 0.5518929958343506 end -------
# ------- counter 53 start -------
# MIN LEARN MODE : [0]
# cache len 54
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.7448
# ------- counter 53, execution_time 0.47769904136657715 end -------
# ------- counter 54 start -------
# MIN LEARN MODE : [0]
# cache len 55
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.7404
# ------- counter 54, execution_time 0.5049448013305664 end -------
# ------- counter 55 start -------
# MIN LEARN MODE : [0]
# cache len 56
# copy_revealed_targets len 11000
# Update revealed_targets
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.7264
# ------- counter 55, execution_time 0.5816912651062012 end -------
# ------- counter 56 start -------
# MIN LEARN MODE : [0]
# cache len 57
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6949
# ------- counter 56, execution_time 0.5352456569671631 end -------
# ------- counter 57 start -------
# MIN LEARN MODE : [0]
# cache len 58
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6949
# ------- counter 57, execution_time 0.5565152168273926 end -------
# ------- counter 58 start -------
# MIN LEARN MODE : [0]
# cache len 59
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.695
# ------- counter 58, execution_time 0.509559154510498 end -------
# ------- counter 59 start -------
# MIN LEARN MODE : [0]
# cache len 60
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6707
# ------- counter 59, execution_time 0.4621601104736328 end -------
# ------- counter 60 start -------
# MIN LEARN MODE : [0]
# cache len 61
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6707
# ------- counter 60, execution_time 0.487994909286499 end -------
# ------- counter 61 start -------
# MIN LEARN MODE : [0]
# cache len 62
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6708
# ------- counter 61, execution_time 0.46314024925231934 end -------
# ------- counter 62 start -------
# MIN LEARN MODE : [0]
# cache len 63
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6709
# ------- counter 62, execution_time 0.4704718589782715 end -------
# ------- counter 63 start -------
# MIN LEARN MODE : [0]
# cache len 64
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6677
# ------- counter 63, execution_time 0.5310449600219727 end -------
# ------- counter 64 start -------
# MIN LEARN MODE : [0]
# cache len 65
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6354
# ------- counter 64, execution_time 0.49544310569763184 end -------
# ------- counter 65 start -------
# MIN LEARN MODE : [0]
# cache len 66
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6355
# ------- counter 65, execution_time 0.4733297824859619 end -------
# ------- counter 66 start -------
# MIN LEARN MODE : [0]
# cache len 67
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.6355
# ------- counter 66, execution_time 0.46208810806274414 end -------
# ------- counter 67 start -------
# MIN LEARN MODE : [0]
# cache len 68
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5611
# ------- counter 67, execution_time 0.5015549659729004 end -------
# ------- counter 68 start -------
# MIN LEARN MODE : [0]
# cache len 69
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.559
# ------- counter 68, execution_time 0.8407139778137207 end -------
# ------- counter 69 start -------
# MIN LEARN MODE : [0]
# cache len 70
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.546
# ------- counter 69, execution_time 0.7428469657897949 end -------
# ------- counter 70 start -------
# MIN LEARN MODE : [0]
# cache len 71
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5461
# ------- counter 70, execution_time 0.5230300426483154 end -------
# ------- counter 71 start -------
# MIN LEARN MODE : [0]
# cache len 72
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5461
# ------- counter 71, execution_time 0.4780888557434082 end -------
# ------- counter 72 start -------
# MIN LEARN MODE : [0]
# cache len 73
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5462
# ------- counter 72, execution_time 0.47200608253479004 end -------
# ------- counter 73 start -------
# MIN LEARN MODE : [0]
# cache len 74
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5463
# ------- counter 73, execution_time 0.4730799198150635 end -------
# ------- counter 74 start -------
# MIN LEARN MODE : [0]
# cache len 75
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5463
# ------- counter 74, execution_time 0.4883120059967041 end -------
# ------- counter 75 start -------
# MIN LEARN MODE : [0]
# cache len 76
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5464
# ------- counter 75, execution_time 0.4813239574432373 end -------
# ------- counter 76 start -------
# MIN LEARN MODE : [0]
# cache len 77
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5465
# ------- counter 76, execution_time 0.5098011493682861 end -------
# ------- counter 77 start -------
# MIN LEARN MODE : [0]
# cache len 78
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5465
# ------- counter 77, execution_time 0.4639561176300049 end -------
# ------- counter 78 start -------
# MIN LEARN MODE : [0]
# cache len 79
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5465
# ------- counter 78, execution_time 0.47536206245422363 end -------
# ------- counter 79 start -------
# MIN LEARN MODE : [0]
# cache len 80
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5476
# ------- counter 79, execution_time 0.6445009708404541 end -------
# ------- counter 80 start -------
# MIN LEARN MODE : [0]
# cache len 81
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5477
# ------- counter 80, execution_time 0.5222306251525879 end -------
# ------- counter 81 start -------
# MIN LEARN MODE : [0]
# cache len 82
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.543
# ------- counter 81, execution_time 0.5263338088989258 end -------
# ------- counter 82 start -------
# MIN LEARN MODE : [0]
# cache len 83
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5433
# ------- counter 82, execution_time 0.4772469997406006 end -------
# ------- counter 83 start -------
# MIN LEARN MODE : [0]
# cache len 84
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5412
# ------- counter 83, execution_time 0.6236426830291748 end -------
# ------- counter 84 start -------
# MIN LEARN MODE : [0]
# cache len 85
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5332
# ------- counter 84, execution_time 0.6102070808410645 end -------
# ------- counter 85 start -------
# MIN LEARN MODE : [0]
# cache len 86
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5311
# ------- counter 85, execution_time 0.49393296241760254 end -------
# ------- counter 86 start -------
# MIN LEARN MODE : [0]
# cache len 87
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5311
# ------- counter 86, execution_time 0.4866311550140381 end -------
# ------- counter 87 start -------
# MIN LEARN MODE : [0]
# cache len 88
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5312
# ------- counter 87, execution_time 0.5057950019836426 end -------
# ------- counter 88 start -------
# MIN LEARN MODE : [0]
# cache len 89
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5312
# ------- counter 88, execution_time 0.48754286766052246 end -------
# ------- counter 89 start -------
# MIN LEARN MODE : [0]
# cache len 90
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5313
# ------- counter 89, execution_time 0.5394291877746582 end -------
# ------- counter 90 start -------
# MIN LEARN MODE : [0]
# cache len 91
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5165
# ------- counter 90, execution_time 0.5618679523468018 end -------
# ------- counter 91 start -------
# MIN LEARN MODE : [0]
# cache len 92
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5079
# ------- counter 91, execution_time 0.7767620086669922 end -------
# ------- counter 92 start -------
# MIN LEARN MODE : [0]
# cache len 93
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.508
# ------- counter 92, execution_time 0.5179150104522705 end -------
# ------- counter 93 start -------
# MIN LEARN MODE : [0]
# cache len 94
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.5081
# ------- counter 93, execution_time 0.4789109230041504 end -------
# ------- counter 94 start -------
# MIN LEARN MODE : [0]
# cache len 95
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4993
# ------- counter 94, execution_time 0.6004447937011719 end -------
# ------- counter 95 start -------
# MIN LEARN MODE : [0]
# cache len 96
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4994
# ------- counter 95, execution_time 0.5868861675262451 end -------
# ------- counter 96 start -------
# MIN LEARN MODE : [0]
# cache len 97
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4994
# ------- counter 96, execution_time 0.5032620429992676 end -------
# ------- counter 97 start -------
# MIN LEARN MODE : [0]
# cache len 98
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4984
# ------- counter 97, execution_time 0.5070390701293945 end -------
# ------- counter 98 start -------
# MIN LEARN MODE : [0]
# cache len 99
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4919
# ------- counter 98, execution_time 0.5456850528717041 end -------
# ------- counter 99 start -------
# MIN LEARN MODE : [0]
# cache len 100
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4755
# ------- counter 99, execution_time 0.7264361381530762 end -------
# ------- counter 100 start -------
# MIN LEARN MODE : [0]
# cache len 101
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4754
# ------- counter 100, execution_time 0.4786031246185303 end -------
# ------- counter 101 start -------
# MIN LEARN MODE : [0]
# cache len 102
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4755
# ------- counter 101, execution_time 0.5045051574707031 end -------
# ------- counter 102 start -------
# MIN LEARN MODE : [0]
# cache len 103
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4752
# ------- counter 102, execution_time 0.5247030258178711 end -------
# ------- counter 103 start -------
# MIN LEARN MODE : [0]
# cache len 104
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4686
# ------- counter 103, execution_time 0.6311230659484863 end -------
# ------- counter 104 start -------
# MIN LEARN MODE : [0]
# cache len 105
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4686
# ------- counter 104, execution_time 0.8720970153808594 end -------
# ------- counter 105 start -------
# MIN LEARN MODE : [0]
# cache len 106
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4686
# ------- counter 105, execution_time 0.5221579074859619 end -------
# ------- counter 106 start -------
# MIN LEARN MODE : [0]
# cache len 107
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4687
# ------- counter 106, execution_time 0.6591730117797852 end -------
# ------- counter 107 start -------
# MIN LEARN MODE : [0]
# cache len 108
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4687
# ------- counter 107, execution_time 0.5398168563842773 end -------
# ------- counter 108 start -------
# MIN LEARN MODE : [0]
# cache len 109
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4688
# ------- counter 108, execution_time 0.5016460418701172 end -------
# ------- counter 109 start -------
# MIN LEARN MODE : [0]
# cache len 110
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 2
# Submit dummy prediction
# RAM memory GB usage = 0.4689
# ------- counter 109, execution_time 0.4947972297668457 end -------
# ------- counter 110 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 11000
# Update revealed_targets
# Use index
# generate_index_features
# generate_historical_features
# Update model with revealed_target date start
# df_valid len 111
# Different Types: []
# update_global_train_cache
# Updated global_train_cache, len:  165
# 165
#      date_id  seconds_in_bucket  stock_id  origin    target
# 0        478                  0         0       2 -5.429983
# 1        478                 10         0       2 -3.489852
# 2        478                 20         0       2 -3.330112
# 3        478                 30         0       2 -1.900196
# 4        478                 40         0       2  2.189875
# ..       ...                ...       ...     ...       ...
# 160      480                500         0       0  3.999472
# 161      480                510         0       0  3.190041
# 162      480                520         0       0 -0.169873
# 163      480                530         0       0  3.110170
# 164      480                540         0       0  0.760555
#
# [165 rows x 5 columns]
# ----------------- keep_train_models, is_append: True, model len: 2, df len: 165 ---------------------
# Re-train dataset:
#      date_id  seconds_in_bucket  stock_id    target
# 0        478                  0         0 -5.429983
# 1        478                 10         0 -3.489852
# 2        478                 20         0 -3.330112
# 3        478                 30         0 -1.900196
# 4        478                 40         0  2.189875
# ..       ...                ...       ...       ...
# 160      480                500         0  3.999472
# 161      480                510         0  3.190041
# 162      480                520         0 -0.169873
# 163      480                530         0  3.110170
# 164      480                540         0  0.760555
#
# [165 rows x 4 columns]
# ---- train start, counter: 0 ----
# Update latest model
# Adding previous model
# ---- train start, counter: 1 ----
# Update latest model
# Adding previous model
# ---- train end, train time: 0.007791996002197266, updated model len 4 ----
# ReTrain Time: 0.053832054138183594
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4911
# ------- counter 110, execution_time 0.5925168991088867 end -------
# ------- counter 111 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4935
# ------- counter 111, execution_time 0.49323511123657227 end -------
# ------- counter 112 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4936
# ------- counter 112, execution_time 0.5018360614776611 end -------
# ------- counter 113 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4963
# ------- counter 113, execution_time 0.6844902038574219 end -------
# ------- counter 114 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.499
# ------- counter 114, execution_time 0.5471339225769043 end -------
# ------- counter 115 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4992
# ------- counter 115, execution_time 0.4834480285644531 end -------
# ------- counter 116 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4992
# ------- counter 116, execution_time 0.5392420291900635 end -------
# ------- counter 117 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4993
# ------- counter 117, execution_time 0.48380112648010254 end -------
# ------- counter 118 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4994
# ------- counter 118, execution_time 0.4911510944366455 end -------
# ------- counter 119 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4997
# ------- counter 119, execution_time 0.49503111839294434 end -------
# ------- counter 120 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4998
# ------- counter 120, execution_time 0.4972190856933594 end -------
# ------- counter 121 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4999
# ------- counter 121, execution_time 0.498762845993042 end -------
# ------- counter 122 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5001
# ------- counter 122, execution_time 0.5221419334411621 end -------
# ------- counter 123 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5003
# ------- counter 123, execution_time 0.5068099498748779 end -------
# ------- counter 124 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4993
# ------- counter 124, execution_time 0.588151216506958 end -------
# ------- counter 125 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5001
# ------- counter 125, execution_time 0.7417302131652832 end -------
# ------- counter 126 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5005
# ------- counter 126, execution_time 0.5406010150909424 end -------
# ------- counter 127 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5006
# ------- counter 127, execution_time 0.5044560432434082 end -------
# ------- counter 128 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5007
# ------- counter 128, execution_time 0.5050780773162842 end -------
# ------- counter 129 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5007
# ------- counter 129, execution_time 0.5115447044372559 end -------
# ------- counter 130 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5008
# ------- counter 130, execution_time 0.5679318904876709 end -------
# ------- counter 131 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5009
# ------- counter 131, execution_time 0.5572149753570557 end -------
# ------- counter 132 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.501
# ------- counter 132, execution_time 0.5279507637023926 end -------
# ------- counter 133 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5011
# ------- counter 133, execution_time 0.5028338432312012 end -------
# ------- counter 134 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5011
# ------- counter 134, execution_time 0.5087051391601562 end -------
# ------- counter 135 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5012
# ------- counter 135, execution_time 0.5150609016418457 end -------
# ------- counter 136 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5012
# ------- counter 136, execution_time 0.5139999389648438 end -------
# ------- counter 137 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5012
# ------- counter 137, execution_time 0.529240608215332 end -------
# ------- counter 138 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5013
# ------- counter 138, execution_time 0.7004899978637695 end -------
# ------- counter 139 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5014
# ------- counter 139, execution_time 0.5387578010559082 end -------
# ------- counter 140 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5014
# ------- counter 140, execution_time 0.5395021438598633 end -------
# ------- counter 141 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5015
# ------- counter 141, execution_time 0.5184099674224854 end -------
# ------- counter 142 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5016
# ------- counter 142, execution_time 0.47321605682373047 end -------
# ------- counter 143 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5017
# ------- counter 143, execution_time 0.47576093673706055 end -------
# ------- counter 144 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5018
# ------- counter 144, execution_time 0.5541338920593262 end -------
# ------- counter 145 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5014
# ------- counter 145, execution_time 0.8972728252410889 end -------
# ------- counter 146 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4966
# ------- counter 146, execution_time 0.587007999420166 end -------
# ------- counter 147 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4932
# ------- counter 147, execution_time 0.8992130756378174 end -------
# ------- counter 148 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4965
# ------- counter 148, execution_time 0.7393789291381836 end -------
# ------- counter 149 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4978
# ------- counter 149, execution_time 0.6134829521179199 end -------
# ------- counter 150 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4979
# ------- counter 150, execution_time 0.5429518222808838 end -------
# ------- counter 151 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4978
# ------- counter 151, execution_time 0.5145859718322754 end -------
# ------- counter 152 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4951
# ------- counter 152, execution_time 0.8843581676483154 end -------
# ------- counter 153 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4952
# ------- counter 153, execution_time 0.6572721004486084 end -------
# ------- counter 154 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4953
# ------- counter 154, execution_time 0.6248910427093506 end -------
# ------- counter 155 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4981
# ------- counter 155, execution_time 0.6202549934387207 end -------
# ------- counter 156 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4981
# ------- counter 156, execution_time 0.5458202362060547 end -------
# ------- counter 157 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4982
# ------- counter 157, execution_time 0.534937858581543 end -------
# ------- counter 158 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4983
# ------- counter 158, execution_time 0.5714311599731445 end -------
# ------- counter 159 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4984
# ------- counter 159, execution_time 0.5625498294830322 end -------
# ------- counter 160 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4997
# ------- counter 160, execution_time 0.49861979484558105 end -------
# ------- counter 161 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4998
# ------- counter 161, execution_time 0.5249230861663818 end -------
# ------- counter 162 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.4999
# ------- counter 162, execution_time 0.5055711269378662 end -------
# ------- counter 163 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5001
# ------- counter 163, execution_time 0.5482039451599121 end -------
# ------- counter 164 start -------
# MIN LEARN MODE : [0]
# cache len 111
# copy_revealed_targets len 0
# Use index
# generate_index_features
# generate_historical_features
# Predict: 478, 0
# Predictor target models len 4
# Submit dummy prediction
# RAM memory GB usage = 0.5001
# ------- counter 164, execution_time 0.5090811252593994 end -------
# RAM memory GB usage = 0.5047
# CPU times: user 1min 49s, sys: 1.17 s, total: 1min 50s
# Wall time: 1min 51s

# %%
if IS_DEBUG:
    df_revealed_targets = pd.read_csv(REVEALED_TARGETS_FILE)
    df_revealed_targets = df_revealed_targets.dropna(subset=['revealed_date_id', 'seconds_in_bucket', 'stock_id'])
    df_revealed_targets['revealed_date_id'] = df_revealed_targets['revealed_date_id'].astype(int).astype(str)
    df_revealed_targets['seconds_in_bucket'] = df_revealed_targets['seconds_in_bucket'].astype(int).astype(str)
    df_revealed_targets['stock_id'] = df_revealed_targets['stock_id'].astype(int).astype(str)  # Converting to int first to remove any decimal points

    # Concatenate the columns
    df_revealed_targets['row_id'] = df_revealed_targets['revealed_date_id'] + '_' + df_revealed_targets['seconds_in_bucket'] + '_' + df_revealed_targets['stock_id']
    
    df_pred = df_result[['row_id', 'scaled_pred']]
    df = pd.merge(df_pred, df_revealed_targets, how='left', on='row_id')

    df = df.rename(columns={'revealed_target': 'target'})
    df = df.dropna(subset=['target'])
    df['score'] = (df['scaled_pred'] - df['target']).abs()

    #df['score'] = mean_absolute_error(df['scaled_pred'], df['target'])
    df = df[['row_id', 'scaled_pred', 'target', 'score']]
    print(df.describe())

    print("  ")
    print(df)
# Out:
#         scaled_pred      target       score
# count  1.100000e+02  110.000000  110.000000
# mean   1.137121e-09   -0.817223    3.416614
# std    1.369557e-08    4.281077    2.687239
# min   -1.961550e-08  -11.439919    0.009537
# 25%   -1.961550e-08   -4.114807    1.224875
# 50%    1.018682e-08    0.255108    2.739728
# 75%    1.018682e-08    2.127588    5.224943
# max    1.018682e-08    7.599592   11.439919
#
#         row_id   scaled_pred    target     score
# 0      478_0_0 -1.961550e-08 -5.429983  5.429983
# 1     478_10_0 -1.961550e-08 -3.489852  3.489852
# 2     478_20_0  1.018682e-08 -3.330112  3.330112
# 3     478_30_0  1.018682e-08 -1.900196  1.900196
# 4     478_40_0 -1.961550e-08  2.189875  2.189875
# ..         ...           ...       ...       ...
# 105  479_500_0  1.018682e-08  1.579523  1.579523
# 106  479_510_0  1.018682e-08 -0.180006  0.180006
# 107  479_520_0  1.018682e-08  2.199411  2.199411
# 108  479_530_0 -1.961550e-08  1.929998  1.929998
# 109  479_540_0  1.018682e-08  3.889799  3.889799
#
# [110 rows x 4 columns]

# %%
print("aaa")
# Out:
# aaa
